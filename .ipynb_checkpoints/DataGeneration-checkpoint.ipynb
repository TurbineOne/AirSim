# %%
! cd ~/aisum/AirSim

# %%
! cat ../UnrealEngine/unreal.log | grep "<>" | cut -d ' ' -f 4,6 | sed 's/[][]//g' > objectmapping.txt

# %%
! cat objectmapping.txt
# Out:
# SM_monitor_b
# SM_tv_a_wall
# SM_VisitorChair
# SM_AVP1_Power_05
# SM_AVP1_SmokeDetector_02
# SM_projector_a
# SM_AVP1_Power_06
# SM_Door
# SM_computer_a
# SM_AVP1_Keypad_01
# SM_Mousepad
# SM_AVP1_Switch_01
# SM_tv_a_wall
# SM_laptop_a
# SM_tv_a_wall
# SM_AVP1_Hook_01
# SM_mouse_b
# SM_AVP1_Vent_01
# SM_keyboard_b
# SM_ExecutiveChair
# SM_computer_c
# SM_AVP1_Power_04
# SM_AVP1_Power_06
# SM_AVP1_Network_01
# SM_tv_a
# SM_AVP1_Coax_01
# SM_AVP1_Power_03
# SM_DoorFrame
# SM_DeskTray
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_AVP1_Plate_01
# SM_monitor_c
# SM_AVP1_Power_03
# SM_Chair
# SM_Vase2
# SM_Vase1
# SM_Vase2
# SM_AVP1_Slider_01
# SM_tv_a
# SM_Window
# SM_AVP1_SmokeDetector_02
# SM_monitor_b
# SM_Vase
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_TableRound
# SM_Door
# SM_monitor_a
# SM_Couch
# SM_monitor_c
# SM_AVP1_Plate_01
# SM_TableRound
# SM_keyboard_a
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_computer_c
# SM_monitor_c
# SM_AVP1_Intercom_01
# SM_AVP1_Power_06
# SM_DeskLamp
# SM_AVP1_Switch_03
# SM_AVP1_Network_01
# SM_AVP1_Multimedia_01
# SM_printer_big_a
# SM_computer_a
# SM_Cabinet
# SM_Monitor
# SM_AVP1_Switch_01
# SM_Door
# SM_speaker_a_SM_speaker_a
# SM_Shelf
# SM_keyboard_c
# SM_AVP1_Network_01
# SM_AVP1_Power_02
# SM_Vase
# SM_Monitor
# SM_AVP1_Hook_01
# SM_Vase1
# SM_Chair
# SM_monitor_d
# SM_monitor_b
# SM_monitor_a
# SM_AVP1_Power_05
# SM_Door
# SM_paper_sherdder_a
# SM_Cabinet
# SM_paper_sherdder_a
# SM_AVP1_Sprinkler_01
# SM_speaker_a_SM_speaker_a
# SM_laptop_a_closed
# SM_keyboard_a
# SM_ExecutiveDesk
# SM_DeskLamp
# SM_tv_a
# SM_AVP1_Power_05
# SM_Mouse
# SM_laptop_a_closed
# SM_Cabinet
# SM_AVP1_Switch_04
# SM_scaner_a_open
# SM_laptop_a
# SM_AVP1_Rocker_02
# SM_Vase
# SM_AVP1_Power_01
# SM_Mousepad
# SM_mouse_a
# SM_AVP1_Power_02
# SM_AVP1_Multimedia_01
# SM_laptop_a
# SM_computer_b
# SM_AVP1_Thermo_02
# SM_monitor_a
# SM_ExecutiveChair
# SM_keyboard_c
# SM_projector_a
# SM_AVP1_Dimmer_01
# SM_AVP1_Vent_01
# SM_headphones_a
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Intercom_01
# SM_Monitor
# SM_AVP1_Switch_04
# SM_monitor_a_stand
# SM_ExecutiveDesk
# SM_Vase1
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_monitor_a
# SM_AVP1_Light_01
# SM_scaner_a
# SM_Laptop
# SM_AVP1_Rocker_01
# SM_printer_a
# SM_AVP1_Rocker_02
# SM_telephone_a
# SM_AVP1_Light_01
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_keyboard_b
# SM_AVP1_Power_05
# SM_monitor_b_screen
# SM_AVP1_Thermo_02
# SM_Globe
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_monitor_c
# SM_AVP1_Power_04
# SM_printer_a
# SM_VisitorChair
# SM_Stairs
# SM_AVP1_Vent_02
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_AVP1_Power_03
# SM_computer_a
# SM_Monitor
# SM_Chair
# SM_Chair
# SM_headphones_a
# SM_AVP1_Slider_01
# SM_AVP1_Multimedia_01
# SM_printer_big_a
# SM_AVP1_SmokeDetector_01
# SM_Window
# SM_headphones_a
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_ExecutiveChair
# SM_AVP1_Rocker_02
# SM_tv_a
# SM_monitor_a_screen
# SM_Monitor
# SM_Laptop
# SM_printer_big_a
# SM_AVP1_Multimedia_01
# SM_Vase1
# SM_AVP1_Power_01
# SM_AVP1_Coax_01
# SM_AVP1_Vent_01
# SM_Window
# SM_VisitorChair
# SM_Shelf
# SM_Vase1
# SM_Door
# SM_Chair
# SM_scaner_a_open
# SM_speaker_b
# SM_AVP1_Power_02
# SM_Vase2
# SM_Vase2
# SM_AVP1_Multimedia_01
# SM_DoorFrame
# SM_TableRound
# SM_Chair
# SM_computer_c
# SM_Mousepad
# SM_computer_c
# SM_AVP1_Vent_02
# SM_Door
# SM_DeskTray
# SM_AVP1_Dimmer_01
# SM_mouse_c
# SM_Mousepad
# SM_Vase
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_mouse_c
# SM_monitor_d
# SM_Monitor
# SM_Door
# SM_telephone_a
# SM_Vase
# SM_scaner_a_open
# SM_monitor_a
# SM_Vase
# SM_AVP1_Dimmer_01
# SM_computer_c
# SM_AVP1_SmokeDetector_01
# SM_DoorFrame
# SM_Chair
# SM_ExecutiveDesk
# SM_AVP1_Rocker_02
# SM_speaker_b
# SM_Monitor
# SM_Vase
# SM_AVP1_Coax_01
# SM_AVP1_Power_06
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_04
# SM_Cabinet
# SM_AVP1_Power_02
# SM_AVP1_Network_01
# SM_monitor_c
# SM_monitor_b
# SM_Stairs
# SM_ExecutiveChair
# SM_laptop_a_closed
# SM_monitor_c
# SM_AVP1_Power_03
# SM_Door
# SM_monitor_a
# SM_AVP1_Rocker_01
# SM_DeskTray
# SM_Window
# SM_Globe
# SM_Chair
# SM_printer_big_a
# SM_keyboard_a
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_keyboard_a
# SM_keyboard_c
# SM_AVP1_Power_05
# SM_AVP1_Rocker_01
# SM_printer_big_a
# SM_AVP1_Plate_01
# SM_Laptop
# SM_AVP1_Dimmer_01
# SM_monitor_b
# SM_computer_c
# SM_Mousepad
# SM_tv_a_wall
# SM_AVP1_Intercom_01
# SM_monitor_a_screen
# SM_tv_a_wall
# SM_Door
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_AVP1_Slider_01
# SM_AVP1_Vent_02
# SM_Keyboard
# SM_laptop_a_closed
# SM_Chair
# SM_Globe
# SM_DoorFrame
# SM_printer_big_a
# SM_mouse_a
# SM_scaner_a_open
# SM_AVP1_Motion_01
# SM_Chair
# SM_monitor_d
# SM_computer_a
# SM_AVP1_Switch_03
# SM_Vase
# SM_Door
# SM_laptop_a
# SM_paper_sherdder_a
# SM_AVP1_Slider_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Power_06
# SM_AVP1_Rocker_02
# SM_DeskLamp
# SM_DeskLamp
# SM_Laptop
# SM_monitor_a_stand
# SM_AVP1_Power_05
# SM_monitor_b_stand
# SM_DoorFrame
# SM_Globe
# SM_VisitorChair
# SM_AVP1_Coax_01
# SM_scaner_a_open
# SM_VisitorChair
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Sprinkler_01
# SM_mouse_a
# SM_mouse_b
# SM_AVP1_Power_06
# SM_Vase1
# SM_paper_sherdder_a
# SM_AVP1_Hook_01
# SM_AVP1_Power_06
# SM_AVP1_Dimmer_01
# SM_monitor_b_screen
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Power_05
# SM_AVP1_Vent_01
# SM_AVP1_Rocker_02
# SM_AVP1_Light_01
# SM_AVP1_Network_01
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_laptop_a
# SM_keyboard_b
# SM_Vase1
# SM_Cabinet
# SM_DeskLamp
# SM_monitor_a_stand
# SM_Monitor
# SM_Chair
# SM_monitor_a
# SM_Window
# SM_keyboard_c
# SM_Vase1
# SM_ExecutiveDesk
# SM_tv_a
# SM_tv_a_wall
# SM_monitor_b
# SM_AVP1_Sprinkler_01
# SM_AVP1_Hook_01
# SM_speaker_b
# SM_laptop_a
# SM_AVP1_Network_01
# SM_headphones_a
# SM_AVP1_Power_01
# SM_Keyboard
# SM_Monitor
# SM_scaner_a_open
# SM_paper_sherdder_a
# SM_PencilPot
# SM_Door
# SM_computer_c
# SM_AVP1_Switch_02
# SM_AVP1_Network_01
# SM_Window
# SM_AVP1_Switch_02
# SM_mouse_b
# SM_AVP1_Vent_02
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_02
# SM_mouse_a
# SM_mouse_a
# SM_AVP1_Keypad_01
# SM_Globe
# SM_keyboard_a
# SM_paper_sherdder_a
# SM_computer_c
# SM_printer_big_a
# SM_AVP1_Slider_01
# SM_AVP1_Rocker_02
# SM_AVP1_Vent_02
# SM_monitor_a
# SM_Keyboard
# SM_Couch
# SM_AVP1_Power_04
# SM_AVP1_Switch_04
# SM_projector_a
# SM_tv_a_wall
# SM_AVP1_Light_01
# SM_AVP1_Plate_01
# SM_monitor_b
# SM_AVP1_Switch_04
# SM_AVP1_Power_05
# SM_paper_sherdder_a
# SM_projector_a
# SM_AVP1_Power_04
# SM_AVP1_Light_01
# SM_monitor_a
# SM_tv_a
# SM_AVP1_Thermo_01
# SM_AVP1_Multimedia_01
# SM_scaner_a_open
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_AVP1_SmokeDetector_02
# SM_Couch
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_Globe
# SM_AVP1_Intercom_01
# SM_keyboard_c
# SM_AVP1_Switch_04
# SM_AVP1_Slider_01
# SM_Shelf
# SM_monitor_d
# SM_mouse_a
# SM_Vase2
# SM_VisitorChair
# SM_Couch
# SM_AVP1_Vent_02
# SM_AVP1_Power_01
# SM_AVP1_Network_01
# SM_paper_sherdder_a
# SM_AVP1_Power_01
# SM_ExecutiveChair
# SM_monitor_c
# SM_Vase
# SM_VisitorChair
# SM_AVP1_Plate_01
# SM_Monitor
# SM_telephone_a
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_Chair
# SM_monitor_b
# SM_projector_a
# SM_AVP1_Sprinkler_01
# SM_AVP1_Light_01
# SM_computer_c
# SM_keyboard_a
# SM_monitor_a
# SM_Monitor
# SM_computer_c
# SM_Stairs
# SM_monitor_a_screen
# SM_AVP1_Vent_01
# SM_projector_a
# SM_AVP1_Plate_01
# SM_monitor_a
# SM_monitor_a_stand
# SM_AVP1_Thermo_01
# SM_PencilPot
# SM_AVP1_Vent_02
# SM_headphones_a
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_02
# SM_telephone_a
# SM_projector_a
# SM_ExecutiveDesk
# SM_monitor_d
# SM_PencilPot
# SM_Vase
# SM_TableRound
# SM_mouse_b
# SM_AVP1_Power_06
# SM_AVP1_Switch_02
# SM_AVP1_Light_01
# SM_headphones_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Switch_04
# SM_Monitor
# SM_monitor_a
# SM_AVP1_Intercom_01
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_02
# SM_AVP1_Intercom_01
# SM_scaner_a
# SM_AVP1_Plate_01
# SM_AVP1_Slider_01
# SM_Monitor
# SM_speaker_b
# SM_monitor_b
# SM_monitor_d
# SM_Keyboard
# SM_DoorFrame
# SM_Shelf
# SM_DeskTray
# SM_AVP1_Thermo_01
# SM_AVP1_Light_01
# SM_Keyboard
# SM_computer_c
# SM_AVP1_Power_02
# SM_Shelf
# SM_printer_a
# SM_Monitor
# SM_AVP1_Vent_01
# SM_AVP1_Coax_01
# SM_AVP1_Switch_04
# SM_mouse_a
# SM_AVP1_Thermo_01
# SM_mouse_a
# SM_AVP1_Light_01
# SM_AVP1_Vent_02
# SM_Window
# SM_AVP1_Slider_01
# SM_AVP1_Motion_01
# SM_AVP1_Power_04
# SM_mouse_a
# SM_monitor_c
# SM_mouse_a
# SM_mouse_a
# SM_DeskLamp
# SM_AVP1_Power_03
# SM_Keyboard
# SM_DeskTray
# SM_ExecutiveDesk
# SM_AVP1_Power_05
# SM_VisitorChair
# SM_AVP1_Vent_01
# SM_monitor_d
# SM_monitor_a_stand
# SM_printer_big_a
# SM_AVP1_Rocker_02
# SM_AVP1_Multimedia_01
# SM_monitor_b
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_AVP1_Power_03
# SM_Chair
# SM_tv_a_wall
# SM_DeskTray
# SM_laptop_a
# SM_AVP1_Power_02
# SM_keyboard_a
# SM_Couch
# SM_monitor_b
# SM_computer_b
# SM_mouse_b
# SM_laptop_a
# SM_monitor_b_screen
# SM_Mousepad
# SM_AVP1_Coax_01
# SM_AVP1_Light_01
# SM_Door
# SM_mouse_b
# SM_keyboard_b
# SM_Vase
# SM_keyboard_a
# SM_Stairs
# SM_laptop_a
# SM_paper_sherdder_a
# SM_Window
# SM_monitor_d
# SM_AVP1_Thermo_02
# SM_mouse_c
# SM_AVP1_SmokeDetector_02
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Hook_01
# SM_AVP1_Power_06
# SM_AVP1_Slider_01
# SM_AVP1_Power_05
# SM_laptop_a_closed
# SM_AVP1_Power_06
# SM_keyboard_c
# SM_AVP1_Vent_02
# SM_Vase2
# SM_Shelf
# SM_AVP1_Vent_01
# SM_projector_a
# SM_AVP1_Switch_04
# SM_Shelf
# SM_laptop_a
# SM_Monitor
# SM_AVP1_Rocker_01
# SM_speaker_a_SM_speaker_a
# SM_printer_big_a
# SM_AVP1_Switch_03
# SM_ExecutiveDesk
# SM_monitor_d
# SM_AVP1_Power_04
# SM_Laptop
# SM_AVP1_Power_03
# SM_AVP1_Switch_02
# SM_computer_c
# SM_AVP1_Vent_02
# SM_tv_a_wall
# SM_AVP1_Switch_01
# SM_Stairs
# SM_projector_a
# SM_monitor_a
# SM_AVP1_Vent_02
# SM_Keyboard
# SM_AVP1_Power_04
# SM_AVP1_Power_06
# SM_AVP1_Switch_03
# SM_Window
# SM_Monitor
# SM_computer_a
# SM_monitor_c
# SM_AVP1_Dimmer_01
# SM_Window
# SM_monitor_b
# SM_Couch
# SM_projector_a
# SM_Globe
# SM_AVP1_Light_01
# SM_scaner_a
# SM_telephone_a
# SM_Shelf
# SM_AVP1_Rocker_02
# SM_AVP1_Intercom_01
# SM_Door
# SM_laptop_a_closed
# SM_AVP1_Light_01
# SM_monitor_b
# SM_Vase1
# SM_mouse_c
# SM_Chair
# SM_AVP1_Power_02
# SM_mouse_a
# SM_AVP1_Light_01
# SM_mouse_b
# SM_AVP1_Thermo_02
# SM_AVP1_Power_03
# SM_AVP1_Switch_04
# SM_Vase2
# SM_AVP1_Switch_04
# SM_AVP1_Power_01
# SM_laptop_a
# SM_AVP1_Power_03
# SM_tv_a_wall
# SM_printer_big_a
# SM_monitor_b
# SM_speaker_b
# SM_Chair
# SM_AVP1_Thermo_02
# SM_AVP1_Motion_01
# SM_AVP1_Coax_01
# SM_VisitorChair
# SM_Vase1
# SM_scaner_a_open
# SM_AVP1_Rocker_02
# SM_Shelf
# SM_AVP1_Vent_01
# SM_AVP1_Power_03
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_02
# SM_Window
# SM_paper_sherdder_a
# SM_DeskLamp
# SM_tv_a_wall
# SM_Door
# SM_computer_c
# SM_tv_a
# SM_AVP1_Switch_01
# SM_scaner_a
# SM_Shelf
# SM_AVP1_Switch_02
# SM_keyboard_a
# SM_AVP1_Plate_01
# SM_AVP1_Rocker_01
# SM_laptop_a_closed
# SM_Vase
# SM_Window
# SM_AVP1_Plate_01
# SM_AVP1_Switch_02
# SM_AVP1_SmokeDetector_02
# SM_Mouse
# SM_AVP1_Coax_01
# SM_AVP1_Motion_01
# SM_AVP1_Power_01
# SM_AVP1_Switch_04
# SM_monitor_d
# SM_monitor_b_stand
# SM_AVP1_Thermo_02
# SM_monitor_d
# SM_AVP1_Intercom_01
# SM_monitor_d
# SM_TableRound
# SM_computer_b
# SM_AVP1_Motion_01
# SM_AVP1_Power_05
# SM_keyboard_a
# SM_Door
# SM_Chair
# SM_AVP1_Power_03
# SM_Window
# SM_monitor_a_screen
# SM_Door
# SM_monitor_b_screen
# SM_VisitorChair
# SM_Chair
# SM_Chair
# SM_keyboard_c
# SM_Stairs
# SM_AVP1_Dimmer_01
# SM_monitor_b_screen
# SM_printer_big_a
# SM_Door
# SM_monitor_a_stand
# SM_monitor_b
# SM_TableRound
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_laptop_a
# SM_AVP1_Power_01
# SM_TableRound
# SM_AVP1_SmokeDetector_02
# SM_ExecutiveDesk
# SM_monitor_d
# SM_Globe
# SM_AVP1_Switch_04
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Plate_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Rocker_01
# SM_tv_a
# SM_AVP1_Rocker_01
# SM_AVP1_Intercom_01
# SM_monitor_d
# SM_laptop_a_closed
# SM_mouse_c
# SM_DeskTray
# SM_scaner_a_open
# SM_AVP1_SmokeDetector_02
# SM_monitor_a_stand
# SM_projector_a
# SM_mouse_b
# SM_computer_a
# SM_ExecutiveDesk
# SM_printer_a
# SM_AVP1_Vent_02
# SM_monitor_b
# SM_Stairs
# SM_monitor_c
# SM_AVP1_Intercom_01
# SM_printer_big_a
# SM_DeskLamp
# SM_keyboard_a
# SM_scaner_a
# SM_printer_big_a
# SM_Mouse
# SM_Globe
# SM_AVP1_Vent_01
# SM_Vase
# SM_AVP1_Switch_03
# SM_ExecutiveDesk
# SM_AVP1_Thermo_01
# SM_PencilPot
# SM_keyboard_c
# SM_scaner_a_open
# SM_keyboard_a
# SM_AVP1_SmokeDetector_02
# SM_Stairs
# SM_Monitor
# SM_monitor_d
# SM_Monitor
# SM_AVP1_Power_03
# SM_AVP1_Switch_02
# SM_computer_a
# SM_DeskLamp
# SM_computer_b
# SM_Door
# SM_printer_big_a
# SM_AVP1_Switch_02
# SM_DoorFrame
# SM_computer_b
# SM_AVP1_Power_01
# SM_mouse_a
# SM_AVP1_Intercom_01
# SM_scaner_a_open
# SM_telephone_a
# SM_tv_a
# SM_headphones_a
# SM_AVP1_Power_06
# SM_headphones_a
# SM_mouse_c
# SM_mouse_a
# SM_monitor_c
# SM_AVP1_Thermo_02
# SM_computer_a
# SM_AVP1_Plate_01
# SM_AVP1_Power_04
# SM_ExecutiveChair
# SM_projector_a
# SM_AVP1_Power_06
# SM_DeskLamp
# SM_laptop_a_closed
# SM_AVP1_Hook_01
# SM_Stairs
# SM_ExecutiveChair
# SM_DeskLamp
# SM_AVP1_Switch_01
# SM_AVP1_Slider_01
# SM_ExecutiveChair
# SM_DoorFrame
# SM_computer_a
# SM_AVP1_Switch_03
# SM_AVP1_Thermo_02
# SM_Keyboard
# SM_AVP1_Dimmer_01
# SM_AVP1_Dimmer_01
# SM_AVP1_SmokeDetector_01
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_Mousepad
# SM_scaner_a_open
# SM_monitor_b_screen
# SM_paper_sherdder_a
# SM_AVP1_Power_02
# SM_AVP1_Thermo_02
# SM_AVP1_Keypad_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Network_01
# SM_AVP1_Multimedia_01
# SM_Door
# SM_monitor_b_stand
# SM_Door
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_monitor_b_stand
# SM_AVP1_Rocker_02
# SM_mouse_c
# SM_Window
# SM_AVP1_Keypad_01
# SM_computer_a
# SM_ExecutiveChair
# SM_AVP1_Keypad_01
# SM_AVP1_Power_05
# SM_laptop_a_closed
# SM_AVP1_Switch_03
# SM_Vase1
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Switch_04
# SM_PencilPot
# SM_ExecutiveChair
# SM_AVP1_Power_06
# SM_projector_a
# SM_AVP1_Vent_02
# SM_AVP1_Light_01
# SM_Mouse
# SM_Chair
# SM_Stairs
# SM_AVP1_Rocker_01
# SM_monitor_a
# SM_monitor_a_screen
# SM_Laptop
# SM_Door
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_Keyboard
# SM_mouse_b
# SM_laptop_a
# SM_speaker_a_SM_speaker_a
# SM_Window
# SM_AVP1_Multimedia_01
# SM_tv_a
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_04
# SM_Vase1
# SM_VisitorChair
# SM_AVP1_Power_04
# SM_mouse_a
# SM_DeskLamp
# SM_Couch
# SM_Chair
# SM_ExecutiveDesk
# SM_DeskTray
# SM_AVP1_Rocker_02
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Sprinkler_01
# SM_Shelf
# SM_Monitor
# SM_monitor_b
# SM_printer_a
# SM_keyboard_b
# SM_monitor_b
# SM_mouse_a
# SM_printer_big_a
# SM_Mousepad
# SM_Couch
# SM_Globe
# SM_AVP1_Plate_01
# SM_mouse_a
# SM_AVP1_Plate_01
# SM_AVP1_Rocker_01
# SM_mouse_c
# SM_telephone_a
# SM_AVP1_Power_04
# SM_DeskLamp
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Power_04
# SM_AVP1_Motion_01
# SM_tv_a_wall
# SM_AVP1_Plate_01
# SM_Chair
# SM_ExecutiveDesk
# SM_mouse_a
# SM_AVP1_Power_01
# SM_monitor_b_stand
# SM_AVP1_Power_06
# SM_AVP1_Power_05
# SM_scaner_a_open
# SM_AVP1_Switch_01
# SM_monitor_b
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_Light_01
# SM_AVP1_SmokeDetector_01
# SM_DoorFrame
# SM_AVP1_Network_01
# SM_AVP1_Power_01
# SM_AVP1_Thermo_02
# SM_scaner_a_open
# SM_Vase
# SM_monitor_c
# SM_Couch
# SM_Door
# SM_AVP1_Light_01
# SM_ExecutiveDesk
# SM_AVP1_Keypad_01
# SM_AVP1_SmokeDetector_01
# SM_Couch
# SM_Vase
# SM_printer_a
# SM_AVP1_Rocker_02
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_AVP1_Power_02
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_AVP1_Power_04
# SM_AVP1_Light_01
# SM_monitor_a
# SM_DoorFrame
# SM_Door
# SM_monitor_b_screen
# SM_AVP1_Dimmer_01
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Plate_01
# SM_Window
# SM_AVP1_Power_06
# SM_keyboard_b
# SM_AVP1_SmokeDetector_01
# SM_Chair
# SM_AVP1_Sprinkler_01
# SM_AVP1_Power_03
# SM_monitor_a_screen
# SM_Monitor
# SM_printer_big_a
# SM_AVP1_Thermo_01
# SM_projector_a
# SM_AVP1_Intercom_01
# SM_computer_a
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_keyboard_b
# SM_paper_sherdder_a
# SM_Monitor
# SM_DeskTray
# SM_telephone_a
# SM_Vase2
# SM_computer_c
# SM_Shelf
# SM_mouse_a
# SM_Chair
# SM_AVP1_Intercom_01
# SM_AVP1_Switch_04
# SM_AVP1_Rocker_02
# SM_Keyboard
# SM_AVP1_Vent_02
# SM_AVP1_Power_05
# SM_Door
# SM_monitor_a
# SM_Chair
# SM_computer_c
# SM_computer_b
# SM_ExecutiveChair
# SM_paper_sherdder_a
# SM_AVP1_Vent_01
# SM_AVP1_Vent_02
# SM_monitor_a_screen
# SM_mouse_b
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_scaner_a
# SM_AVP1_Switch_01
# SM_AVP1_Rocker_02
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_mouse_b
# SM_AVP1_Switch_02
# SM_scaner_a
# SM_monitor_a_stand
# SM_AVP1_Power_03
# SM_Stairs
# SM_computer_a
# SM_AVP1_Thermo_01
# SM_Globe
# SM_Vase1
# SM_Door
# SM_Couch
# SM_Laptop
# SM_AVP1_Hook_01
# SM_Vase2
# SM_AVP1_Thermo_02
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_AVP1_Rocker_02
# SM_Monitor
# SM_Chair
# SM_DeskTray
# SM_monitor_a
# SM_tv_a_wall
# SM_monitor_b_screen
# SM_AVP1_Hook_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_01
# SM_paper_sherdder_a
# SM_AVP1_Switch_03
# SM_Shelf
# SM_computer_b
# SM_monitor_c
# SM_AVP1_Thermo_01
# SM_Mousepad
# SM_laptop_a_closed
# SM_AVP1_Dimmer_01
# SM_AVP1_Rocker_02
# SM_PencilPot
# SM_Monitor
# SM_tv_a
# SM_AVP1_Network_01
# SM_AVP1_Power_01
# SM_computer_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_SmokeDetector_02
# SM_mouse_c
# SM_AVP1_Switch_02
# SM_Mouse
# SM_Monitor
# SM_AVP1_Rocker_02
# SM_speaker_b
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_TableRound
# SM_AVP1_Rocker_02
# SM_Window
# SM_AVP1_Coax_01
# SM_AVP1_Multimedia_01
# SM_Laptop
# SM_monitor_a_screen
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_AVP1_Multimedia_01
# SM_AVP1_Coax_01
# SM_ExecutiveDesk
# SM_Window
# SM_AVP1_Power_02
# SM_monitor_b_stand
# SM_AVP1_Power_02
# SM_monitor_c
# SM_scaner_a
# SM_AVP1_Network_01
# SM_monitor_a_screen
# SM_Cabinet
# SM_monitor_c
# SM_VisitorChair
# SM_Keyboard
# SM_mouse_c
# SM_Shelf
# SM_paper_sherdder_a
# SM_mouse_b
# SM_Mousepad
# SM_Monitor
# SM_AVP1_Network_01
# SM_AVP1_Power_04
# SM_speaker_b
# SM_AVP1_Switch_03
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_02
# SM_laptop_a_closed
# SM_speaker_b
# SM_AVP1_Thermo_02
# SM_printer_a
# SM_monitor_a_stand
# SM_Cabinet
# SM_projector_a
# SM_DeskLamp
# SM_Chair
# SM_monitor_b_stand
# SM_AVP1_Power_01
# SM_AVP1_Switch_01
# SM_scaner_a_open
# SM_mouse_b
# SM_monitor_c
# SM_keyboard_c
# SM_tv_a_wall
# SM_mouse_a
# SM_AVP1_Multimedia_01
# SM_AVP1_SmokeDetector_02
# SM_computer_a
# SM_scaner_a
# SM_AVP1_Power_01
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_computer_c
# SM_Monitor
# SM_PencilPot
# SM_AVP1_Power_02
# SM_Window
# SM_Laptop
# SM_AVP1_Network_01
# SM_tv_a_wall
# SM_AVP1_Intercom_01
# SM_Monitor
# SM_AVP1_Switch_02
# SM_mouse_b
# SM_PencilPot
# SM_laptop_a_closed
# SM_AVP1_Coax_01
# SM_AVP1_Switch_04
# SM_DeskLamp
# SM_AVP1_Motion_01
# SM_PencilPot
# SM_Vase2
# SM_laptop_a
# SM_mouse_a
# SM_AVP1_Network_01
# SM_AVP1_Power_06
# SM_AVP1_Multimedia_01
# SM_Vase
# SM_AVP1_Power_01
# SM_monitor_b
# SM_AVP1_Rocker_02
# SM_AVP1_Motion_01
# SM_computer_b
# SM_AVP1_Power_01
# SM_AVP1_Power_03
# SM_AVP1_Hook_01
# SM_speaker_a_SM_speaker_a
# SM_tv_a_wall
# SM_DeskTray
# SM_Shelf
# SM_ExecutiveChair
# SM_monitor_a_screen
# SM_monitor_d
# SM_Door
# SM_monitor_a_stand
# SM_projector_a
# SM_AVP1_Power_02
# SM_computer_c
# SM_monitor_b
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_mouse_c
# SM_AVP1_Vent_01
# SM_monitor_b_screen
# SM_projector_a
# SM_Globe
# SM_Door
# SM_Vase1
# SM_AVP1_Intercom_01
# SM_Mouse
# SM_Shelf
# SM_Globe
# SM_monitor_a
# SM_paper_sherdder_a
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_AVP1_Thermo_02
# SM_speaker_a_SM_speaker_a
# SM_DeskTray
# SM_Cabinet
# SM_AVP1_Switch_03
# SM_AVP1_Slider_01
# SM_speaker_b
# SM_AVP1_SmokeDetector_02
# SM_paper_sherdder_a
# SM_monitor_c
# SM_DoorFrame
# SM_Monitor
# SM_Chair
# SM_mouse_a
# SM_telephone_a
# SM_monitor_a_screen
# SM_Couch
# SM_laptop_a_closed
# SM_AVP1_Switch_04
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_computer_a
# SM_Chair
# SM_Cabinet
# SM_AVP1_Slider_01
# SM_monitor_a
# SM_scaner_a
# SM_monitor_a
# SM_keyboard_c
# SM_computer_a
# SM_projector_a
# SM_AVP1_Switch_02
# SM_AVP1_Network_01
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_monitor_b
# SM_AVP1_Light_01
# SM_scaner_a_open
# SM_tv_a_wall
# SM_paper_sherdder_a
# SM_scaner_a_open
# SM_AVP1_Dimmer_01
# SM_TableRound
# SM_printer_big_a
# SM_keyboard_c
# SM_Cabinet
# SM_keyboard_a
# SM_AVP1_Keypad_01
# SM_PencilPot
# SM_AVP1_Keypad_01
# SM_computer_a
# SM_AVP1_Vent_01
# SM_monitor_b_stand
# SM_monitor_c
# SM_computer_a
# SM_keyboard_a
# SM_Monitor
# SM_AVP1_Light_01
# SM_AVP1_Keypad_01
# SM_Vase1
# SM_Door
# SM_Keyboard
# SM_telephone_a
# SM_Chair
# SM_monitor_b
# SM_paper_sherdder_a
# SM_scaner_a_open
# SM_PencilPot
# SM_AVP1_Intercom_01
# SM_AVP1_Rocker_01
# SM_speaker_a_SM_speaker_a
# SM_tv_a_wall
# SM_Keyboard
# SM_AVP1_Hook_01
# SM_Globe
# SM_monitor_b
# SM_Monitor
# SM_tv_a_wall
# SM_Vase2
# SM_AVP1_Coax_01
# SM_keyboard_b
# SM_Vase1
# SM_monitor_a_stand
# SM_AVP1_Sprinkler_01
# SM_AVP1_Vent_01
# SM_AVP1_Switch_02
# SM_monitor_d
# SM_keyboard_b
# SM_AVP1_Power_05
# SM_monitor_b_screen
# SM_Vase2
# SM_Stairs
# SM_AVP1_SmokeDetector_01
# SM_monitor_d
# SM_AVP1_Light_01
# SM_DoorFrame
# SM_laptop_a_closed
# SM_Laptop
# SM_mouse_c
# SM_AVP1_Vent_02
# SM_AVP1_Power_03
# SM_AVP1_Power_05
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_keyboard_a
# SM_AVP1_Power_06
# SM_monitor_d
# SM_Mouse
# SM_monitor_b_screen
# SM_AVP1_Multimedia_01
# SM_monitor_a_stand
# SM_DeskTray
# SM_AVP1_SmokeDetector_02
# SM_Vase2
# SM_DoorFrame
# SM_keyboard_a
# SM_computer_c
# SM_AVP1_Dimmer_01
# SM_Shelf
# SM_AVP1_Switch_01
# SM_Chair
# SM_keyboard_a
# SM_AVP1_Vent_02
# SM_Mousepad
# SM_laptop_a_closed
# SM_mouse_a
# SM_monitor_a_stand
# SM_Stairs
# SM_AVP1_Power_03
# SM_monitor_b_stand
# SM_keyboard_b
# SM_printer_big_a
# SM_monitor_c
# SM_AVP1_Power_01
# SM_Door
# SM_TableRound
# SM_mouse_a
# SM_DoorFrame
# SM_monitor_a
# SM_Laptop
# SM_AVP1_Motion_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_02
# SM_Keyboard
# SM_Vase1
# SM_DeskTray
# SM_DeskTray
# SM_AVP1_Power_01
# SM_monitor_a
# SM_AVP1_Switch_01
# SM_VisitorChair
# SM_Keyboard
# SM_AVP1_SmokeDetector_02
# SM_ExecutiveChair
# SM_AVP1_Rocker_02
# SM_projector_a
# SM_AVP1_Switch_03
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_Mouse
# SM_AVP1_Hook_01
# SM_monitor_c
# SM_Chair
# SM_mouse_c
# SM_computer_b
# SM_monitor_a_stand
# SM_AVP1_Multimedia_01
# SM_computer_a
# SM_printer_a
# SM_tv_a_wall
# SM_ExecutiveDesk
# SM_AVP1_Power_05
# SM_AVP1_Keypad_01
# SM_Door
# SM_AVP1_Switch_03
# SM_printer_a
# SM_AVP1_Network_01
# SM_speaker_b
# SM_Monitor
# SM_ExecutiveChair
# SM_AVP1_Switch_02
# SM_monitor_a_stand
# SM_AVP1_Slider_01
# SM_Cabinet
# SM_Vase1
# SM_mouse_c
# SM_Mouse
# SM_AVP1_Power_03
# SM_AVP1_Switch_04
# SM_monitor_b_screen
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_Window
# SM_Mouse
# SM_monitor_b_stand
# SM_Vase
# SM_Window
# SM_AVP1_Power_05
# SM_AVP1_Power_05
# SM_Vase
# SM_AVP1_Multimedia_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Switch_02
# SM_telephone_a
# SM_ExecutiveChair
# SM_AVP1_Motion_01
# SM_headphones_a
# SM_monitor_d
# SM_monitor_c
# SM_Mouse
# SM_Chair
# SM_mouse_c
# SM_Couch
# SM_computer_c
# SM_AVP1_Switch_01
# SM_AVP1_Power_02
# SM_monitor_a
# SM_monitor_b_stand
# SM_DeskLamp
# SM_ExecutiveDesk
# SM_keyboard_a
# SM_Vase1
# SM_AVP1_Keypad_01
# SM_DeskTray
# SM_ExecutiveDesk
# SM_ExecutiveDesk
# SM_monitor_d
# SM_Window
# SM_ExecutiveDesk
# SM_tv_a
# SM_monitor_b
# SM_printer_a
# SM_Mousepad
# SM_Chair
# SM_tv_a
# SM_AVP1_Slider_01
# SM_Chair
# SM_DeskLamp
# SM_keyboard_c
# SM_AVP1_Power_03
# SM_Monitor
# SM_Couch
# SM_AVP1_Sprinkler_01
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_AVP1_Slider_01
# SM_keyboard_a
# SM_AVP1_Power_05
# SM_DeskTray
# SM_projector_a
# SM_AVP1_Hook_01
# SM_Door
# SM_scaner_a
# SM_DeskTray
# SM_telephone_a
# SM_DeskTray
# SM_AVP1_Power_04
# SM_Chair
# SM_DeskTray
# SM_headphones_a
# SM_keyboard_a
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_AVP1_Multimedia_01
# SM_monitor_a
# SM_Shelf
# SM_mouse_a
# SM_Couch
# SM_AVP1_Light_01
# SM_scaner_a
# SM_AVP1_Vent_02
# SM_AVP1_Dimmer_01
# SM_tv_a
# SM_monitor_d
# SM_AVP1_Vent_02
# SM_DeskTray
# SM_AVP1_Switch_02
# SM_AVP1_Switch_01
# SM_AVP1_SmokeDetector_01
# SM_scaner_a
# SM_AVP1_Power_06
# SM_Mousepad
# SM_tv_a
# SM_AVP1_Sprinkler_01
# SM_keyboard_c
# SM_ExecutiveDesk
# SM_mouse_a
# SM_ExecutiveDesk
# SM_Keyboard
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_02
# SM_AVP1_Switch_03
# SM_computer_a
# SM_AVP1_Multimedia_01
# SM_monitor_b
# SM_Laptop
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Switch_01
# SM_monitor_c
# SM_monitor_a_screen
# SM_Chair
# SM_computer_a
# SM_AVP1_Multimedia_01
# SM_Door
# SM_PencilPot
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Power_03
# SM_Cabinet
# SM_monitor_b_screen
# SM_VisitorChair
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_laptop_a_closed
# SM_AVP1_Vent_01
# SM_monitor_b_screen
# SM_Monitor
# SM_AVP1_Slider_01
# SM_AVP1_Rocker_02
# SM_monitor_a_screen
# SM_monitor_a_screen
# SM_computer_a
# SM_AVP1_Intercom_01
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_screen
# SM_Monitor
# SM_Cabinet
# SM_AVP1_Power_03
# SM_ExecutiveChair
# SM_mouse_a
# SM_keyboard_c
# SM_ExecutiveChair
# SM_TableRound
# SM_keyboard_c
# SM_AVP1_Power_03
# SM_Mousepad
# SM_projector_a
# SM_AVP1_Light_01
# SM_AVP1_Intercom_01
# SM_AVP1_Switch_03
# SM_PencilPot
# SM_AVP1_Power_06
# SM_AVP1_Plate_01
# SM_monitor_d
# SM_mouse_a
# SM_Mouse
# SM_printer_big_a
# SM_keyboard_b
# SM_tv_a
# SM_AVP1_Motion_01
# SM_Shelf
# SM_DeskTray
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Coax_01
# SM_Chair
# SM_AVP1_Intercom_01
# SM_Window
# SM_Globe
# SM_Shelf
# SM_AVP1_Power_02
# SM_computer_a
# SM_TableRound
# SM_AVP1_Vent_01
# SM_projector_a
# SM_projector_a
# SM_TableRound
# SM_Globe
# SM_AVP1_Switch_04
# SM_ExecutiveChair
# SM_printer_big_a
# SM_Chair
# SM_Vase1
# SM_AVP1_SmokeDetector_01
# SM_mouse_a
# SM_mouse_c
# SM_AVP1_Switch_04
# SM_Stairs
# SM_VisitorChair
# SM_AVP1_Intercom_01
# SM_monitor_b_screen
# SM_AVP1_Network_01
# SM_AVP1_Motion_01
# SM_Shelf
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_computer_c
# SM_AVP1_Plate_01
# SM_headphones_a
# SM_monitor_b
# SM_AVP1_Network_01
# SM_Vase2
# SM_AVP1_Sprinkler_01
# SM_computer_b
# SM_AVP1_Vent_02
# SM_AVP1_Hook_01
# SM_AVP1_Vent_02
# SM_printer_a
# SM_Cabinet
# SM_AVP1_Dimmer_01
# SM_AVP1_Vent_01
# SM_ExecutiveDesk
# SM_keyboard_b
# SM_Monitor
# SM_mouse_b
# SM_Laptop
# SM_AVP1_Power_04
# SM_AVP1_Thermo_02
# SM_DoorFrame
# SM_AVP1_SmokeDetector_02
# SM_DeskTray
# SM_Mousepad
# SM_laptop_a
# SM_keyboard_b
# SM_monitor_c
# SM_keyboard_c
# SM_AVP1_Multimedia_01
# SM_DoorFrame
# SM_AVP1_Vent_02
# SM_PencilPot
# SM_monitor_a
# SM_TableRound
# SM_Monitor
# SM_keyboard_c
# SM_Mousepad
# SM_tv_a
# SM_AVP1_SmokeDetector_02
# SM_mouse_c
# SM_DoorFrame
# SM_laptop_a
# SM_AVP1_Switch_03
# SM_AVP1_Motion_01
# SM_tv_a
# SM_monitor_a_screen
# SM_AVP1_Coax_01
# SM_monitor_a
# SM_Keyboard
# SM_TableRound
# SM_Door
# SM_AVP1_Network_01
# SM_DeskTray
# SM_DeskLamp
# SM_Mousepad
# SM_tv_a_wall
# SM_Chair
# SM_Vase1
# SM_AVP1_Power_01
# SM_AVP1_SmokeDetector_02
# SM_scaner_a_open
# SM_Monitor
# SM_scaner_a
# SM_speaker_a_SM_speaker_a
# SM_Chair
# SM_AVP1_Network_01
# SM_Chair
# SM_AVP1_Rocker_01
# SM_telephone_a
# SM_AVP1_Switch_02
# SM_AVP1_Thermo_01
# SM_AVP1_Keypad_01
# SM_AVP1_Slider_01
# SM_headphones_a
# SM_Shelf
# SM_PencilPot
# SM_mouse_c
# SM_AVP1_Motion_01
# SM_Chair
# SM_AVP1_Power_05
# SM_AVP1_Switch_04
# SM_Cabinet
# SM_Door
# SM_printer_a
# SM_AVP1_Sprinkler_01
# SM_monitor_a
# SM_monitor_d
# SM_scaner_a_open
# SM_AVP1_Intercom_01
# SM_PencilPot
# SM_Stairs
# SM_mouse_c
# SM_Cabinet
# SM_monitor_a
# SM_Monitor
# SM_AVP1_Motion_01
# SM_monitor_b_screen
# SM_AVP1_Switch_02
# SM_speaker_a_SM_speaker_a
# SM_speaker_a_SM_speaker_a
# SM_Shelf
# SM_AVP1_SmokeDetector_02
# SM_Mouse
# SM_mouse_a
# SM_AVP1_Switch_03
# SM_Chair
# SM_AVP1_Hook_01
# SM_AVP1_Sprinkler_01
# SM_AVP1_Multimedia_01
# SM_Shelf
# SM_Vase1
# SM_monitor_b_screen
# SM_PencilPot
# SM_speaker_b
# SM_Window
# SM_AVP1_Power_03
# SM_Door
# SM_mouse_a
# SM_Globe
# SM_monitor_a_screen
# SM_Vase
# SM_keyboard_c
# SM_AVP1_Light_01
# SM_AVP1_Power_01
# SM_AVP1_Switch_03
# SM_mouse_b
# SM_AVP1_Rocker_02
# SM_telephone_a
# SM_AVP1_Thermo_01
# SM_computer_a
# SM_AVP1_Switch_02
# SM_Vase2
# SM_AVP1_Slider_01
# SM_AVP1_Switch_01
# SM_monitor_a
# SM_AVP1_Power_03
# SM_AVP1_Power_05
# SM_Vase1
# SM_telephone_a
# SM_keyboard_b
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_AVP1_Power_02
# SM_PencilPot
# SM_Keyboard
# SM_paper_sherdder_a
# SM_Stairs
# SM_mouse_a
# SM_Monitor
# SM_monitor_a_stand
# SM_AVP1_Plate_01
# SM_monitor_c
# SM_Door
# SM_Globe
# SM_AVP1_Switch_02
# SM_ExecutiveChair
# SM_AVP1_Vent_02
# SM_monitor_c
# SM_AVP1_Power_01
# SM_tv_a_wall
# SM_mouse_a
# SM_AVP1_Coax_01
# SM_AVP1_Light_01
# SM_Door
# SM_AVP1_Power_01
# SM_AVP1_Switch_03
# SM_mouse_c
# SM_computer_b
# SM_speaker_a_SM_speaker_a
# SM_Chair
# SM_Globe
# SM_AVP1_Coax_01
# SM_mouse_b
# SM_AVP1_Power_06
# SM_mouse_b
# SM_Laptop
# SM_monitor_b_screen
# SM_computer_c
# SM_DoorFrame
# SM_AVP1_SmokeDetector_02
# SM_monitor_a_screen
# SM_AVP1_Coax_01
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Motion_01
# SM_AVP1_Plate_01
# SM_Door
# SM_Chair
# SM_projector_a
# SM_monitor_c
# SM_Laptop
# SM_ExecutiveChair
# SM_computer_a
# SM_VisitorChair
# SM_Chair
# SM_paper_sherdder_a
# SM_telephone_a
# SM_Chair
# SM_monitor_d
# SM_AVP1_Rocker_01
# SM_monitor_d
# SM_AVP1_Slider_01
# SM_Couch
# SM_AVP1_Rocker_01
# SM_Monitor
# SM_monitor_d
# SM_DoorFrame
# SM_monitor_a_screen
# SM_AVP1_Intercom_01
# SM_AVP1_SmokeDetector_01
# SM_paper_sherdder_a
# SM_computer_c
# SM_AVP1_Vent_01
# SM_Door
# SM_Stairs
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_speaker_b
# SM_Monitor
# SM_AVP1_Power_04
# SM_projector_a
# SM_Globe
# SM_AVP1_Light_01
# SM_AVP1_SmokeDetector_01
# SM_PencilPot
# SM_laptop_a_closed
# SM_laptop_a_closed
# SM_AVP1_Vent_02
# SM_Shelf
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Coax_01
# SM_Door
# SM_AVP1_Hook_01
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_Monitor
# SM_tv_a
# SM_Couch
# SM_AVP1_Multimedia_01
# SM_monitor_b_screen
# SM_printer_a
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_printer_a
# SM_Couch
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_keyboard_b
# SM_Door
# SM_AVP1_Power_02
# SM_Mouse
# SM_AVP1_Plate_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Intercom_01
# SM_tv_a
# SM_Globe
# SM_Mousepad
# SM_AVP1_Power_04
# SM_Laptop
# SM_keyboard_b
# SM_tv_a_wall
# SM_printer_a
# SM_AVP1_Rocker_01
# SM_monitor_a
# SM_keyboard_c
# SM_AVP1_Power_04
# SM_Keyboard
# SM_AVP1_Power_06
# SM_Vase1
# SM_keyboard_b
# SM_mouse_a
# SM_monitor_d
# SM_AVP1_Light_01
# SM_monitor_c
# SM_AVP1_Network_01
# SM_keyboard_c
# SM_AVP1_Switch_01
# SM_Vase
# SM_laptop_a_closed
# SM_Monitor
# SM_AVP1_Motion_01
# SM_Vase1
# SM_scaner_a_open
# SM_scaner_a_open
# SM_Stairs
# SM_printer_a
# SM_computer_b
# SM_scaner_a_open
# SM_scaner_a_open
# SM_speaker_a_SM_speaker_a
# SM_monitor_a
# SM_AVP1_Switch_03
# SM_projector_a
# SM_AVP1_Thermo_02
# SM_TableRound
# SM_tv_a
# SM_DoorFrame
# SM_scaner_a_open
# SM_laptop_a_closed
# SM_monitor_b_stand
# SM_Mousepad
# SM_PencilPot
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_monitor_b_stand
# SM_AVP1_Power_06
# SM_tv_a_wall
# SM_scaner_a_open
# SM_scaner_a
# SM_monitor_c
# SM_ExecutiveDesk
# SM_mouse_b
# SM_AVP1_Thermo_01
# SM_AVP1_Light_01
# SM_AVP1_Motion_01
# SM_Window
# SM_monitor_b_screen
# SM_AVP1_Power_02
# SM_Monitor
# SM_mouse_c
# SM_monitor_b_screen
# SM_speaker_b
# SM_computer_a
# SM_AVP1_Switch_02
# SM_monitor_d
# SM_TableRound
# SM_VisitorChair
# SM_Door
# SM_Chair
# SM_AVP1_Plate_01
# SM_Couch
# SM_AVP1_Rocker_02
# SM_AVP1_Hook_01
# SM_monitor_b
# SM_DoorFrame
# SM_Monitor
# SM_ExecutiveChair
# SM_AVP1_Thermo_02
# SM_VisitorChair
# SM_Door
# SM_AVP1_SmokeDetector_02
# SM_Chair
# SM_AVP1_Coax_01
# SM_Cabinet
# SM_keyboard_b
# SM_VisitorChair
# SM_AVP1_Switch_01
# SM_telephone_a
# SM_AVP1_Slider_01
# SM_AVP1_Sprinkler_01
# SM_computer_c
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_02
# SM_AVP1_Power_04
# SM_scaner_a
# SM_scaner_a
# SM_AVP1_Vent_01
# SM_keyboard_b
# SM_Door
# SM_Window
# SM_AVP1_Switch_03
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_Door
# SM_Stairs
# SM_AVP1_Thermo_01
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_AVP1_Power_01
# SM_AVP1_Power_01
# SM_AVP1_Intercom_01
# SM_tv_a_wall
# SM_Globe
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_scaner_a
# SM_DoorFrame
# SM_Chair
# SM_printer_a
# SM_AVP1_Thermo_01
# SM_computer_c
# SM_paper_sherdder_a
# SM_AVP1_Power_04
# SM_AVP1_Motion_01
# SM_Vase2
# SM_Door
# SM_AVP1_Network_01
# SM_mouse_c
# SM_AVP1_Coax_01
# SM_monitor_c
# SM_mouse_c
# SM_tv_a
# SM_AVP1_Power_04
# SM_DeskLamp
# SM_monitor_b
# SM_AVP1_Multimedia_01
# SM_monitor_b_stand
# SM_AVP1_SmokeDetector_01
# SM_keyboard_b
# SM_Door
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_ExecutiveDesk
# SM_Chair
# SM_printer_a
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Power_06
# SM_mouse_c
# SM_keyboard_b
# SM_computer_a
# SM_keyboard_a
# SM_AVP1_Switch_02
# SM_Vase2
# SM_AVP1_Rocker_01
# SM_keyboard_b
# SM_AVP1_Plate_01
# SM_monitor_d
# SM_printer_big_a
# SM_monitor_a
# SM_AVP1_Switch_04
# SM_monitor_b_screen
# SM_AVP1_Vent_02
# SM_scaner_a
# SM_Chair
# SM_AVP1_Switch_03
# SM_Globe
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_keyboard_c
# SM_monitor_a_screen
# SM_Chair
# SM_Vase2
# SM_AVP1_Multimedia_01
# SM_speaker_b
# SM_Stairs
# SM_scaner_a_open
# SM_VisitorChair
# SM_Chair
# SM_Vase
# SM_Mousepad
# SM_AVP1_Motion_01
# SM_AVP1_Vent_02
# SM_Door
# SM_DeskTray
# SM_AVP1_Power_02
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Motion_01
# SM_PencilPot
# SM_mouse_a
# SM_AVP1_Power_05
# SM_Shelf
# SM_Mousepad
# SM_DeskLamp
# SM_Window
# SM_telephone_a
# SM_Window
# SM_DoorFrame
# SM_AVP1_SmokeDetector_01
# SM_computer_b
# SM_monitor_a_screen
# SM_DoorFrame
# SM_computer_b
# SM_AVP1_Power_02
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_printer_big_a
# SM_Window
# SM_Stairs
# SM_projector_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Hook_01
# SM_tv_a_wall
# SM_AVP1_Power_04
# SM_AVP1_Power_01
# SM_AVP1_Rocker_02
# SM_headphones_a
# SM_Chair
# SM_AVP1_Light_01
# SM_Cabinet
# SM_Door
# SM_monitor_a
# SM_DoorFrame
# SM_computer_b
# SM_Stairs
# SM_Chair
# SM_computer_b
# SM_laptop_a_closed
# SM_computer_a
# SM_mouse_c
# SM_AVP1_Light_01
# SM_AVP1_Thermo_02
# SM_Couch
# SM_AVP1_Network_01
# SM_Chair
# SM_tv_a_wall
# SM_AVP1_Multimedia_01
# SM_Vase1
# SM_monitor_a_stand
# SM_AVP1_Intercom_01
# SM_AVP1_Power_06
# SM_monitor_b_stand
# SM_paper_sherdder_a
# SM_projector_a
# SM_Laptop
# SM_Chair
# SM_AVP1_Multimedia_01
# SM_projector_a
# SM_Door
# SM_AVP1_Keypad_01
# SM_AVP1_Dimmer_01
# SM_ExecutiveChair
# SM_scaner_a_open
# SM_AVP1_Switch_02
# SM_AVP1_Thermo_02
# SM_AVP1_Vent_02
# SM_AVP1_Switch_03
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_keyboard_b
# SM_mouse_b
# SM_Stairs
# SM_mouse_a
# SM_Stairs
# SM_AVP1_Rocker_01
# SM_AVP1_Network_01
# SM_Vase2
# SM_monitor_b_screen
# SM_VisitorChair
# SM_AVP1_Switch_01
# SM_AVP1_Vent_01
# SM_TableRound
# SM_monitor_b_screen
# SM_speaker_a_SM_speaker_a
# SM_Vase1
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_computer_c
# SM_computer_a
# SM_AVP1_Sprinkler_01
# SM_ExecutiveChair
# SM_DeskLamp
# SM_printer_big_a
# SM_AVP1_Keypad_01
# SM_keyboard_a
# SM_Globe
# SM_scaner_a_open
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_monitor_b_stand
# SM_AVP1_Switch_03
# SM_Mouse
# SM_computer_a
# SM_monitor_a_stand
# SM_Shelf
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_monitor_c
# SM_monitor_b_screen
# SM_mouse_c
# SM_AVP1_Switch_03
# SM_Mouse
# SM_AVP1_Plate_01
# SM_AVP1_Plate_01
# SM_AVP1_Vent_01
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_TableRound
# SM_monitor_b_stand
# SM_Cabinet
# SM_Shelf
# SM_monitor_a_stand
# SM_projector_a
# SM_computer_a
# SM_speaker_b
# SM_AVP1_Vent_01
# SM_printer_big_a
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_laptop_a
# SM_AVP1_Hook_01
# SM_DeskLamp
# SM_Stairs
# SM_TableRound
# SM_DeskTray
# SM_AVP1_Motion_01
# SM_scaner_a
# SM_Globe
# SM_AVP1_Multimedia_01
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_Chair
# SM_AVP1_Power_03
# SM_printer_a
# SM_AVP1_Intercom_01
# SM_monitor_a_stand
# SM_computer_b
# SM_Couch
# SM_telephone_a
# SM_keyboard_a
# SM_monitor_a_stand
# SM_monitor_c
# SM_DoorFrame
# SM_printer_a
# SM_Chair
# SM_Vase2
# SM_DeskLamp
# SM_Mouse
# SM_AVP1_Power_06
# SM_AVP1_Switch_04
# SM_speaker_a_SM_speaker_a
# SM_mouse_a
# SM_AVP1_Thermo_01
# SM_Window
# SM_AVP1_Switch_03
# SM_scaner_a_open
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Vent_01
# SM_keyboard_a
# SM_Monitor
# SM_telephone_a
# SM_AVP1_Power_06
# SM_computer_c
# SM_AVP1_Power_03
# SM_Mousepad
# SM_Mousepad
# SM_AVP1_Rocker_01
# SM_laptop_a
# SM_monitor_b_screen
# SM_monitor_c
# SM_AVP1_Power_02
# SM_Cabinet
# SM_telephone_a
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_headphones_a
# SM_Vase2
# SM_AVP1_Power_04
# SM_telephone_a
# SM_Cabinet
# SM_AVP1_Sprinkler_01
# SM_monitor_b
# SM_Chair
# SM_AVP1_Coax_01
# SM_headphones_a
# SM_ExecutiveDesk
# SM_Chair
# SM_scaner_a
# SM_computer_a
# SM_AVP1_Thermo_02
# SM_AVP1_Network_01
# SM_printer_a
# SM_mouse_c
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_AVP1_Thermo_01
# SM_AVP1_Switch_02
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_computer_c
# SM_AVP1_Switch_03
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_scaner_a
# SM_AVP1_Switch_04
# SM_Vase1
# SM_DeskTray
# SM_Monitor
# SM_AVP1_Power_06
# SM_tv_a_wall
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_speaker_b
# SM_AVP1_Thermo_02
# SM_AVP1_Hook_01
# SM_DoorFrame
# SM_Stairs
# SM_Door
# SM_DeskLamp
# SM_ExecutiveDesk
# SM_AVP1_Keypad_01
# SM_Vase2
# SM_AVP1_Power_01
# SM_AVP1_Switch_04
# SM_headphones_a
# SM_Window
# SM_AVP1_Switch_02
# SM_AVP1_Vent_02
# SM_Vase
# SM_AVP1_Thermo_02
# SM_AVP1_Rocker_02
# SM_AVP1_Plate_01
# SM_Monitor
# SM_Vase2
# SM_AVP1_Power_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Slider_01
# SM_paper_sherdder_a
# SM_keyboard_c
# SM_AVP1_Rocker_01
# SM_AVP1_Power_04
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_printer_a
# SM_Door
# SM_AVP1_SmokeDetector_01
# SM_ExecutiveChair
# SM_AVP1_SmokeDetector_02
# SM_DeskTray
# SM_keyboard_b
# SM_Couch
# SM_computer_c
# SM_Window
# SM_laptop_a_closed
# SM_AVP1_Vent_01
# SM_AVP1_Switch_01
# SM_scaner_a
# SM_TableRound
# SM_Door
# SM_Monitor
# SM_AVP1_SmokeDetector_02
# SM_Laptop
# SM_AVP1_SmokeDetector_02
# SM_Keyboard
# SM_AVP1_Power_02
# SM_printer_big_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Sprinkler_01
# SM_tv_a
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_AVP1_Sprinkler_01
# SM_TableRound
# SM_Chair
# SM_monitor_a
# SM_telephone_a
# SM_ExecutiveDesk
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Multimedia_01
# SM_Door
# SM_AVP1_Vent_01
# SM_keyboard_c
# SM_keyboard_a
# SM_AVP1_Multimedia_01
# SM_monitor_d
# SM_laptop_a_closed
# SM_tv_a_wall
# SM_Laptop
# SM_monitor_d
# SM_scaner_a_open
# SM_Cabinet
# SM_AVP1_Power_01
# SM_AVP1_Power_04
# SM_Keyboard
# SM_monitor_a_stand
# SM_AVP1_Keypad_01
# SM_projector_a
# SM_tv_a
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Light_01
# SM_monitor_a_stand
# SM_tv_a_wall
# SM_AVP1_Plate_01
# SM_AVP1_Power_02
# SM_tv_a_wall
# SM_monitor_b_stand
# SM_speaker_a_SM_speaker_a
# SM_scaner_a_open
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_Mousepad
# SM_mouse_b
# SM_AVP1_Network_01
# SM_ExecutiveDesk
# SM_Window
# SM_monitor_b
# SM_AVP1_Switch_03
# SM_AVP1_Power_06
# SM_Cabinet
# SM_AVP1_Sprinkler_01
# SM_projector_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Hook_01
# SM_keyboard_b
# SM_Door
# SM_printer_a
# SM_Keyboard
# SM_AVP1_Thermo_02
# SM_tv_a
# SM_AVP1_Thermo_02
# SM_Cabinet
# SM_Vase2
# SM_computer_c
# SM_Laptop
# SM_AVP1_Vent_02
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_laptop_a_closed
# SM_keyboard_a
# SM_monitor_d
# SM_AVP1_Thermo_01
# SM_AVP1_Rocker_02
# SM_Keyboard
# SM_keyboard_c
# SM_laptop_a_closed
# SM_printer_a
# SM_monitor_d
# SM_AVP1_Light_01
# SM_keyboard_b
# SM_AVP1_Keypad_01
# SM_AVP1_Rocker_02
# SM_printer_a
# SM_Vase2
# SM_AVP1_Power_01
# SM_mouse_a
# SM_TableRound
# SM_Couch
# SM_Chair
# SM_Mouse
# SM_tv_a
# SM_Monitor
# SM_Globe
# SM_keyboard_b
# SM_speaker_b
# SM_ExecutiveDesk
# SM_AVP1_Network_01
# SM_Keyboard
# SM_AVP1_Sprinkler_01
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_DeskLamp
# SM_AVP1_Coax_01
# SM_tv_a
# SM_Keyboard
# SM_Laptop
# SM_Vase
# SM_Window
# SM_monitor_b_stand
# SM_AVP1_Sprinkler_01
# SM_keyboard_b
# SM_Door
# SM_Globe
# SM_AVP1_Power_01
# SM_monitor_c
# SM_mouse_c
# SM_PencilPot
# SM_AVP1_Dimmer_01
# SM_monitor_b
# SM_Vase2
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_SmokeDetector_02
# SM_TableRound
# SM_AVP1_Power_03
# SM_AVP1_Power_01
# SM_TableRound
# SM_AVP1_Multimedia_01
# SM_Monitor
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_AVP1_Thermo_02
# SM_projector_a
# SM_AVP1_Network_01
# SM_AVP1_Switch_04
# SM_AVP1_Dimmer_01
# SM_VisitorChair
# SM_monitor_a_stand
# SM_Couch
# SM_monitor_b
# SM_Vase
# SM_monitor_d
# SM_computer_c
# SM_monitor_c
# SM_keyboard_c
# SM_computer_c
# SM_Door
# SM_AVP1_Motion_01
# SM_monitor_b_stand
# SM_AVP1_Intercom_01
# SM_paper_sherdder_a
# SM_Vase2
# SM_laptop_a
# SM_AVP1_Thermo_01
# SM_DeskTray
# SM_AVP1_Power_03
# SM_Vase1
# SM_printer_big_a
# SM_AVP1_Thermo_02
# SM_keyboard_a
# SM_AVP1_Light_01
# SM_Vase
# SM_headphones_a
# SM_AVP1_Thermo_02
# SM_monitor_b_stand
# SM_monitor_d
# SM_DeskTray
# SM_AVP1_Slider_01
# SM_Vase
# SM_AVP1_Hook_01
# SM_AVP1_Switch_04
# SM_Monitor
# SM_telephone_a
# SM_Monitor
# SM_monitor_b_stand
# SM_AVP1_Motion_01
# SM_speaker_b
# SM_tv_a_wall
# SM_VisitorChair
# SM_Couch
# SM_monitor_c
# SM_AVP1_Switch_01
# SM_computer_a
# SM_monitor_a_screen
# SM_Window
# SM_Globe
# SM_AVP1_Light_01
# SM_AVP1_Motion_01
# SM_Vase
# SM_mouse_b
# SM_monitor_b_stand
# SM_ExecutiveDesk
# SM_scaner_a_open
# SM_TableRound
# SM_keyboard_b
# SM_AVP1_Intercom_01
# SM_TableRound
# SM_computer_a
# SM_mouse_a
# SM_AVP1_Switch_03
# SM_mouse_a
# SM_Globe
# SM_AVP1_Coax_01
# SM_keyboard_c
# SM_Stairs
# SM_AVP1_Switch_02
# SM_AVP1_Switch_01
# SM_computer_b
# SM_PencilPot
# SM_monitor_a_stand
# SM_Window
# SM_AVP1_Power_05
# SM_TableRound
# SM_monitor_b_stand
# SM_Door
# SM_Shelf
# SM_Laptop
# SM_laptop_a_closed
# SM_Shelf
# SM_tv_a_wall
# SM_scaner_a
# SM_AVP1_Slider_01
# SM_scaner_a_open
# SM_computer_a
# SM_ExecutiveChair
# SM_tv_a
# SM_ExecutiveDesk
# SM_AVP1_Power_03
# SM_laptop_a
# SM_Chair
# SM_Keyboard
# SM_monitor_d
# SM_speaker_b
# SM_PencilPot
# SM_AVP1_Switch_03
# SM_monitor_a_screen
# SM_Chair
# SM_tv_a_wall
# SM_Mouse
# SM_laptop_a
# SM_laptop_a_closed
# SM_AVP1_Sprinkler_01
# SM_mouse_a
# SM_monitor_c
# SM_tv_a_wall
# SM_Couch
# SM_DoorFrame
# SM_Chair
# SM_VisitorChair
# SM_mouse_c
# SM_speaker_a_SM_speaker_a
# SM_DeskLamp
# SM_mouse_b
# SM_AVP1_Dimmer_01
# SM_VisitorChair
# SM_PencilPot
# SM_Chair
# SM_AVP1_Light_01
# SM_TableRound
# SM_AVP1_Switch_02
# SM_AVP1_Coax_01
# SM_monitor_a_screen
# SM_AVP1_Thermo_01
# SM_AVP1_Network_01
# SM_AVP1_Power_04
# SM_Door
# SM_headphones_a
# SM_laptop_a
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_04
# SM_Shelf
# SM_mouse_a
# SM_monitor_a_screen
# SM_computer_b
# SM_laptop_a
# SM_Laptop
# SM_keyboard_a
# SM_AVP1_Plate_01
# SM_AVP1_Power_05
# SM_AVP1_Rocker_01
# SM_monitor_b_screen
# SM_computer_a
# SM_monitor_a
# SM_AVP1_Vent_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Sprinkler_01
# SM_Keyboard
# SM_keyboard_a
# SM_telephone_a
# SM_AVP1_Vent_02
# SM_keyboard_c
# SM_AVP1_Switch_04
# SM_AVP1_Coax_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Thermo_01
# SM_printer_a
# SM_keyboard_c
# SM_DoorFrame
# SM_speaker_a_SM_speaker_a
# SM_Door
# SM_monitor_a_screen
# SM_AVP1_Power_03
# SM_AVP1_Switch_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Vent_02
# SM_Couch
# SM_telephone_a
# SM_DeskTray
# SM_monitor_b_screen
# SM_Door
# SM_Chair
# SM_monitor_b_screen
# SM_Chair
# SM_AVP1_Power_03
# SM_AVP1_Rocker_02
# SM_paper_sherdder_a
# SM_DoorFrame
# SM_telephone_a
# SM_monitor_b_screen
# SM_AVP1_Network_01
# SM_Vase1
# SM_scaner_a
# SM_mouse_a
# SM_AVP1_Keypad_01
# SM_Monitor
# SM_projector_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Keypad_01
# SM_monitor_a_screen
# SM_projector_a
# SM_Mouse
# SM_monitor_b_screen
# SM_AVP1_Vent_01
# SM_AVP1_Slider_01
# SM_monitor_a_stand
# SM_DeskTray
# SM_tv_a_wall
# SM_scaner_a
# SM_AVP1_Power_04
# SM_Door
# SM_AVP1_Hook_01
# SM_AVP1_Hook_01
# SM_laptop_a_closed
# SM_Door
# SM_headphones_a
# SM_tv_a_wall
# SM_keyboard_c
# SM_AVP1_Thermo_01
# SM_Door
# SM_computer_a
# SM_projector_a
# SM_Laptop
# SM_AVP1_Network_01
# SM_printer_a
# SM_AVP1_Power_01
# SM_keyboard_c
# SM_AVP1_Keypad_01
# SM_AVP1_Thermo_02
# SM_AVP1_Keypad_01
# SM_paper_sherdder_a
# SM_AVP1_Switch_03
# SM_AVP1_Power_02
# SM_headphones_a
# SM_AVP1_Coax_01
# SM_mouse_c
# SM_AVP1_Slider_01
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_Coax_01
# SM_scaner_a
# SM_Window
# SM_Laptop
# SM_DoorFrame
# SM_Door
# SM_DeskTray
# SM_VisitorChair
# SM_AVP1_Network_01
# SM_Chair
# SM_AVP1_Hook_01
# SM_monitor_b
# SM_Monitor
# SM_laptop_a
# SM_printer_big_a
# SM_Vase
# SM_AVP1_Power_03
# SM_keyboard_a
# SM_AVP1_Rocker_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Vent_02
# SM_DeskLamp
# SM_monitor_b
# SM_AVP1_Switch_03
# SM_AVP1_Switch_03
# SM_laptop_a_closed
# SM_AVP1_Keypad_01
# SM_mouse_b
# SM_Vase1
# SM_projector_a
# SM_DoorFrame
# SM_AVP1_Plate_01
# SM_ExecutiveChair
# SM_AVP1_Power_01
# SM_scaner_a_open
# SM_tv_a_wall
# SM_DeskLamp
# SM_AVP1_Thermo_01
# SM_ExecutiveChair
# SM_telephone_a
# SM_monitor_b
# SM_AVP1_Multimedia_01
# SM_Shelf
# SM_AVP1_Power_02
# SM_DoorFrame
# SM_AVP1_Multimedia_01
# SM_mouse_a
# SM_mouse_b
# SM_Mouse
# SM_monitor_b
# SM_AVP1_Vent_01
# SM_Laptop
# SM_Cabinet
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Power_02
# SM_Couch
# SM_printer_big_a
# SM_Couch
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_scaner_a
# SM_AVP1_Switch_01
# SM_monitor_b_stand
# SM_AVP1_Switch_01
# SM_AVP1_Motion_01
# SM_Door
# SM_laptop_a
# SM_Shelf
# SM_monitor_b
# SM_monitor_a_stand
# SM_Monitor
# SM_Vase2
# SM_monitor_a_stand
# SM_AVP1_Vent_01
# SM_AVP1_Light_01
# SM_AVP1_Power_04
# SM_ExecutiveChair
# SM_tv_a
# SM_Couch
# SM_Monitor
# SM_tv_a_wall
# SM_computer_a
# SM_tv_a
# SM_laptop_a_closed
# SM_keyboard_c
# SM_AVP1_Thermo_01
# SM_Cabinet
# SM_monitor_a_stand
# SM_telephone_a
# SM_monitor_c
# SM_Window
# SM_AVP1_Coax_01
# SM_Vase2
# SM_ExecutiveChair
# SM_AVP1_Network_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_03
# SM_Monitor
# SM_scaner_a_open
# SM_AVP1_Light_01
# SM_Vase2
# SM_printer_a
# SM_TableRound
# SM_headphones_a
# SM_monitor_a
# SM_monitor_b_stand
# SM_Vase
# SM_tv_a
# SM_Globe
# SM_AVP1_Plate_01
# SM_AVP1_Thermo_01
# SM_Couch
# SM_telephone_a
# SM_Chair
# SM_VisitorChair
# SM_AVP1_SmokeDetector_02
# SM_Monitor
# SM_PencilPot
# SM_monitor_c
# SM_AVP1_Multimedia_01
# SM_Laptop
# SM_monitor_c
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_AVP1_Motion_01
# SM_laptop_a
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_monitor_d
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Thermo_02
# SM_telephone_a
# SM_AVP1_Power_03
# SM_Keyboard
# SM_AVP1_Switch_04
# SM_Keyboard
# SM_scaner_a
# SM_scaner_a_open
# SM_AVP1_Switch_04
# SM_laptop_a_closed
# SM_Vase
# SM_Laptop
# SM_mouse_b
# SM_Stairs
# SM_AVP1_Dimmer_01
# SM_laptop_a
# SM_Vase1
# SM_AVP1_Slider_01
# SM_AVP1_Intercom_01
# SM_mouse_a
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_Globe
# SM_speaker_b
# SM_DeskTray
# SM_AVP1_Hook_01
# SM_keyboard_b
# SM_AVP1_Light_01
# SM_DeskTray
# SM_laptop_a
# SM_AVP1_Power_05
# SM_mouse_a
# SM_printer_a
# SM_AVP1_Plate_01
# SM_scaner_a
# SM_AVP1_Intercom_01
# SM_ExecutiveChair
# SM_AVP1_Multimedia_01
# SM_mouse_a
# SM_computer_a
# SM_tv_a_wall
# SM_laptop_a
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_keyboard_a
# SM_AVP1_Slider_01
# SM_AVP1_Light_01
# SM_tv_a_wall
# SM_telephone_a
# SM_DeskLamp
# SM_AVP1_Rocker_02
# SM_Chair
# SM_mouse_c
# SM_telephone_a
# SM_AVP1_Plate_01
# SM_Stairs
# SM_monitor_a_screen
# SM_Shelf
# SM_Stairs
# SM_AVP1_Thermo_01
# SM_monitor_b_screen
# SM_AVP1_Sprinkler_01
# SM_keyboard_c
# SM_keyboard_c
# SM_computer_b
# SM_Chair
# SM_monitor_b
# SM_AVP1_Slider_01
# SM_AVP1_Sprinkler_01
# SM_AVP1_Motion_01
# SM_speaker_a_SM_speaker_a
# SM_DeskLamp
# SM_AVP1_Switch_03
# SM_Globe
# SM_AVP1_Coax_01
# SM_AVP1_Vent_01
# SM_Chair
# SM_monitor_b_screen
# SM_AVP1_SmokeDetector_01
# SM_VisitorChair
# SM_DeskLamp
# SM_AVP1_SmokeDetector_01
# SM_telephone_a
# SM_paper_sherdder_a
# SM_Monitor
# SM_AVP1_Power_01
# SM_AVP1_Sprinkler_01
# SM_DeskTray
# SM_Chair
# SM_mouse_b
# SM_AVP1_Plate_01
# SM_Door
# SM_keyboard_a
# SM_monitor_a_stand
# SM_Monitor
# SM_AVP1_SmokeDetector_02
# SM_Globe
# SM_AVP1_Motion_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Hook_01
# SM_paper_sherdder_a
# SM_telephone_a
# SM_DoorFrame
# SM_Shelf
# SM_tv_a_wall
# SM_DoorFrame
# SM_AVP1_Hook_01
# SM_AVP1_Rocker_01
# SM_Keyboard
# SM_AVP1_Coax_01
# SM_Mouse
# SM_Door
# SM_AVP1_Light_01
# SM_Mousepad
# SM_Couch
# SM_Keyboard
# SM_AVP1_Switch_04
# SM_AVP1_Power_01
# SM_keyboard_a
# SM_AVP1_Power_03
# SM_AVP1_Dimmer_01
# SM_Cabinet
# SM_AVP1_Switch_01
# SM_monitor_a_screen
# SM_scaner_a
# SM_tv_a_wall
# SM_printer_big_a
# SM_AVP1_Rocker_02
# SM_keyboard_b
# SM_AVP1_Slider_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Thermo_01
# SM_Door
# SM_Keyboard
# SM_Couch
# SM_printer_big_a
# SM_DoorFrame
# SM_laptop_a_closed
# SM_tv_a_wall
# SM_AVP1_Power_06
# SM_Chair
# SM_ExecutiveDesk
# SM_PencilPot
# SM_Door
# SM_DoorFrame
# SM_AVP1_Sprinkler_01
# SM_printer_big_a
# SM_mouse_c
# SM_Shelf
# SM_Chair
# SM_VisitorChair
# SM_laptop_a
# SM_AVP1_SmokeDetector_02
# SM_Chair
# SM_Monitor
# SM_DeskTray
# SM_AVP1_Power_06
# SM_AVP1_SmokeDetector_01
# SM_Mousepad
# SM_AVP1_Vent_02
# SM_Chair
# SM_speaker_a_SM_speaker_a
# SM_tv_a
# SM_AVP1_Power_02
# SM_paper_sherdder_a
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_headphones_a
# SM_AVP1_Slider_01
# SM_mouse_c
# SM_DoorFrame
# SM_mouse_a
# SM_AVP1_Rocker_02
# SM_Window
# SM_AVP1_Motion_01
# SM_Shelf
# SM_AVP1_Multimedia_01
# SM_Chair
# SM_computer_b
# SM_AVP1_Power_02
# SM_Monitor
# SM_scaner_a
# SM_Shelf
# SM_AVP1_Thermo_01
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_01
# SM_Window
# SM_Mouse
# SM_paper_sherdder_a
# SM_monitor_a_screen
# SM_Monitor
# SM_monitor_a_stand
# SM_AVP1_Power_02
# SM_Monitor
# SM_printer_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Power_02
# SM_AVP1_Motion_01
# SM_AVP1_Power_01
# SM_keyboard_c
# SM_AVP1_Motion_01
# SM_Chair
# SM_speaker_a_SM_speaker_a
# SM_Stairs
# SM_telephone_a
# SM_AVP1_Power_03
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_AVP1_Power_02
# SM_AVP1_Switch_03
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_01
# SM_AVP1_Hook_01
# SM_DoorFrame
# SM_monitor_a_screen
# SM_DeskTray
# SM_VisitorChair
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Switch_03
# SM_keyboard_a
# SM_monitor_b_screen
# SM_keyboard_c
# SM_AVP1_SmokeDetector_02
# SM_Vase2
# SM_AVP1_Switch_03
# SM_AVP1_Coax_01
# SM_AVP1_Plate_01
# SM_AVP1_Switch_04
# SM_laptop_a
# SM_AVP1_Switch_01
# SM_AVP1_Intercom_01
# SM_monitor_b_screen
# SM_Shelf
# SM_computer_b
# SM_AVP1_Slider_01
# SM_Window
# SM_AVP1_Network_01
# SM_mouse_a
# SM_AVP1_Rocker_01
# SM_AVP1_Vent_02
# SM_printer_big_a
# SM_AVP1_Intercom_01
# SM_Stairs
# SM_AVP1_Motion_01
# SM_Laptop
# SM_AVP1_Power_03
# SM_DeskLamp
# SM_AVP1_Power_06
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_laptop_a_closed
# SM_AVP1_Light_01
# SM_TableRound
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_mouse_a
# SM_AVP1_Rocker_02
# SM_Vase1
# SM_AVP1_Power_06
# SM_AVP1_Plate_01
# SM_headphones_a
# SM_Keyboard
# SM_AVP1_Hook_01
# SM_VisitorChair
# SM_Door
# SM_AVP1_Switch_04
# SM_mouse_a
# SM_mouse_b
# SM_AVP1_Switch_04
# SM_AVP1_Thermo_02
# SM_AVP1_Power_06
# SM_Shelf
# SM_AVP1_SmokeDetector_01
# SM_keyboard_a
# SM_AVP1_Light_01
# SM_AVP1_Network_01
# SM_DeskLamp
# SM_tv_a_wall
# SM_TableRound
# SM_Chair
# SM_Mousepad
# SM_DoorFrame
# SM_speaker_b
# SM_tv_a_wall
# SM_Mouse
# SM_AVP1_Thermo_02
# SM_AVP1_Rocker_02
# SM_AVP1_Power_04
# SM_Door
# SM_AVP1_Power_06
# SM_AVP1_Dimmer_01
# SM_keyboard_b
# SM_Couch
# SM_AVP1_SmokeDetector_01
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_DoorFrame
# SM_headphones_a
# SM_scaner_a
# SM_Laptop
# SM_AVP1_Switch_04
# SM_Shelf
# SM_printer_a
# SM_scaner_a
# SM_DeskTray
# SM_AVP1_Power_01
# SM_tv_a_wall
# SM_Mouse
# SM_Laptop
# SM_AVP1_Power_06
# SM_monitor_b_stand
# SM_paper_sherdder_a
# SM_Monitor
# SM_AVP1_Network_01
# SM_Mousepad
# SM_monitor_a_stand
# SM_AVP1_Switch_02
# SM_mouse_c
# SM_Laptop
# SM_scaner_a
# SM_printer_a
# SM_headphones_a
# SM_AVP1_Multimedia_01
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_stand
# SM_monitor_b
# SM_PencilPot
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_VisitorChair
# SM_monitor_b_stand
# SM_AVP1_Multimedia_01
# SM_printer_a
# SM_AVP1_Dimmer_01
# SM_scaner_a
# SM_ExecutiveDesk
# SM_AVP1_Coax_01
# SM_printer_a
# SM_DeskLamp
# SM_laptop_a
# SM_monitor_a
# SM_monitor_a_stand
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_ExecutiveDesk
# SM_AVP1_Multimedia_01
# SM_Couch
# SM_monitor_b_screen
# SM_Mousepad
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_monitor_c
# SM_Chair
# SM_Chair
# SM_VisitorChair
# SM_AVP1_Thermo_01
# SM_monitor_a
# SM_laptop_a_closed
# SM_Chair
# SM_monitor_a
# SM_Door
# SM_Keyboard
# SM_AVP1_Slider_01
# SM_monitor_a
# SM_mouse_a
# SM_AVP1_Motion_01
# SM_TableRound
# SM_AVP1_Multimedia_01
# SM_Monitor
# SM_DoorFrame
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Motion_01
# SM_Stairs
# SM_Couch
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_AVP1_Rocker_02
# SM_mouse_c
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_02
# SM_Door
# SM_headphones_a
# SM_tv_a
# SM_AVP1_Keypad_01
# SM_computer_b
# SM_monitor_c
# SM_Door
# SM_DeskLamp
# SM_AVP1_Switch_01
# SM_Cabinet
# SM_AVP1_Thermo_02
# SM_computer_a
# SM_computer_b
# SM_AVP1_Slider_01
# SM_AVP1_Dimmer_01
# SM_laptop_a_closed
# SM_AVP1_Coax_01
# SM_speaker_b
# SM_AVP1_Switch_03
# SM_AVP1_Switch_01
# SM_mouse_c
# SM_projector_a
# SM_AVP1_Plate_01
# SM_keyboard_b
# SM_AVP1_Switch_01
# SM_laptop_a
# SM_keyboard_b
# SM_Vase2
# SM_AVP1_Thermo_01
# SM_Laptop
# SM_Monitor
# SM_AVP1_Vent_01
# SM_computer_c
# SM_Vase1
# SM_computer_a
# SM_AVP1_Power_06
# SM_monitor_b_screen
# SM_AVP1_Slider_01
# SM_monitor_b_screen
# SM_monitor_b
# SM_printer_a
# SM_monitor_d
# SM_VisitorChair
# SM_Stairs
# SM_computer_b
# SM_Shelf
# SM_monitor_c
# SM_AVP1_Network_01
# SM_Chair
# SM_Vase
# SM_DoorFrame
# SM_DoorFrame
# SM_Monitor
# SM_TableRound
# SM_Door
# SM_Monitor
# SM_Window
# ...
# SM_laptop_a :
# SM_TableRound :
# SM_AVP1_Switch_02 :
# SM_DeskTray :
# SM_computer_c :
# SM_AVP1_Switch_04 :
# SM_Monitor :
# SM_VisitorChair :
# SM_AVP1_Slider_01 :
# SM_Door :
# SM_AVP1_Power_06 :
# SM_Shelf :
# SM_speaker_b :
# SM_monitor_a_stand :
# SM_tv_a :
# SM_Door :
# SM_AVP1_Keypad_01 :
# SM_DeskTray :
# SM_Monitor :
# SM_monitor_c :
# SM_monitor_d :
# SM_mouse_b :
# SM_monitor_d :
# SM_printer_a :
# SM_AVP1_Network_01 :
# SM_AVP1_Multimedia_01 :
# SM_scaner_a_open :
# SM_Mousepad :
# SM_AVP1_Switch_02 :
# SM_Cabinet :
# SM_AVP1_Power_02 :
# SM_AVP1_Thermo_02 :
# SM_keyboard_c :
# SM_computer_b :
# SM_Mouse :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Thermo_01 :
# SM_Stairs :
# SM_laptop_a :
# SM_headphones_a :
# SM_Keyboard :
# SM_Mousepad :
# SM_monitor_a :
# SM_keyboard_b :
# SM_AVP1_Keypad_01 :
# SM_Mouse :
# SM_Couch :
# SM_AVP1_Switch_01 :
# SM_monitor_b :
# SM_Window :
# SM_headphones_a :
# SM_AVP1_Switch_02 :
# SM_laptop_a_closed :
# SM_DeskTray :
# SM_Cabinet :
# SM_AVP1_SmokeDetector_02 :
# SM_AVP1_Network_01 :
# SM_AVP1_Slider_01 :
# SM_monitor_b :
# SM_paper_sherdder_a :
# SM_monitor_b_stand :
# SM_mouse_a :
# SM_AVP1_Switch_04 :
# SM_AVP1_Dimmer_01 :
# SM_Chair :
# SM_paper_sherdder_a :
# SM_VisitorChair :
# SM_AVP1_Hook_01 :
# SM_paper_sherdder_a :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Power_02 :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_Plate_01 :
# SM_scaner_a :
# SM_ExecutiveChair :
# SM_Mousepad :
# SM_monitor_a_stand :
# SM_scaner_a_open :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_Switch_01 :
# SM_AVP1_Vent_02 :
# SM_Cabinet :
# SM_printer_big_a :
# SM_AVP1_Coax_01 :
# SM_AVP1_SmokeDetector_01 :
# SM_Door :
# SM_TableRound :
# SM_projector_a :
# SM_monitor_a_stand :
# SM_monitor_a_screen :
# SM_AVP1_Vent_02 :
# SM_AVP1_Vent_02 :
# SM_PencilPot :
# SM_AVP1_Thermo_02 :
# SM_AVP1_Power_02 :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_Thermo_01 :
# SM_mouse_c :
# SM_AVP1_Sprinkler_01 :
# SM_monitor_c :
# SM_monitor_b_stand :
# SM_AVP1_Thermo_02 :
# SM_monitor_a_screen :
# SM_laptop_a :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_Switch_02 :
# SM_speaker_a_SM_speaker_a :
# SM_AVP1_Thermo_01 :
# SM_monitor_a :
# SM_scaner_a_open :
# SM_AVP1_Switch_03 :
# SM_speaker_b :
# SM_AVP1_Power_01 :
# SM_monitor_b :
# SM_mouse_c :
# SM_AVP1_Multimedia_01 :
# SM_monitor_c :
# SM_PencilPot :
# SM_keyboard_b :
# SM_AVP1_Power_04 :
# SM_computer_a :
# SM_monitor_a_screen :
# SM_projector_a :
# SM_keyboard_c :
# SM_computer_a :
# SM_AVP1_Power_05 :
# SM_laptop_a_closed :
# SM_Chair :
# SM_ExecutiveDesk :
# SM_DoorFrame :
# SM_ExecutiveChair :
# SM_mouse_c :
# SM_printer_a :
# SM_keyboard_a :
# SM_AVP1_Coax_01 :
# SM_DeskTray :
# SM_AVP1_Network_01 :
# SM_AVP1_Motion_01 :
# SM_tv_a :
# SM_monitor_a :
# SM_AVP1_Switch_02 :
# SM_monitor_b_screen :
# SM_AVP1_Power_06 :
# SM_Stairs :
# SM_AVP1_Plate_01 :
# SM_AVP1_Vent_01 :
# SM_Couch :
# SM_Chair :
# SM_monitor_a_stand :
# SM_printer_big_a :
# SM_monitor_b_stand :
# SM_tv_a_wall :
# SM_speaker_b :
# SM_keyboard_c :
# SM_monitor_b_stand :
# SM_Vase :
# SM_AVP1_Power_01 :
# SM_ExecutiveDesk :
# SM_AVP1_Hook_01 :
# SM_speaker_b :
# SM_AVP1_Vent_01 :
# SM_monitor_d :
# SM_VisitorChair :
# SM_monitor_a_stand :
# SM_AVP1_Vent_02 :
# SM_AVP1_Network_01 :
# SM_Laptop :
# SM_AVP1_Vent_02 :
# SM_Mouse :
# SM_AVP1_Motion_01 :
# SM_Vase1 :
# SM_scaner_a :
# SM_computer_b :
# SM_mouse_c :
# SM_monitor_d :
# SM_laptop_a_closed :
# SM_speaker_b :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Power_01 :
# SM_mouse_c :
# SM_AVP1_Power_03 :
# SM_mouse_a :
# SM_monitor_b_screen :
# SM_Door :
# SM_Vase :
# SM_Chair :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Intercom_01 :
# SM_monitor_c :
# SM_AVP1_Power_01 :
# SM_AVP1_Vent_02 :
# SM_DoorFrame :
# SM_AVP1_Power_06 :
# SM_monitor_c :
# SM_Vase :
# SM_AVP1_Dimmer_01 :
# SM_AVP1_Rocker_02 :
# SM_AVP1_Rocker_02 :
# SM_Laptop :
# SM_keyboard_a :
# SM_monitor_a :
# SM_AVP1_Dimmer_01 :
# SM_telephone_a :
# SM_AVP1_Network_01 :
# SM_AVP1_Vent_02 :
# SM_Monitor :
# SM_ExecutiveChair :
# SM_AVP1_Switch_01 :
# SM_Globe :
# SM_Globe :
# SM_projector_a :
# SM_Mousepad :
# SM_computer_c :
# SM_scaner_a :
# SM_laptop_a_closed :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Power_06 :
# SM_AVP1_Switch_01 :
# SM_Chair :
# SM_AVP1_Intercom_01 :
# SM_Stairs :
# SM_keyboard_a :
# SM_tv_a :
# SM_monitor_a :
# SM_AVP1_Switch_01 :
# SM_AVP1_Thermo_02 :
# SM_AVP1_Power_03 :
# SM_monitor_b_screen :
# SM_AVP1_Thermo_02 :
# SM_telephone_a :
# SM_AVP1_Light_01 :
# SM_Vase :
# SM_VisitorChair :
# SM_monitor_b_stand :
# SM_AVP1_Vent_01 :
# SM_mouse_b :
# SM_AVP1_Rocker_02 :
# SM_AVP1_Thermo_02 :
# SM_monitor_a_stand :
# SM_ExecutiveDesk :
# SM_Mousepad :
# SM_laptop_a_closed :
# SM_mouse_b :
# SM_AVP1_Hook_01 :
# SM_Vase1 :
# SM_AVP1_Power_02 :
# SM_computer_a :
# SM_TableRound :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Thermo_01 :
# SM_paper_sherdder_a :
# SM_DoorFrame :
# SM_AVP1_Vent_01 :
# SM_AVP1_Sprinkler_01 :
# SM_headphones_a :
# SM_DeskTray :
# SM_keyboard_a :
# SM_monitor_a_stand :
# SM_AVP1_Hook_01 :
# SM_AVP1_Power_04 :
# SM_DeskTray :
# SM_monitor_a :
# SM_keyboard_a :
# SM_AVP1_Thermo_01 :
# SM_telephone_a :
# SM_Vase1 :
# SM_AVP1_Vent_02 :
# SM_AVP1_Thermo_02 :
# SM_computer_b :
# SM_AVP1_Switch_01 :
# SM_AVP1_Sprinkler_01 :
# SM_computer_a :
# SM_AVP1_SmokeDetector_02 :
# SM_Stairs :
# SM_monitor_a_stand :
# SM_VisitorChair :
# SM_AVP1_Thermo_02 :
# SM_keyboard_b :
# SM_Chair :
# SM_Cabinet :
# SM_Globe :
# SM_monitor_b_stand :
# SM_Mouse :
# SM_AVP1_Power_05 :
# SM_Monitor :
# SM_tv_a_wall :
# SM_TableRound :
# SM_Window :
# SM_paper_sherdder_a :
# SM_printer_big_a :
# SM_Vase1 :
# SM_projector_a :
# SM_DeskLamp :
# SM_Monitor :
# SM_Door :
# SM_DoorFrame :
# SM_mouse_c :
# SM_monitor_b_stand :
# SM_Cabinet :
# SM_AVP1_Power_03 :
# SM_AVP1_Power_02 :
# SM_AVP1_Vent_02 :
# SM_speaker_a_SM_speaker_a :
# SM_AVP1_Network_01 :
# SM_printer_a :
# SM_monitor_d :
# SM_monitor_a_screen :
# SM_Mousepad :
# SM_Laptop :
# SM_AVP1_SmokeDetector_01 :
# SM_Stairs :
# SM_speaker_a_SM_speaker_a :
# SM_mouse_a :
# SM_scaner_a_open :
# SM_AVP1_Vent_02 :
# SM_AVP1_SmokeDetector_01 :
# SM_Monitor :
# SM_monitor_d :
# SM_TableRound :
# SM_keyboard_c :
# SM_AVP1_SmokeDetector_02 :
# SM_monitor_b :
# SM_Vase1 :
# SM_Monitor :
# SM_computer_a :
# SM_ExecutiveDesk :
# SM_monitor_c :
# SM_AVP1_Slider_01 :
# SM_AVP1_Thermo_01 :
# SM_keyboard_b :
# SM_AVP1_Network_01 :
# SM_AVP1_Power_02 :
# SM_monitor_a :
# SM_AVP1_Rocker_02 :
# SM_DeskTray :
# SM_headphones_a :
# SM_AVP1_Power_03 :
# SM_AVP1_Sprinkler_01 :
# SM_computer_a :
# SM_monitor_b_screen :
# SM_Shelf :
# SM_speaker_a_SM_speaker_a :
# SM_Keyboard :
# SM_AVP1_Vent_01 :
# SM_AVP1_Keypad_01 :
# SM_laptop_a :
# SM_mouse_a :
# SM_computer_c :
# SM_printer_a :
# SM_DeskTray :
# SM_AVP1_Switch_04 :
# SM_AVP1_Vent_02 :
# SM_AVP1_Rocker_02 :
# SM_Vase :
# SM_mouse_c :
# SM_tv_a :
# SM_AVP1_Motion_01 :
# SM_AVP1_Thermo_02 :
# SM_Mousepad :
# SM_Shelf :
# SM_mouse_a :
# SM_Cabinet :
# SM_AVP1_Light_01 :
# SM_monitor_a :
# SM_AVP1_Power_03 :
# SM_Chair :
# SM_telephone_a :
# SM_paper_sherdder_a :
# SM_AVP1_Plate_01 :
# SM_AVP1_Plate_01 :
# SM_Door :
# SM_AVP1_Rocker_01 :
# SM_monitor_b_stand :
# SM_projector_a :
# SM_AVP1_Coax_01 :
# SM_AVP1_Keypad_01 :
# SM_laptop_a_closed :
# SM_tv_a_wall :
# SM_monitor_c :
# SM_laptop_a_closed :
# SM_AVP1_SmokeDetector_01 :
# SM_scaner_a :
# SM_speaker_a_SM_speaker_a :
# SM_projector_a :
# SM_AVP1_Hook_01 :
# SM_ExecutiveChair :
# SM_Globe :
# SM_Chair :
# SM_speaker_a_SM_speaker_a :
# SM_AVP1_Sprinkler_01 :
# SM_monitor_c :
# SM_AVP1_Slider_01 :
# SM_tv_a_wall :
# SM_monitor_a_screen :
# SM_AVP1_Dimmer_01 :
# SM_monitor_b_stand :
# SM_ExecutiveChair :
# SM_AVP1_Coax_01 :
# SM_AVP1_Slider_01 :
# SM_AVP1_Slider_01 :
# SM_monitor_d :
# SM_AVP1_Dimmer_01 :
# SM_Window :
# SM_AVP1_Light_01 :
# SM_AVP1_Rocker_01 :
# SM_DoorFrame :
# SM_AVP1_Switch_03 :
# SM_AVP1_Intercom_01 :
# SM_Chair :
# SM_AVP1_Motion_01 :
# SM_AVP1_Switch_01 :
# SM_laptop_a :
# SM_DoorFrame :
# SM_ExecutiveChair :
# SM_PencilPot :
# SM_AVP1_Plate_01 :
# SM_TableRound :
# SM_mouse_b :
# SM_AVP1_Power_04 :
# SM_AVP1_SmokeDetector_01 :
# SM_TableRound :
# SM_scaner_a :
# SM_Vase :
# SM_AVP1_Power_03 :
# SM_AVP1_Power_03 :
# SM_Chair :
# SM_computer_c :
# SM_DeskTray :
# SM_Globe :
# SM_Keyboard :
# SM_Keyboard :
# SM_Globe :
# SM_AVP1_Power_02 :
# SM_keyboard_a :
# SM_monitor_a_stand :
# SM_AVP1_Switch_03 :
# SM_Globe :
# SM_laptop_a_closed :
# SM_monitor_a :
# SM_AVP1_Power_02 :
# SM_AVP1_Vent_02 :
# SM_Vase2 :
# SM_VisitorChair :
# SM_AVP1_Slider_01 :
# SM_Mouse :
# SM_DoorFrame :
# SM_mouse_c :
# SM_headphones_a :
# SM_monitor_a_screen :
# SM_laptop_a :
# SM_Keyboard :
# SM_AVP1_Hook_01 :
# SM_Couch :
# SM_monitor_d :
# SM_AVP1_Power_01 :
# SM_monitor_a :
# SM_DeskLamp :
# SM_tv_a :
# SM_printer_big_a :
# SM_AVP1_SmokeDetector_01 :
# SM_Laptop :
# SM_AVP1_Plate_01 :
# SM_AVP1_Keypad_01 :
# SM_AVP1_Thermo_01 :
# SM_mouse_b :
# SM_paper_sherdder_a :
# SM_monitor_b :
# SM_scaner_a_open :
# SM_printer_a :
# SM_laptop_a :
# SM_Stairs :
# SM_AVP1_SmokeDetector_01 :
# SM_monitor_a_screen :
# SM_Keyboard :
# SM_mouse_a :
# SM_mouse_a :
# SM_Globe :
# SM_telephone_a :
# SM_mouse_b :
# SM_Couch :
# SM_monitor_b_stand :
# SM_DeskTray :
# SM_AVP1_Power_01 :
# SM_monitor_d :
# SM_Monitor :
# SM_projector_a :
# SM_AVP1_Network_01 :
# SM_AVP1_Network_01 :
# SM_Couch :
# SM_AVP1_Slider_01 :
# SM_speaker_b :
# SM_Globe :
# SM_Vase1 :
# SM_AVP1_Power_01 :
# SM_DeskLamp :
# SM_AVP1_Intercom_01 :
# SM_AVP1_Switch_03 :
# SM_monitor_a :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Switch_03 :
# SM_AVP1_Switch_03 :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Intercom_01 :
# SM_AVP1_Vent_02 :
# SM_Monitor :
# SM_AVP1_Hook_01 :
# SM_Chair :
# SM_scaner_a_open :
# SM_AVP1_Power_05 :
# SM_AVP1_Thermo_02 :
# SM_AVP1_Light_01 :
# SM_mouse_c :
# SM_AVP1_Slider_01 :
# SM_laptop_a_closed :
# SM_ExecutiveDesk :
# SM_AVP1_Motion_01 :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_SmokeDetector_02 :
# SM_Monitor :
# SM_AVP1_Light_01 :
# SM_TableRound :
# SM_Vase :
# SM_monitor_b :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_Power_04 :
# SM_mouse_a :
# SM_Globe :
# SM_AVP1_Rocker_02 :
# SM_monitor_d :
# SM_monitor_a_stand :
# SM_AVP1_Power_02 :
# SM_headphones_a :
# SM_Globe :
# SM_AVP1_Coax_01 :
# SM_computer_a :
# SM_VisitorChair :
# SM_AVP1_Switch_03 :
# SM_tv_a_wall :
# SM_tv_a_wall :
# SM_AVP1_Power_01 :
# SM_AVP1_Thermo_02 :
# SM_Monitor :
# SM_printer_big_a :
# SM_TableRound :
# SM_Laptop :
# SM_PencilPot :
# SM_ExecutiveChair :
# SM_Mousepad :
# SM_AVP1_SmokeDetector_02 :
# SM_monitor_b_screen :
# SM_paper_sherdder_a :
# SM_computer_b :
# SM_mouse_c :
# SM_AVP1_Multimedia_01 :
# SM_scaner_a_open :
# SM_monitor_a_screen :
# SM_keyboard_c :
# SM_monitor_a_screen :
# SM_tv_a_wall :
# SM_mouse_c :
# SM_ExecutiveDesk :
# SM_Window :
# SM_DoorFrame :
# SM_scaner_a_open :
# SM_computer_b :
# SM_AVP1_SmokeDetector_01 :
# SM_monitor_d :
# SM_printer_big_a :
# SM_AVP1_Power_06 :
# SM_AVP1_Dimmer_01 :
# SM_Couch :
# SM_keyboard_c :
# SM_AVP1_Coax_01 :
# SM_AVP1_Power_05 :
# SM_AVP1_Power_04 :
# SM_monitor_b_stand :
# SM_AVP1_Switch_02 :
# SM_keyboard_c :
# SM_mouse_c :
# SM_computer_b :
# SM_printer_big_a :
# SM_AVP1_Switch_04 :
# SM_computer_a :
# SM_AVP1_Thermo_01 :
# SM_ExecutiveChair :
# SM_AVP1_Power_02 :
# SM_speaker_a_SM_speaker_a :
# SM_laptop_a :
# SM_mouse_a :
# SM_AVP1_Slider_01 :
# SM_monitor_a :
# SM_AVP1_Switch_02 :
# SM_Window :
# SM_AVP1_Power_03 :
# SM_monitor_d :
# SM_monitor_c :
# SM_AVP1_Switch_03 :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Slider_01 :
# SM_keyboard_b :
# SM_laptop_a :
# SM_headphones_a :
# SM_AVP1_Power_06 :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Slider_01 :
# SM_ExecutiveDesk :
# SM_AVP1_Sprinkler_01 :
# SM_DeskLamp :
# SM_Vase :
# SM_DeskTray :
# SM_Chair :
# SM_AVP1_Vent_02 :
# SM_tv_a :
# SM_AVP1_Vent_02 :
# SM_computer_c :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Vent_01 :
# SM_monitor_b_screen :
# SM_PencilPot :
# SM_computer_a :
# SM_DoorFrame :
# SM_printer_a :
# SM_monitor_b_stand :
# SM_keyboard_a :
# SM_AVP1_Vent_01 :
# SM_AVP1_Multimedia_01 :
# SM_Chair :
# SM_DeskTray :
# SM_AVP1_Power_06 :
# SM_AVP1_Vent_01 :
# SM_AVP1_Rocker_01 :
# SM_Chair :
# SM_AVP1_Switch_02 :
# SM_Shelf :
# SM_scaner_a :
# SM_Monitor :
# SM_AVP1_Rocker_02 :
# SM_AVP1_Rocker_01 :
# SM_DoorFrame :
# SM_projector_a :
# SM_AVP1_Dimmer_01 :
# SM_monitor_b_screen :
# SM_AVP1_Power_04 :
# SM_AVP1_Keypad_01 :
# SM_AVP1_SmokeDetector_02 :
# SM_AVP1_Keypad_01 :
# SM_printer_big_a :
# SM_Laptop :
# SM_AVP1_Intercom_01 :
# SM_mouse_c :
# SM_telephone_a :
# SM_monitor_c :
# SM_AVP1_Power_01 :
# SM_AVP1_SmokeDetector_01 :
# SM_computer_a :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_Power_04 :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Plate_01 :
# SM_Vase1 :
# SM_computer_a :
# SM_laptop_a_closed :
# SM_Globe :
# SM_monitor_b_stand :
# SM_AVP1_Switch_01 :
# SM_AVP1_Plate_01 :
# SM_laptop_a :
# SM_scaner_a :
# SM_keyboard_a :
# SM_headphones_a :
# SM_AVP1_Motion_01 :
# SM_laptop_a :
# SM_monitor_a_screen :
# SM_projector_a :
# SM_scaner_a :
# SM_AVP1_Dimmer_01 :
# SM_AVP1_Power_01 :
# SM_AVP1_Switch_03 :
# SM_AVP1_Vent_02 :
# SM_Vase :
# SM_AVP1_Intercom_01 :
# SM_Door :
# SM_AVP1_Sprinkler_01 :
# SM_paper_sherdder_a :
# SM_ExecutiveChair :
# SM_AVP1_Switch_01 :
# SM_Couch :
# SM_TableRound :
# SM_monitor_a_stand :
# SM_AVP1_Motion_01 :
# SM_monitor_d :
# SM_monitor_b :
# SM_Keyboard :
# SM_speaker_b :
# SM_AVP1_Switch_03 :
# SM_Monitor :
# SM_computer_b :
# SM_AVP1_Power_05 :
# SM_AVP1_Power_02 :
# SM_monitor_a_stand :
# SM_ExecutiveDesk :
# SM_AVP1_SmokeDetector_01 :
# SM_AVP1_SmokeDetector_01 :
# SM_computer_a :
# SM_Chair :
# SM_ExecutiveChair :
# SM_Keyboard :
# SM_Keyboard :
# SM_Vase1 :
# SM_monitor_a_stand :
# SM_Stairs :
# SM_Window :
# SM_monitor_a_stand :
# SM_tv_a :
# SM_tv_a :
# SM_AVP1_Vent_01 :
# SM_AVP1_Hook_01 :
# SM_Monitor :
# SM_tv_a :
# SM_keyboard_c :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_Power_03 :
# SM_AVP1_Vent_02 :
# SM_monitor_b_screen :
# SM_monitor_a_screen :
# SM_AVP1_Vent_02 :
# SM_monitor_d :
# SM_Vase1 :
# SM_monitor_a :
# SM_AVP1_Switch_03 :
# SM_PencilPot :
# SM_AVP1_Thermo_01 :
# SM_AVP1_Network_01 :
# SM_AVP1_Switch_04 :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_Plate_01 :
# SM_monitor_a :
# SM_laptop_a :
# SM_AVP1_Coax_01 :
# SM_Monitor :
# SM_mouse_b :
# SM_ExecutiveDesk :
# SM_DeskLamp :
# SM_computer_c :
# SM_Chair :
# SM_AVP1_Switch_04 :
# SM_AVP1_Switch_03 :
# SM_speaker_b :
# SM_AVP1_Intercom_01 :
# SM_AVP1_Switch_04 :
# SM_AVP1_Coax_01 :
# SM_AVP1_SmokeDetector_02 :
# SM_monitor_b_stand :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_Slider_01 :
# SM_laptop_a_closed :
# SM_computer_a :
# SM_AVP1_Power_01 :
# SM_paper_sherdder_a :
# SM_DeskTray :
# SM_Vase :
# SM_mouse_a :
# SM_DeskLamp :
# SM_Shelf :
# SM_headphones_a :
# SM_Monitor :
# SM_AVP1_Network_01 :
# SM_AVP1_Hook_01 :
# SM_Cabinet :
# SM_keyboard_c :
# SM_AVP1_Power_01 :
# SM_printer_a :
# SM_monitor_b :
# SM_AVP1_SmokeDetector_02 :
# SM_laptop_a :
# SM_keyboard_b :
# SM_Globe :
# SM_computer_c :
# SM_ExecutiveChair :
# SM_DoorFrame :
# SM_computer_c :
# SM_AVP1_Thermo_02 :
# SM_AVP1_Network_01 :
# SM_Vase2 :
# SM_Couch :
# SM_Vase1 :
# SM_AVP1_Switch_01 :
# SM_monitor_b :
# SM_monitor_a_stand :
# SM_Chair :
# SM_AVP1_Plate_01 :
# SM_speaker_b :
# SM_tv_a_wall :
# SM_Globe :
# SM_Monitor :
# SM_laptop_a :
# SM_Laptop :
# SM_monitor_c :
# SM_ExecutiveDesk :
# SM_AVP1_Dimmer_01 :
# SM_Vase2 :
# SM_ExecutiveDesk :
# SM_Couch :
# SM_Vase2 :
# SM_printer_a :
# SM_computer_a :
# SM_VisitorChair :
# SM_AVP1_Multimedia_01 :
# SM_AVP1_SmokeDetector_02 :
# SM_keyboard_a :
# SM_Chair :
# SM_tv_a :
# SM_AVP1_Multimedia_01 :
# SM_monitor_a_stand :
# SM_Laptop :
# SM_DoorFrame :
# SM_computer_b :
# SM_AVP1_Switch_04 :
# SM_DeskTray :
# SM_Mouse :
# SM_projector_a :
# SM_computer_a :
# SM_Vase1 :
# SM_AVP1_Power_04 :
# SM_laptop_a_closed :
# SM_AVP1_Sprinkler_01 :
# SM_AVP1_Power_02 :
# SM_projector_a :
# SM_laptop_a :
# SM_headphones_a :
# SM_AVP1_Power_06 :
# SM_monitor_a_screen :
# SM_printer_a :
# SM_keyboard_a :
# SM_AVP1_Slider_01 :
# SM_mouse_b :
# SM_telephone_a :
# SM_computer_c :
# SM_AVP1_Switch_03 :
# SM_Monitor :
# SM_Shelf :
# SM_AVP1_Network_01 :
# SM_Mousepad :
# SM_tv_a_wall :
# SM_scaner_a :
# SM_mouse_c :
# SM_AVP1_Coax_01 :
# SM_AVP1_Hook_01 :
# SM_keyboard_b :
# SM_headphones_a :
# SM_Shelf :
# SM_Window :
# SM_DoorFrame :
# SM_computer_b :
# SM_AVP1_Keypad_01 :
# SM_Vase :
# SM_speaker_b :
# SM_AVP1_Power_05 :
# SM_TableRound :
# SM_Vase1 :
# SM_Cabinet :
# SM_ExecutiveDesk :
# SM_tv_a :
# SM_AVP1_Power_01 :
# SM_Mouse :
# SM_AVP1_Plate_01 :
# SM_laptop_a :
# SM_laptop_a :
# SM_keyboard_c :
# SM_AVP1_Switch_03 :
# SM_printer_a :
# SM_AVP1_Coax_01 :
# SM_printer_big_a :
# SM_AVP1_Vent_02 :
# SM_AVP1_Keypad_01 :
# SM_keyboard_b :
# SM_AVP1_Motion_01 :
# SM_mouse_c :
# SM_scaner_a_open :
# SM_TableRound :
# SM_AVP1_Switch_02 :
# SM_AVP1_Rocker_02 :
# SM_Vase2 :
# SM_monitor_a :
# SM_AVP1_Switch_02 :
# SM_laptop_a :
# SM_Shelf :
# SM_tv_a_wall :
# SM_Laptop :
# SM_Chair :
# SM_keyboard_a :
# SM_Globe :
# SM_AVP1_Motion_01 :
# SM_speaker_a_SM_speaker_a :
# SM_projector_a :
# SM_AVP1_Vent_01 :
# SM_TableRound :
# SM_scaner_a :
# SM_AVP1_Network_01 :
# SM_Stairs :
# SM_AVP1_Rocker_02 :
# SM_PencilPot :
# SM_monitor_a_screen :
# SM_AVP1_Sprinkler_01 :
# SM_TableRound :
# SM_AVP1_Light_01 :
# SM_Shelf :
# SM_AVP1_Vent_01 :
# SM_monitor_d :
# SM_Monitor :
# SM_speaker_b :
# SM_AVP1_Intercom_01 :
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
objectmappingslist = open("objectmapping.txt", "r")
lines = objectmappingslist.readlines()

#We use a hash to ensure we can override mappings on multiple runs
# for instance, there is a new mapping per "play button press"

objectmappings = {}
for line in lines:
    splitsy = line.split(" ")
    objectmappings[splitsy[0]] = splitsy[1].strip()

objectmappingslist.close()

#This now holds the mapping from scene object to item class.
#The sim is able to pull which items are visible but its based on 
#scene object - which makes this mapping necessary.
print(objectmappings)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-043d0133e843> in <module>
#       8 for line in lines:
#       9     splitsy = line.split(" ")
# ---> 10     objectmappings[splitsy[0]] = splitsy[1].strip()
#      11
#      12 objectmappingslist.close()
#
# IndexError: list index out of range

# %%
cd PythonClient/computer_vision
# Out:
# /home/mamacker/aisum/AirSim/PythonClient/computer_vision

# %%
#This will generate many, many images.
#python manycapture.py

# %%
#Pull segmentation color values from:
#https://microsoft.github.io/AirSim/seg_rgbs.txt

# %%
pip install airsim tornado==4.5.3
# Out:
# Requirement already satisfied: airsim in /home/mamacker/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: tornado==4.5.3 in /home/mamacker/.local/lib/python3.8/site-packages (4.5.3)
# Requirement already satisfied: msgpack-rpc-python in /home/mamacker/.local/lib/python3.8/site-packages (from airsim) (0.4.1)
# Requirement already satisfied: opencv-contrib-python in /home/mamacker/.local/lib/python3.8/site-packages (from airsim) (4.5.1.48)
# Requirement already satisfied: numpy in /home/mamacker/.local/lib/python3.8/site-packages (from airsim) (1.20.2)
# Requirement already satisfied: msgpack-python in /home/mamacker/.local/lib/python3.8/site-packages (from msgpack-rpc-python->airsim) (0.5.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import airsim
import setup_path

import pprint
import os
import time
import math
import tempfile
import random

# %%
pp = pprint.PrettyPrinter(indent=4)

client = airsim.VehicleClient()
client.confirmConnection()
client.simSetVehiclePose(airsim.Pose(airsim.Vector3r(0,0,0), airsim.to_quaternion(0, 0,0)), True)
# Out:
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)

# %%
#mrclient = airsim.MultirotorClient()
#mrclient.confirmConnection()
#mrclient.enableApiControl(True)

# %%
client.simSetVehiclePose(airsim.Pose(airsim.Vector3r(0, 0, 0), airsim.to_quaternion(0, 0, 0)), True)
#mrclient.client.call_async("armDisarm",True)

# %%
#mrclient.takeoffAsync()
#mrclient.moveToPositionAsync(0, 0, 0, 5)

# %%
#get camera parameters
for camera_name in range(5):
    camera_info = client.simGetCameraInfo(str(camera_name))
    print("CameraInfo %d:" % camera_name)
    pp.pprint(camera_info)

# %%
tmp_dir = "image_capture"
print ("Saving images to %s" % tmp_dir)
try:
    os.makedirs(tmp_dir)
except OSError:
    if not os.path.isdir(tmp_dir):
        raise

# %%
# Run through each object type and make sure they ALL have the appropriate segmentation ID
#'SM_Laptop' : 23

###########################FIXME
print("Checking object mappings...")
objecttypes = {}
#Consolidate and count keys.
for key in objectmappings:
    print(objectmappings[key])
    value = objectmappings[key]
    if value not in objecttypes:
        objecttypes[value] = 0
        
    objecttypes[value] = objecttypes[value] + 1
    
all_keys = list(objecttypes.keys())
print("Types of objects found:" + str(len(all_keys)))
# Out:
# Checking object mappings...
# SM_monitor_b
# SM_tv_a_wall
# SM_VisitorChair
# SM_AVP1_Power_05
# SM_AVP1_SmokeDetector_02
# SM_projector_a
# SM_AVP1_Power_06
# SM_Door
# SM_computer_a
# SM_AVP1_Keypad_01
# SM_Mousepad
# SM_AVP1_Switch_01
# SM_tv_a_wall
# SM_laptop_a
# SM_tv_a_wall
# SM_AVP1_Hook_01
# SM_mouse_b
# SM_AVP1_Vent_01
# SM_keyboard_b
# SM_ExecutiveChair
# SM_computer_c
# SM_AVP1_Power_04
# SM_AVP1_Power_06
# SM_AVP1_Network_01
# SM_tv_a
# SM_AVP1_Coax_01
# SM_AVP1_Power_03
# SM_DoorFrame
# SM_DeskTray
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_AVP1_Plate_01
# SM_monitor_c
# SM_AVP1_Power_03
# SM_Chair
# SM_Vase2
# SM_Vase1
# SM_Vase2
# SM_AVP1_Slider_01
# SM_tv_a
# SM_Window
# SM_AVP1_SmokeDetector_02
# SM_monitor_b
# SM_Vase
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_TableRound
# SM_Door
# SM_monitor_a
# SM_Couch
# SM_monitor_c
# SM_AVP1_Plate_01
# SM_TableRound
# SM_keyboard_a
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_computer_c
# SM_monitor_c
# SM_AVP1_Intercom_01
# SM_AVP1_Power_06
# SM_DeskLamp
# SM_AVP1_Switch_03
# SM_AVP1_Network_01
# SM_AVP1_Multimedia_01
# SM_printer_big_a
# SM_computer_a
# SM_Cabinet
# SM_Monitor
# SM_AVP1_Switch_01
# SM_Door
# SM_speaker_a_SM_speaker_a
# SM_Shelf
# SM_keyboard_c
# SM_AVP1_Network_01
# SM_AVP1_Power_02
# SM_Vase
# SM_Monitor
# SM_AVP1_Hook_01
# SM_Vase1
# SM_Chair
# SM_monitor_d
# SM_monitor_b
# SM_monitor_a
# SM_AVP1_Power_05
# SM_Door
# SM_paper_sherdder_a
# SM_Cabinet
# SM_paper_sherdder_a
# SM_AVP1_Sprinkler_01
# SM_speaker_a_SM_speaker_a
# SM_laptop_a_closed
# SM_keyboard_a
# SM_ExecutiveDesk
# SM_DeskLamp
# SM_tv_a
# SM_AVP1_Power_05
# SM_Mouse
# SM_laptop_a_closed
# SM_Cabinet
# SM_AVP1_Switch_04
# SM_scaner_a_open
# SM_laptop_a
# SM_AVP1_Rocker_02
# SM_Vase
# SM_AVP1_Power_01
# SM_Mousepad
# SM_mouse_a
# SM_AVP1_Power_02
# SM_AVP1_Multimedia_01
# SM_laptop_a
# SM_computer_b
# SM_AVP1_Thermo_02
# SM_monitor_a
# SM_ExecutiveChair
# SM_keyboard_c
# SM_projector_a
# SM_AVP1_Dimmer_01
# SM_AVP1_Vent_01
# SM_headphones_a
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Intercom_01
# SM_Monitor
# SM_AVP1_Switch_04
# SM_monitor_a_stand
# SM_ExecutiveDesk
# SM_Vase1
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_monitor_a
# SM_AVP1_Light_01
# SM_scaner_a
# SM_Laptop
# SM_AVP1_Rocker_01
# SM_printer_a
# SM_AVP1_Rocker_02
# SM_telephone_a
# SM_AVP1_Light_01
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_keyboard_b
# SM_AVP1_Power_05
# SM_monitor_b_screen
# SM_AVP1_Thermo_02
# SM_Globe
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_monitor_c
# SM_AVP1_Power_04
# SM_printer_a
# SM_VisitorChair
# SM_Stairs
# SM_AVP1_Vent_02
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_AVP1_Power_03
# SM_computer_a
# SM_Monitor
# SM_Chair
# SM_Chair
# SM_headphones_a
# SM_AVP1_Slider_01
# SM_AVP1_Multimedia_01
# SM_printer_big_a
# SM_AVP1_SmokeDetector_01
# SM_Window
# SM_headphones_a
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_ExecutiveChair
# SM_AVP1_Rocker_02
# SM_tv_a
# SM_monitor_a_screen
# SM_Monitor
# SM_Laptop
# SM_printer_big_a
# SM_AVP1_Multimedia_01
# SM_Vase1
# SM_AVP1_Power_01
# SM_AVP1_Coax_01
# SM_AVP1_Vent_01
# SM_Window
# SM_VisitorChair
# SM_Shelf
# SM_Vase1
# SM_Door
# SM_Chair
# SM_scaner_a_open
# SM_speaker_b
# SM_AVP1_Power_02
# SM_Vase2
# SM_Vase2
# SM_AVP1_Multimedia_01
# SM_DoorFrame
# SM_TableRound
# SM_Chair
# SM_computer_c
# SM_Mousepad
# SM_computer_c
# SM_AVP1_Vent_02
# SM_Door
# SM_DeskTray
# SM_AVP1_Dimmer_01
# SM_mouse_c
# SM_Mousepad
# SM_Vase
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_mouse_c
# SM_monitor_d
# SM_Monitor
# SM_Door
# SM_telephone_a
# SM_Vase
# SM_scaner_a_open
# SM_monitor_a
# SM_Vase
# SM_AVP1_Dimmer_01
# SM_computer_c
# SM_AVP1_SmokeDetector_01
# SM_DoorFrame
# SM_Chair
# SM_ExecutiveDesk
# SM_AVP1_Rocker_02
# SM_speaker_b
# SM_Monitor
# SM_Vase
# SM_AVP1_Coax_01
# SM_AVP1_Power_06
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_04
# SM_Cabinet
# SM_AVP1_Power_02
# SM_AVP1_Network_01
# SM_monitor_c
# SM_monitor_b
# SM_Stairs
# SM_ExecutiveChair
# SM_laptop_a_closed
# SM_monitor_c
# SM_AVP1_Power_03
# SM_Door
# SM_monitor_a
# SM_AVP1_Rocker_01
# SM_DeskTray
# SM_Window
# SM_Globe
# SM_Chair
# SM_printer_big_a
# SM_keyboard_a
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_keyboard_a
# SM_keyboard_c
# SM_AVP1_Power_05
# SM_AVP1_Rocker_01
# SM_printer_big_a
# SM_AVP1_Plate_01
# SM_Laptop
# SM_AVP1_Dimmer_01
# SM_monitor_b
# SM_computer_c
# SM_Mousepad
# SM_tv_a_wall
# SM_AVP1_Intercom_01
# SM_monitor_a_screen
# SM_tv_a_wall
# SM_Door
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_AVP1_Slider_01
# SM_AVP1_Vent_02
# SM_Keyboard
# SM_laptop_a_closed
# SM_Chair
# SM_Globe
# SM_DoorFrame
# SM_printer_big_a
# SM_mouse_a
# SM_scaner_a_open
# SM_AVP1_Motion_01
# SM_Chair
# SM_monitor_d
# SM_computer_a
# SM_AVP1_Switch_03
# SM_Vase
# SM_Door
# SM_laptop_a
# SM_paper_sherdder_a
# SM_AVP1_Slider_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Power_06
# SM_AVP1_Rocker_02
# SM_DeskLamp
# SM_DeskLamp
# SM_Laptop
# SM_monitor_a_stand
# SM_AVP1_Power_05
# SM_monitor_b_stand
# SM_DoorFrame
# SM_Globe
# SM_VisitorChair
# SM_AVP1_Coax_01
# SM_scaner_a_open
# SM_VisitorChair
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Sprinkler_01
# SM_mouse_a
# SM_mouse_b
# SM_AVP1_Power_06
# SM_Vase1
# SM_paper_sherdder_a
# SM_AVP1_Hook_01
# SM_AVP1_Power_06
# SM_AVP1_Dimmer_01
# SM_monitor_b_screen
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Power_05
# SM_AVP1_Vent_01
# SM_AVP1_Rocker_02
# SM_AVP1_Light_01
# SM_AVP1_Network_01
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_laptop_a
# SM_keyboard_b
# SM_Vase1
# SM_Cabinet
# SM_DeskLamp
# SM_monitor_a_stand
# SM_Monitor
# SM_Chair
# SM_monitor_a
# SM_Window
# SM_keyboard_c
# SM_Vase1
# SM_ExecutiveDesk
# SM_tv_a
# SM_tv_a_wall
# SM_monitor_b
# SM_AVP1_Sprinkler_01
# SM_AVP1_Hook_01
# SM_speaker_b
# SM_laptop_a
# SM_AVP1_Network_01
# SM_headphones_a
# SM_AVP1_Power_01
# SM_Keyboard
# SM_Monitor
# SM_scaner_a_open
# SM_paper_sherdder_a
# SM_PencilPot
# SM_Door
# SM_computer_c
# SM_AVP1_Switch_02
# SM_AVP1_Network_01
# SM_Window
# SM_AVP1_Switch_02
# SM_mouse_b
# SM_AVP1_Vent_02
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_02
# SM_mouse_a
# SM_mouse_a
# SM_AVP1_Keypad_01
# SM_Globe
# SM_keyboard_a
# SM_paper_sherdder_a
# SM_computer_c
# SM_printer_big_a
# SM_AVP1_Slider_01
# SM_AVP1_Rocker_02
# SM_AVP1_Vent_02
# SM_monitor_a
# SM_Keyboard
# SM_Couch
# SM_AVP1_Power_04
# SM_AVP1_Switch_04
# SM_projector_a
# SM_tv_a_wall
# SM_AVP1_Light_01
# SM_AVP1_Plate_01
# SM_monitor_b
# SM_AVP1_Switch_04
# SM_AVP1_Power_05
# SM_paper_sherdder_a
# SM_projector_a
# SM_AVP1_Power_04
# SM_AVP1_Light_01
# SM_monitor_a
# SM_tv_a
# SM_AVP1_Thermo_01
# SM_AVP1_Multimedia_01
# SM_scaner_a_open
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_AVP1_SmokeDetector_02
# SM_Couch
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_Globe
# SM_AVP1_Intercom_01
# SM_keyboard_c
# SM_AVP1_Switch_04
# SM_AVP1_Slider_01
# SM_Shelf
# SM_monitor_d
# SM_mouse_a
# SM_Vase2
# SM_VisitorChair
# SM_Couch
# SM_AVP1_Vent_02
# SM_AVP1_Power_01
# SM_AVP1_Network_01
# SM_paper_sherdder_a
# SM_AVP1_Power_01
# SM_ExecutiveChair
# SM_monitor_c
# SM_Vase
# SM_VisitorChair
# SM_AVP1_Plate_01
# SM_Monitor
# SM_telephone_a
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_Chair
# SM_monitor_b
# SM_projector_a
# SM_AVP1_Sprinkler_01
# SM_AVP1_Light_01
# SM_computer_c
# SM_keyboard_a
# SM_monitor_a
# SM_Monitor
# SM_computer_c
# SM_Stairs
# SM_monitor_a_screen
# SM_AVP1_Vent_01
# SM_projector_a
# SM_AVP1_Plate_01
# SM_monitor_a
# SM_monitor_a_stand
# SM_AVP1_Thermo_01
# SM_PencilPot
# SM_AVP1_Vent_02
# SM_headphones_a
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_02
# SM_telephone_a
# SM_projector_a
# SM_ExecutiveDesk
# SM_monitor_d
# SM_PencilPot
# SM_Vase
# SM_TableRound
# SM_mouse_b
# SM_AVP1_Power_06
# SM_AVP1_Switch_02
# SM_AVP1_Light_01
# SM_headphones_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Switch_04
# SM_Monitor
# SM_monitor_a
# SM_AVP1_Intercom_01
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_02
# SM_AVP1_Intercom_01
# SM_scaner_a
# SM_AVP1_Plate_01
# SM_AVP1_Slider_01
# SM_Monitor
# SM_speaker_b
# SM_monitor_b
# SM_monitor_d
# SM_Keyboard
# SM_DoorFrame
# SM_Shelf
# SM_DeskTray
# SM_AVP1_Thermo_01
# SM_AVP1_Light_01
# SM_Keyboard
# SM_computer_c
# SM_AVP1_Power_02
# SM_Shelf
# SM_printer_a
# SM_Monitor
# SM_AVP1_Vent_01
# SM_AVP1_Coax_01
# SM_AVP1_Switch_04
# SM_mouse_a
# SM_AVP1_Thermo_01
# SM_mouse_a
# SM_AVP1_Light_01
# SM_AVP1_Vent_02
# SM_Window
# SM_AVP1_Slider_01
# SM_AVP1_Motion_01
# SM_AVP1_Power_04
# SM_mouse_a
# SM_monitor_c
# SM_mouse_a
# SM_mouse_a
# SM_DeskLamp
# SM_AVP1_Power_03
# SM_Keyboard
# SM_DeskTray
# SM_ExecutiveDesk
# SM_AVP1_Power_05
# SM_VisitorChair
# SM_AVP1_Vent_01
# SM_monitor_d
# SM_monitor_a_stand
# SM_printer_big_a
# SM_AVP1_Rocker_02
# SM_AVP1_Multimedia_01
# SM_monitor_b
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_AVP1_Power_03
# SM_Chair
# SM_tv_a_wall
# SM_DeskTray
# SM_laptop_a
# SM_AVP1_Power_02
# SM_keyboard_a
# SM_Couch
# SM_monitor_b
# SM_computer_b
# SM_mouse_b
# SM_laptop_a
# SM_monitor_b_screen
# SM_Mousepad
# SM_AVP1_Coax_01
# SM_AVP1_Light_01
# SM_Door
# SM_mouse_b
# SM_keyboard_b
# SM_Vase
# SM_keyboard_a
# SM_Stairs
# SM_laptop_a
# SM_paper_sherdder_a
# SM_Window
# SM_monitor_d
# SM_AVP1_Thermo_02
# SM_mouse_c
# SM_AVP1_SmokeDetector_02
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Hook_01
# SM_AVP1_Power_06
# SM_AVP1_Slider_01
# SM_AVP1_Power_05
# SM_laptop_a_closed
# SM_AVP1_Power_06
# SM_keyboard_c
# SM_AVP1_Vent_02
# SM_Vase2
# SM_Shelf
# SM_AVP1_Vent_01
# SM_projector_a
# SM_AVP1_Switch_04
# SM_Shelf
# SM_laptop_a
# SM_Monitor
# SM_AVP1_Rocker_01
# SM_speaker_a_SM_speaker_a
# SM_printer_big_a
# SM_AVP1_Switch_03
# SM_ExecutiveDesk
# SM_monitor_d
# SM_AVP1_Power_04
# SM_Laptop
# SM_AVP1_Power_03
# SM_AVP1_Switch_02
# SM_computer_c
# SM_AVP1_Vent_02
# SM_tv_a_wall
# SM_AVP1_Switch_01
# SM_Stairs
# SM_projector_a
# SM_monitor_a
# SM_AVP1_Vent_02
# SM_Keyboard
# SM_AVP1_Power_04
# SM_AVP1_Power_06
# SM_AVP1_Switch_03
# SM_Window
# SM_Monitor
# SM_computer_a
# SM_monitor_c
# SM_AVP1_Dimmer_01
# SM_Window
# SM_monitor_b
# SM_Couch
# SM_projector_a
# SM_Globe
# SM_AVP1_Light_01
# SM_scaner_a
# SM_telephone_a
# SM_Shelf
# SM_AVP1_Rocker_02
# SM_AVP1_Intercom_01
# SM_Door
# SM_laptop_a_closed
# SM_AVP1_Light_01
# SM_monitor_b
# SM_Vase1
# SM_mouse_c
# SM_Chair
# SM_AVP1_Power_02
# SM_mouse_a
# SM_AVP1_Light_01
# SM_mouse_b
# SM_AVP1_Thermo_02
# SM_AVP1_Power_03
# SM_AVP1_Switch_04
# SM_Vase2
# SM_AVP1_Switch_04
# SM_AVP1_Power_01
# SM_laptop_a
# SM_AVP1_Power_03
# SM_tv_a_wall
# SM_printer_big_a
# SM_monitor_b
# SM_speaker_b
# SM_Chair
# SM_AVP1_Thermo_02
# SM_AVP1_Motion_01
# SM_AVP1_Coax_01
# SM_VisitorChair
# SM_Vase1
# SM_scaner_a_open
# SM_AVP1_Rocker_02
# SM_Shelf
# SM_AVP1_Vent_01
# SM_AVP1_Power_03
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_02
# SM_Window
# SM_paper_sherdder_a
# SM_DeskLamp
# SM_tv_a_wall
# SM_Door
# SM_computer_c
# SM_tv_a
# SM_AVP1_Switch_01
# SM_scaner_a
# SM_Shelf
# SM_AVP1_Switch_02
# SM_keyboard_a
# SM_AVP1_Plate_01
# SM_AVP1_Rocker_01
# SM_laptop_a_closed
# SM_Vase
# SM_Window
# SM_AVP1_Plate_01
# SM_AVP1_Switch_02
# SM_AVP1_SmokeDetector_02
# SM_Mouse
# SM_AVP1_Coax_01
# SM_AVP1_Motion_01
# SM_AVP1_Power_01
# SM_AVP1_Switch_04
# SM_monitor_d
# SM_monitor_b_stand
# SM_AVP1_Thermo_02
# SM_monitor_d
# SM_AVP1_Intercom_01
# SM_monitor_d
# SM_TableRound
# SM_computer_b
# SM_AVP1_Motion_01
# SM_AVP1_Power_05
# SM_keyboard_a
# SM_Door
# SM_Chair
# SM_AVP1_Power_03
# SM_Window
# SM_monitor_a_screen
# SM_Door
# SM_monitor_b_screen
# SM_VisitorChair
# SM_Chair
# SM_Chair
# SM_keyboard_c
# SM_Stairs
# SM_AVP1_Dimmer_01
# SM_monitor_b_screen
# SM_printer_big_a
# SM_Door
# SM_monitor_a_stand
# SM_monitor_b
# SM_TableRound
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_laptop_a
# SM_AVP1_Power_01
# SM_TableRound
# SM_AVP1_SmokeDetector_02
# SM_ExecutiveDesk
# SM_monitor_d
# SM_Globe
# SM_AVP1_Switch_04
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Plate_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Rocker_01
# SM_tv_a
# SM_AVP1_Rocker_01
# SM_AVP1_Intercom_01
# SM_monitor_d
# SM_laptop_a_closed
# SM_mouse_c
# SM_DeskTray
# SM_scaner_a_open
# SM_AVP1_SmokeDetector_02
# SM_monitor_a_stand
# SM_projector_a
# SM_mouse_b
# SM_computer_a
# SM_ExecutiveDesk
# SM_printer_a
# SM_AVP1_Vent_02
# SM_monitor_b
# SM_Stairs
# SM_monitor_c
# SM_AVP1_Intercom_01
# SM_printer_big_a
# SM_DeskLamp
# SM_keyboard_a
# SM_scaner_a
# SM_printer_big_a
# SM_Mouse
# SM_Globe
# SM_AVP1_Vent_01
# SM_Vase
# SM_AVP1_Switch_03
# SM_ExecutiveDesk
# SM_AVP1_Thermo_01
# SM_PencilPot
# SM_keyboard_c
# SM_scaner_a_open
# SM_keyboard_a
# SM_AVP1_SmokeDetector_02
# SM_Stairs
# SM_Monitor
# SM_monitor_d
# SM_Monitor
# SM_AVP1_Power_03
# SM_AVP1_Switch_02
# SM_computer_a
# SM_DeskLamp
# SM_computer_b
# SM_Door
# SM_printer_big_a
# SM_AVP1_Switch_02
# SM_DoorFrame
# SM_computer_b
# SM_AVP1_Power_01
# SM_mouse_a
# SM_AVP1_Intercom_01
# SM_scaner_a_open
# SM_telephone_a
# SM_tv_a
# SM_headphones_a
# SM_AVP1_Power_06
# SM_headphones_a
# SM_mouse_c
# SM_mouse_a
# SM_monitor_c
# SM_AVP1_Thermo_02
# SM_computer_a
# SM_AVP1_Plate_01
# SM_AVP1_Power_04
# SM_ExecutiveChair
# SM_projector_a
# SM_AVP1_Power_06
# SM_DeskLamp
# SM_laptop_a_closed
# SM_AVP1_Hook_01
# SM_Stairs
# SM_ExecutiveChair
# SM_DeskLamp
# SM_AVP1_Switch_01
# SM_AVP1_Slider_01
# SM_ExecutiveChair
# SM_DoorFrame
# SM_computer_a
# SM_AVP1_Switch_03
# SM_AVP1_Thermo_02
# SM_Keyboard
# SM_AVP1_Dimmer_01
# SM_AVP1_Dimmer_01
# SM_AVP1_SmokeDetector_01
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_Mousepad
# SM_scaner_a_open
# SM_monitor_b_screen
# SM_paper_sherdder_a
# SM_AVP1_Power_02
# SM_AVP1_Thermo_02
# SM_AVP1_Keypad_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Network_01
# SM_AVP1_Multimedia_01
# SM_Door
# SM_monitor_b_stand
# SM_Door
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_monitor_b_stand
# SM_AVP1_Rocker_02
# SM_mouse_c
# SM_Window
# SM_AVP1_Keypad_01
# SM_computer_a
# SM_ExecutiveChair
# SM_AVP1_Keypad_01
# SM_AVP1_Power_05
# SM_laptop_a_closed
# SM_AVP1_Switch_03
# SM_Vase1
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Switch_04
# SM_PencilPot
# SM_ExecutiveChair
# SM_AVP1_Power_06
# SM_projector_a
# SM_AVP1_Vent_02
# SM_AVP1_Light_01
# SM_Mouse
# SM_Chair
# SM_Stairs
# SM_AVP1_Rocker_01
# SM_monitor_a
# SM_monitor_a_screen
# SM_Laptop
# SM_Door
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_Keyboard
# SM_mouse_b
# SM_laptop_a
# SM_speaker_a_SM_speaker_a
# SM_Window
# SM_AVP1_Multimedia_01
# SM_tv_a
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_04
# SM_Vase1
# SM_VisitorChair
# SM_AVP1_Power_04
# SM_mouse_a
# SM_DeskLamp
# SM_Couch
# SM_Chair
# SM_ExecutiveDesk
# SM_DeskTray
# SM_AVP1_Rocker_02
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Sprinkler_01
# SM_Shelf
# SM_Monitor
# SM_monitor_b
# SM_printer_a
# SM_keyboard_b
# SM_monitor_b
# SM_mouse_a
# SM_printer_big_a
# SM_Mousepad
# SM_Couch
# SM_Globe
# SM_AVP1_Plate_01
# SM_mouse_a
# SM_AVP1_Plate_01
# SM_AVP1_Rocker_01
# SM_mouse_c
# SM_telephone_a
# SM_AVP1_Power_04
# SM_DeskLamp
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Power_04
# SM_AVP1_Motion_01
# SM_tv_a_wall
# SM_AVP1_Plate_01
# SM_Chair
# SM_ExecutiveDesk
# SM_mouse_a
# SM_AVP1_Power_01
# SM_monitor_b_stand
# SM_AVP1_Power_06
# SM_AVP1_Power_05
# SM_scaner_a_open
# SM_AVP1_Switch_01
# SM_monitor_b
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_Light_01
# SM_AVP1_SmokeDetector_01
# SM_DoorFrame
# SM_AVP1_Network_01
# SM_AVP1_Power_01
# SM_AVP1_Thermo_02
# SM_scaner_a_open
# SM_Vase
# SM_monitor_c
# SM_Couch
# SM_Door
# SM_AVP1_Light_01
# SM_ExecutiveDesk
# SM_AVP1_Keypad_01
# SM_AVP1_SmokeDetector_01
# SM_Couch
# SM_Vase
# SM_printer_a
# SM_AVP1_Rocker_02
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_AVP1_Power_02
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_AVP1_Power_04
# SM_AVP1_Light_01
# SM_monitor_a
# SM_DoorFrame
# SM_Door
# SM_monitor_b_screen
# SM_AVP1_Dimmer_01
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Plate_01
# SM_Window
# SM_AVP1_Power_06
# SM_keyboard_b
# SM_AVP1_SmokeDetector_01
# SM_Chair
# SM_AVP1_Sprinkler_01
# SM_AVP1_Power_03
# SM_monitor_a_screen
# SM_Monitor
# SM_printer_big_a
# SM_AVP1_Thermo_01
# SM_projector_a
# SM_AVP1_Intercom_01
# SM_computer_a
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_keyboard_b
# SM_paper_sherdder_a
# SM_Monitor
# SM_DeskTray
# SM_telephone_a
# SM_Vase2
# SM_computer_c
# SM_Shelf
# SM_mouse_a
# SM_Chair
# SM_AVP1_Intercom_01
# SM_AVP1_Switch_04
# SM_AVP1_Rocker_02
# SM_Keyboard
# SM_AVP1_Vent_02
# SM_AVP1_Power_05
# SM_Door
# SM_monitor_a
# SM_Chair
# SM_computer_c
# SM_computer_b
# SM_ExecutiveChair
# SM_paper_sherdder_a
# SM_AVP1_Vent_01
# SM_AVP1_Vent_02
# SM_monitor_a_screen
# SM_mouse_b
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_scaner_a
# SM_AVP1_Switch_01
# SM_AVP1_Rocker_02
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_mouse_b
# SM_AVP1_Switch_02
# SM_scaner_a
# SM_monitor_a_stand
# SM_AVP1_Power_03
# SM_Stairs
# SM_computer_a
# SM_AVP1_Thermo_01
# SM_Globe
# SM_Vase1
# SM_Door
# SM_Couch
# SM_Laptop
# SM_AVP1_Hook_01
# SM_Vase2
# SM_AVP1_Thermo_02
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_AVP1_Rocker_02
# SM_Monitor
# SM_Chair
# SM_DeskTray
# SM_monitor_a
# SM_tv_a_wall
# SM_monitor_b_screen
# SM_AVP1_Hook_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_01
# SM_paper_sherdder_a
# SM_AVP1_Switch_03
# SM_Shelf
# SM_computer_b
# SM_monitor_c
# SM_AVP1_Thermo_01
# SM_Mousepad
# SM_laptop_a_closed
# SM_AVP1_Dimmer_01
# SM_AVP1_Rocker_02
# SM_PencilPot
# SM_Monitor
# SM_tv_a
# SM_AVP1_Network_01
# SM_AVP1_Power_01
# SM_computer_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_SmokeDetector_02
# SM_mouse_c
# SM_AVP1_Switch_02
# SM_Mouse
# SM_Monitor
# SM_AVP1_Rocker_02
# SM_speaker_b
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_TableRound
# SM_AVP1_Rocker_02
# SM_Window
# SM_AVP1_Coax_01
# SM_AVP1_Multimedia_01
# SM_Laptop
# SM_monitor_a_screen
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_AVP1_Multimedia_01
# SM_AVP1_Coax_01
# SM_ExecutiveDesk
# SM_Window
# SM_AVP1_Power_02
# SM_monitor_b_stand
# SM_AVP1_Power_02
# SM_monitor_c
# SM_scaner_a
# SM_AVP1_Network_01
# SM_monitor_a_screen
# SM_Cabinet
# SM_monitor_c
# SM_VisitorChair
# SM_Keyboard
# SM_mouse_c
# SM_Shelf
# SM_paper_sherdder_a
# SM_mouse_b
# SM_Mousepad
# SM_Monitor
# SM_AVP1_Network_01
# SM_AVP1_Power_04
# SM_speaker_b
# SM_AVP1_Switch_03
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_02
# SM_laptop_a_closed
# SM_speaker_b
# SM_AVP1_Thermo_02
# SM_printer_a
# SM_monitor_a_stand
# SM_Cabinet
# SM_projector_a
# SM_DeskLamp
# SM_Chair
# SM_monitor_b_stand
# SM_AVP1_Power_01
# SM_AVP1_Switch_01
# SM_scaner_a_open
# SM_mouse_b
# SM_monitor_c
# SM_keyboard_c
# SM_tv_a_wall
# SM_mouse_a
# SM_AVP1_Multimedia_01
# SM_AVP1_SmokeDetector_02
# SM_computer_a
# SM_scaner_a
# SM_AVP1_Power_01
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_computer_c
# SM_Monitor
# SM_PencilPot
# SM_AVP1_Power_02
# SM_Window
# SM_Laptop
# SM_AVP1_Network_01
# SM_tv_a_wall
# SM_AVP1_Intercom_01
# SM_Monitor
# SM_AVP1_Switch_02
# SM_mouse_b
# SM_PencilPot
# SM_laptop_a_closed
# SM_AVP1_Coax_01
# SM_AVP1_Switch_04
# SM_DeskLamp
# SM_AVP1_Motion_01
# SM_PencilPot
# SM_Vase2
# SM_laptop_a
# SM_mouse_a
# SM_AVP1_Network_01
# SM_AVP1_Power_06
# SM_AVP1_Multimedia_01
# SM_Vase
# SM_AVP1_Power_01
# SM_monitor_b
# SM_AVP1_Rocker_02
# SM_AVP1_Motion_01
# SM_computer_b
# SM_AVP1_Power_01
# SM_AVP1_Power_03
# SM_AVP1_Hook_01
# SM_speaker_a_SM_speaker_a
# SM_tv_a_wall
# SM_DeskTray
# SM_Shelf
# SM_ExecutiveChair
# SM_monitor_a_screen
# SM_monitor_d
# SM_Door
# SM_monitor_a_stand
# SM_projector_a
# SM_AVP1_Power_02
# SM_computer_c
# SM_monitor_b
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_mouse_c
# SM_AVP1_Vent_01
# SM_monitor_b_screen
# SM_projector_a
# SM_Globe
# SM_Door
# SM_Vase1
# SM_AVP1_Intercom_01
# SM_Mouse
# SM_Shelf
# SM_Globe
# SM_monitor_a
# SM_paper_sherdder_a
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_AVP1_Thermo_02
# SM_speaker_a_SM_speaker_a
# SM_DeskTray
# SM_Cabinet
# SM_AVP1_Switch_03
# SM_AVP1_Slider_01
# SM_speaker_b
# SM_AVP1_SmokeDetector_02
# SM_paper_sherdder_a
# SM_monitor_c
# SM_DoorFrame
# SM_Monitor
# SM_Chair
# SM_mouse_a
# SM_telephone_a
# SM_monitor_a_screen
# SM_Couch
# SM_laptop_a_closed
# SM_AVP1_Switch_04
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_computer_a
# SM_Chair
# SM_Cabinet
# SM_AVP1_Slider_01
# SM_monitor_a
# SM_scaner_a
# SM_monitor_a
# SM_keyboard_c
# SM_computer_a
# SM_projector_a
# SM_AVP1_Switch_02
# SM_AVP1_Network_01
# SM_scaner_a_open
# SM_AVP1_Power_03
# SM_monitor_b
# SM_AVP1_Light_01
# SM_scaner_a_open
# SM_tv_a_wall
# SM_paper_sherdder_a
# SM_scaner_a_open
# SM_AVP1_Dimmer_01
# SM_TableRound
# SM_printer_big_a
# SM_keyboard_c
# SM_Cabinet
# SM_keyboard_a
# SM_AVP1_Keypad_01
# SM_PencilPot
# SM_AVP1_Keypad_01
# SM_computer_a
# SM_AVP1_Vent_01
# SM_monitor_b_stand
# SM_monitor_c
# SM_computer_a
# SM_keyboard_a
# SM_Monitor
# SM_AVP1_Light_01
# SM_AVP1_Keypad_01
# SM_Vase1
# SM_Door
# SM_Keyboard
# SM_telephone_a
# SM_Chair
# SM_monitor_b
# SM_paper_sherdder_a
# SM_scaner_a_open
# SM_PencilPot
# SM_AVP1_Intercom_01
# SM_AVP1_Rocker_01
# SM_speaker_a_SM_speaker_a
# SM_tv_a_wall
# SM_Keyboard
# SM_AVP1_Hook_01
# SM_Globe
# SM_monitor_b
# SM_Monitor
# SM_tv_a_wall
# SM_Vase2
# SM_AVP1_Coax_01
# SM_keyboard_b
# SM_Vase1
# SM_monitor_a_stand
# SM_AVP1_Sprinkler_01
# SM_AVP1_Vent_01
# SM_AVP1_Switch_02
# SM_monitor_d
# SM_keyboard_b
# SM_AVP1_Power_05
# SM_monitor_b_screen
# SM_Vase2
# SM_Stairs
# SM_AVP1_SmokeDetector_01
# SM_monitor_d
# SM_AVP1_Light_01
# SM_DoorFrame
# SM_laptop_a_closed
# SM_Laptop
# SM_mouse_c
# SM_AVP1_Vent_02
# SM_AVP1_Power_03
# SM_AVP1_Power_05
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_keyboard_a
# SM_AVP1_Power_06
# SM_monitor_d
# SM_Mouse
# SM_monitor_b_screen
# SM_AVP1_Multimedia_01
# SM_monitor_a_stand
# SM_DeskTray
# SM_AVP1_SmokeDetector_02
# SM_Vase2
# SM_DoorFrame
# SM_keyboard_a
# SM_computer_c
# SM_AVP1_Dimmer_01
# SM_Shelf
# SM_AVP1_Switch_01
# SM_Chair
# SM_keyboard_a
# SM_AVP1_Vent_02
# SM_Mousepad
# SM_laptop_a_closed
# SM_mouse_a
# SM_monitor_a_stand
# SM_Stairs
# SM_AVP1_Power_03
# SM_monitor_b_stand
# SM_keyboard_b
# SM_printer_big_a
# SM_monitor_c
# SM_AVP1_Power_01
# SM_Door
# SM_TableRound
# SM_mouse_a
# SM_DoorFrame
# SM_monitor_a
# SM_Laptop
# SM_AVP1_Motion_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_02
# SM_Keyboard
# SM_Vase1
# SM_DeskTray
# SM_DeskTray
# SM_AVP1_Power_01
# SM_monitor_a
# SM_AVP1_Switch_01
# SM_VisitorChair
# SM_Keyboard
# SM_AVP1_SmokeDetector_02
# SM_ExecutiveChair
# SM_AVP1_Rocker_02
# SM_projector_a
# SM_AVP1_Switch_03
# SM_Monitor
# SM_AVP1_Thermo_02
# SM_Mouse
# SM_AVP1_Hook_01
# SM_monitor_c
# SM_Chair
# SM_mouse_c
# SM_computer_b
# SM_monitor_a_stand
# SM_AVP1_Multimedia_01
# SM_computer_a
# SM_printer_a
# SM_tv_a_wall
# SM_ExecutiveDesk
# SM_AVP1_Power_05
# SM_AVP1_Keypad_01
# SM_Door
# SM_AVP1_Switch_03
# SM_printer_a
# SM_AVP1_Network_01
# SM_speaker_b
# SM_Monitor
# SM_ExecutiveChair
# SM_AVP1_Switch_02
# SM_monitor_a_stand
# SM_AVP1_Slider_01
# SM_Cabinet
# SM_Vase1
# SM_mouse_c
# SM_Mouse
# SM_AVP1_Power_03
# SM_AVP1_Switch_04
# SM_monitor_b_screen
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_Window
# SM_Mouse
# SM_monitor_b_stand
# SM_Vase
# SM_Window
# SM_AVP1_Power_05
# SM_AVP1_Power_05
# SM_Vase
# SM_AVP1_Multimedia_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Switch_02
# SM_telephone_a
# SM_ExecutiveChair
# SM_AVP1_Motion_01
# SM_headphones_a
# SM_monitor_d
# SM_monitor_c
# SM_Mouse
# SM_Chair
# SM_mouse_c
# SM_Couch
# SM_computer_c
# SM_AVP1_Switch_01
# SM_AVP1_Power_02
# SM_monitor_a
# SM_monitor_b_stand
# SM_DeskLamp
# SM_ExecutiveDesk
# SM_keyboard_a
# SM_Vase1
# SM_AVP1_Keypad_01
# SM_DeskTray
# SM_ExecutiveDesk
# SM_ExecutiveDesk
# SM_monitor_d
# SM_Window
# SM_ExecutiveDesk
# SM_tv_a
# SM_monitor_b
# SM_printer_a
# SM_Mousepad
# SM_Chair
# SM_tv_a
# SM_AVP1_Slider_01
# SM_Chair
# SM_DeskLamp
# SM_keyboard_c
# SM_AVP1_Power_03
# SM_Monitor
# SM_Couch
# SM_AVP1_Sprinkler_01
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_AVP1_Slider_01
# SM_keyboard_a
# SM_AVP1_Power_05
# SM_DeskTray
# SM_projector_a
# SM_AVP1_Hook_01
# SM_Door
# SM_scaner_a
# SM_DeskTray
# SM_telephone_a
# SM_DeskTray
# SM_AVP1_Power_04
# SM_Chair
# SM_DeskTray
# SM_headphones_a
# SM_keyboard_a
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_AVP1_Multimedia_01
# SM_monitor_a
# SM_Shelf
# SM_mouse_a
# SM_Couch
# SM_AVP1_Light_01
# SM_scaner_a
# SM_AVP1_Vent_02
# SM_AVP1_Dimmer_01
# SM_tv_a
# SM_monitor_d
# SM_AVP1_Vent_02
# SM_DeskTray
# SM_AVP1_Switch_02
# SM_AVP1_Switch_01
# SM_AVP1_SmokeDetector_01
# SM_scaner_a
# SM_AVP1_Power_06
# SM_Mousepad
# SM_tv_a
# SM_AVP1_Sprinkler_01
# SM_keyboard_c
# SM_ExecutiveDesk
# SM_mouse_a
# SM_ExecutiveDesk
# SM_Keyboard
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_02
# SM_AVP1_Switch_03
# SM_computer_a
# SM_AVP1_Multimedia_01
# SM_monitor_b
# SM_Laptop
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Switch_01
# SM_monitor_c
# SM_monitor_a_screen
# SM_Chair
# SM_computer_a
# SM_AVP1_Multimedia_01
# SM_Door
# SM_PencilPot
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Power_03
# SM_Cabinet
# SM_monitor_b_screen
# SM_VisitorChair
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_laptop_a_closed
# SM_AVP1_Vent_01
# SM_monitor_b_screen
# SM_Monitor
# SM_AVP1_Slider_01
# SM_AVP1_Rocker_02
# SM_monitor_a_screen
# SM_monitor_a_screen
# SM_computer_a
# SM_AVP1_Intercom_01
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_screen
# SM_Monitor
# SM_Cabinet
# SM_AVP1_Power_03
# SM_ExecutiveChair
# SM_mouse_a
# SM_keyboard_c
# SM_ExecutiveChair
# SM_TableRound
# SM_keyboard_c
# SM_AVP1_Power_03
# SM_Mousepad
# SM_projector_a
# SM_AVP1_Light_01
# SM_AVP1_Intercom_01
# SM_AVP1_Switch_03
# SM_PencilPot
# SM_AVP1_Power_06
# SM_AVP1_Plate_01
# SM_monitor_d
# SM_mouse_a
# SM_Mouse
# SM_printer_big_a
# SM_keyboard_b
# SM_tv_a
# SM_AVP1_Motion_01
# SM_Shelf
# SM_DeskTray
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Coax_01
# SM_Chair
# SM_AVP1_Intercom_01
# SM_Window
# SM_Globe
# SM_Shelf
# SM_AVP1_Power_02
# SM_computer_a
# SM_TableRound
# SM_AVP1_Vent_01
# SM_projector_a
# SM_projector_a
# SM_TableRound
# SM_Globe
# SM_AVP1_Switch_04
# SM_ExecutiveChair
# SM_printer_big_a
# SM_Chair
# SM_Vase1
# SM_AVP1_SmokeDetector_01
# SM_mouse_a
# SM_mouse_c
# SM_AVP1_Switch_04
# SM_Stairs
# SM_VisitorChair
# SM_AVP1_Intercom_01
# SM_monitor_b_screen
# SM_AVP1_Network_01
# SM_AVP1_Motion_01
# SM_Shelf
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_computer_c
# SM_AVP1_Plate_01
# SM_headphones_a
# SM_monitor_b
# SM_AVP1_Network_01
# SM_Vase2
# SM_AVP1_Sprinkler_01
# SM_computer_b
# SM_AVP1_Vent_02
# SM_AVP1_Hook_01
# SM_AVP1_Vent_02
# SM_printer_a
# SM_Cabinet
# SM_AVP1_Dimmer_01
# SM_AVP1_Vent_01
# SM_ExecutiveDesk
# SM_keyboard_b
# SM_Monitor
# SM_mouse_b
# SM_Laptop
# SM_AVP1_Power_04
# SM_AVP1_Thermo_02
# SM_DoorFrame
# SM_AVP1_SmokeDetector_02
# SM_DeskTray
# SM_Mousepad
# SM_laptop_a
# SM_keyboard_b
# SM_monitor_c
# SM_keyboard_c
# SM_AVP1_Multimedia_01
# SM_DoorFrame
# SM_AVP1_Vent_02
# SM_PencilPot
# SM_monitor_a
# SM_TableRound
# SM_Monitor
# SM_keyboard_c
# SM_Mousepad
# SM_tv_a
# SM_AVP1_SmokeDetector_02
# SM_mouse_c
# SM_DoorFrame
# SM_laptop_a
# SM_AVP1_Switch_03
# SM_AVP1_Motion_01
# SM_tv_a
# SM_monitor_a_screen
# SM_AVP1_Coax_01
# SM_monitor_a
# SM_Keyboard
# SM_TableRound
# SM_Door
# SM_AVP1_Network_01
# SM_DeskTray
# SM_DeskLamp
# SM_Mousepad
# SM_tv_a_wall
# SM_Chair
# SM_Vase1
# SM_AVP1_Power_01
# SM_AVP1_SmokeDetector_02
# SM_scaner_a_open
# SM_Monitor
# SM_scaner_a
# SM_speaker_a_SM_speaker_a
# SM_Chair
# SM_AVP1_Network_01
# SM_Chair
# SM_AVP1_Rocker_01
# SM_telephone_a
# SM_AVP1_Switch_02
# SM_AVP1_Thermo_01
# SM_AVP1_Keypad_01
# SM_AVP1_Slider_01
# SM_headphones_a
# SM_Shelf
# SM_PencilPot
# SM_mouse_c
# SM_AVP1_Motion_01
# SM_Chair
# SM_AVP1_Power_05
# SM_AVP1_Switch_04
# SM_Cabinet
# SM_Door
# SM_printer_a
# SM_AVP1_Sprinkler_01
# SM_monitor_a
# SM_monitor_d
# SM_scaner_a_open
# SM_AVP1_Intercom_01
# SM_PencilPot
# SM_Stairs
# SM_mouse_c
# SM_Cabinet
# SM_monitor_a
# SM_Monitor
# SM_AVP1_Motion_01
# SM_monitor_b_screen
# SM_AVP1_Switch_02
# SM_speaker_a_SM_speaker_a
# SM_speaker_a_SM_speaker_a
# SM_Shelf
# SM_AVP1_SmokeDetector_02
# SM_Mouse
# SM_mouse_a
# SM_AVP1_Switch_03
# SM_Chair
# SM_AVP1_Hook_01
# SM_AVP1_Sprinkler_01
# SM_AVP1_Multimedia_01
# SM_Shelf
# SM_Vase1
# SM_monitor_b_screen
# SM_PencilPot
# SM_speaker_b
# SM_Window
# SM_AVP1_Power_03
# SM_Door
# SM_mouse_a
# SM_Globe
# SM_monitor_a_screen
# SM_Vase
# SM_keyboard_c
# SM_AVP1_Light_01
# SM_AVP1_Power_01
# SM_AVP1_Switch_03
# SM_mouse_b
# SM_AVP1_Rocker_02
# SM_telephone_a
# SM_AVP1_Thermo_01
# SM_computer_a
# SM_AVP1_Switch_02
# SM_Vase2
# SM_AVP1_Slider_01
# SM_AVP1_Switch_01
# SM_monitor_a
# SM_AVP1_Power_03
# SM_AVP1_Power_05
# SM_Vase1
# SM_telephone_a
# SM_keyboard_b
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_AVP1_Power_02
# SM_PencilPot
# SM_Keyboard
# SM_paper_sherdder_a
# SM_Stairs
# SM_mouse_a
# SM_Monitor
# SM_monitor_a_stand
# SM_AVP1_Plate_01
# SM_monitor_c
# SM_Door
# SM_Globe
# SM_AVP1_Switch_02
# SM_ExecutiveChair
# SM_AVP1_Vent_02
# SM_monitor_c
# SM_AVP1_Power_01
# SM_tv_a_wall
# SM_mouse_a
# SM_AVP1_Coax_01
# SM_AVP1_Light_01
# SM_Door
# SM_AVP1_Power_01
# SM_AVP1_Switch_03
# SM_mouse_c
# SM_computer_b
# SM_speaker_a_SM_speaker_a
# SM_Chair
# SM_Globe
# SM_AVP1_Coax_01
# SM_mouse_b
# SM_AVP1_Power_06
# SM_mouse_b
# SM_Laptop
# SM_monitor_b_screen
# SM_computer_c
# SM_DoorFrame
# SM_AVP1_SmokeDetector_02
# SM_monitor_a_screen
# SM_AVP1_Coax_01
# SM_Cabinet
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Motion_01
# SM_AVP1_Plate_01
# SM_Door
# SM_Chair
# SM_projector_a
# SM_monitor_c
# SM_Laptop
# SM_ExecutiveChair
# SM_computer_a
# SM_VisitorChair
# SM_Chair
# SM_paper_sherdder_a
# SM_telephone_a
# SM_Chair
# SM_monitor_d
# SM_AVP1_Rocker_01
# SM_monitor_d
# SM_AVP1_Slider_01
# SM_Couch
# SM_AVP1_Rocker_01
# SM_Monitor
# SM_monitor_d
# SM_DoorFrame
# SM_monitor_a_screen
# SM_AVP1_Intercom_01
# SM_AVP1_SmokeDetector_01
# SM_paper_sherdder_a
# SM_computer_c
# SM_AVP1_Vent_01
# SM_Door
# SM_Stairs
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_speaker_b
# SM_Monitor
# SM_AVP1_Power_04
# SM_projector_a
# SM_Globe
# SM_AVP1_Light_01
# SM_AVP1_SmokeDetector_01
# SM_PencilPot
# SM_laptop_a_closed
# SM_laptop_a_closed
# SM_AVP1_Vent_02
# SM_Shelf
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Coax_01
# SM_Door
# SM_AVP1_Hook_01
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_Monitor
# SM_tv_a
# SM_Couch
# SM_AVP1_Multimedia_01
# SM_monitor_b_screen
# SM_printer_a
# SM_AVP1_Intercom_01
# SM_AVP1_Light_01
# SM_printer_a
# SM_Couch
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_keyboard_b
# SM_Door
# SM_AVP1_Power_02
# SM_Mouse
# SM_AVP1_Plate_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Intercom_01
# SM_tv_a
# SM_Globe
# SM_Mousepad
# SM_AVP1_Power_04
# SM_Laptop
# SM_keyboard_b
# SM_tv_a_wall
# SM_printer_a
# SM_AVP1_Rocker_01
# SM_monitor_a
# SM_keyboard_c
# SM_AVP1_Power_04
# SM_Keyboard
# SM_AVP1_Power_06
# SM_Vase1
# SM_keyboard_b
# SM_mouse_a
# SM_monitor_d
# SM_AVP1_Light_01
# SM_monitor_c
# SM_AVP1_Network_01
# SM_keyboard_c
# SM_AVP1_Switch_01
# SM_Vase
# SM_laptop_a_closed
# SM_Monitor
# SM_AVP1_Motion_01
# SM_Vase1
# SM_scaner_a_open
# SM_scaner_a_open
# SM_Stairs
# SM_printer_a
# SM_computer_b
# SM_scaner_a_open
# SM_scaner_a_open
# SM_speaker_a_SM_speaker_a
# SM_monitor_a
# SM_AVP1_Switch_03
# SM_projector_a
# SM_AVP1_Thermo_02
# SM_TableRound
# SM_tv_a
# SM_DoorFrame
# SM_scaner_a_open
# SM_laptop_a_closed
# SM_monitor_b_stand
# SM_Mousepad
# SM_PencilPot
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_monitor_b_stand
# SM_AVP1_Power_06
# SM_tv_a_wall
# SM_scaner_a_open
# SM_scaner_a
# SM_monitor_c
# SM_ExecutiveDesk
# SM_mouse_b
# SM_AVP1_Thermo_01
# SM_AVP1_Light_01
# SM_AVP1_Motion_01
# SM_Window
# SM_monitor_b_screen
# SM_AVP1_Power_02
# SM_Monitor
# SM_mouse_c
# SM_monitor_b_screen
# SM_speaker_b
# SM_computer_a
# SM_AVP1_Switch_02
# SM_monitor_d
# SM_TableRound
# SM_VisitorChair
# SM_Door
# SM_Chair
# SM_AVP1_Plate_01
# SM_Couch
# SM_AVP1_Rocker_02
# SM_AVP1_Hook_01
# SM_monitor_b
# SM_DoorFrame
# SM_Monitor
# SM_ExecutiveChair
# SM_AVP1_Thermo_02
# SM_VisitorChair
# SM_Door
# SM_AVP1_SmokeDetector_02
# SM_Chair
# SM_AVP1_Coax_01
# SM_Cabinet
# SM_keyboard_b
# SM_VisitorChair
# SM_AVP1_Switch_01
# SM_telephone_a
# SM_AVP1_Slider_01
# SM_AVP1_Sprinkler_01
# SM_computer_c
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_02
# SM_AVP1_Power_04
# SM_scaner_a
# SM_scaner_a
# SM_AVP1_Vent_01
# SM_keyboard_b
# SM_Door
# SM_Window
# SM_AVP1_Switch_03
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_Door
# SM_Stairs
# SM_AVP1_Thermo_01
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_AVP1_Power_01
# SM_AVP1_Power_01
# SM_AVP1_Intercom_01
# SM_tv_a_wall
# SM_Globe
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_scaner_a
# SM_DoorFrame
# SM_Chair
# SM_printer_a
# SM_AVP1_Thermo_01
# SM_computer_c
# SM_paper_sherdder_a
# SM_AVP1_Power_04
# SM_AVP1_Motion_01
# SM_Vase2
# SM_Door
# SM_AVP1_Network_01
# SM_mouse_c
# SM_AVP1_Coax_01
# SM_monitor_c
# SM_mouse_c
# SM_tv_a
# SM_AVP1_Power_04
# SM_DeskLamp
# SM_monitor_b
# SM_AVP1_Multimedia_01
# SM_monitor_b_stand
# SM_AVP1_SmokeDetector_01
# SM_keyboard_b
# SM_Door
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_ExecutiveDesk
# SM_Chair
# SM_printer_a
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Power_06
# SM_mouse_c
# SM_keyboard_b
# SM_computer_a
# SM_keyboard_a
# SM_AVP1_Switch_02
# SM_Vase2
# SM_AVP1_Rocker_01
# SM_keyboard_b
# SM_AVP1_Plate_01
# SM_monitor_d
# SM_printer_big_a
# SM_monitor_a
# SM_AVP1_Switch_04
# SM_monitor_b_screen
# SM_AVP1_Vent_02
# SM_scaner_a
# SM_Chair
# SM_AVP1_Switch_03
# SM_Globe
# SM_AVP1_Vent_01
# SM_AVP1_Power_06
# SM_keyboard_c
# SM_monitor_a_screen
# SM_Chair
# SM_Vase2
# SM_AVP1_Multimedia_01
# SM_speaker_b
# SM_Stairs
# SM_scaner_a_open
# SM_VisitorChair
# SM_Chair
# SM_Vase
# SM_Mousepad
# SM_AVP1_Motion_01
# SM_AVP1_Vent_02
# SM_Door
# SM_DeskTray
# SM_AVP1_Power_02
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Motion_01
# SM_PencilPot
# SM_mouse_a
# SM_AVP1_Power_05
# SM_Shelf
# SM_Mousepad
# SM_DeskLamp
# SM_Window
# SM_telephone_a
# SM_Window
# SM_DoorFrame
# SM_AVP1_SmokeDetector_01
# SM_computer_b
# SM_monitor_a_screen
# SM_DoorFrame
# SM_computer_b
# SM_AVP1_Power_02
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_printer_big_a
# SM_Window
# SM_Stairs
# SM_projector_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Hook_01
# SM_tv_a_wall
# SM_AVP1_Power_04
# SM_AVP1_Power_01
# SM_AVP1_Rocker_02
# SM_headphones_a
# SM_Chair
# SM_AVP1_Light_01
# SM_Cabinet
# SM_Door
# SM_monitor_a
# SM_DoorFrame
# SM_computer_b
# SM_Stairs
# SM_Chair
# SM_computer_b
# SM_laptop_a_closed
# SM_computer_a
# SM_mouse_c
# SM_AVP1_Light_01
# SM_AVP1_Thermo_02
# SM_Couch
# SM_AVP1_Network_01
# SM_Chair
# SM_tv_a_wall
# SM_AVP1_Multimedia_01
# SM_Vase1
# SM_monitor_a_stand
# SM_AVP1_Intercom_01
# SM_AVP1_Power_06
# SM_monitor_b_stand
# SM_paper_sherdder_a
# SM_projector_a
# SM_Laptop
# SM_Chair
# SM_AVP1_Multimedia_01
# SM_projector_a
# SM_Door
# SM_AVP1_Keypad_01
# SM_AVP1_Dimmer_01
# SM_ExecutiveChair
# SM_scaner_a_open
# SM_AVP1_Switch_02
# SM_AVP1_Thermo_02
# SM_AVP1_Vent_02
# SM_AVP1_Switch_03
# SM_AVP1_Thermo_02
# SM_AVP1_Multimedia_01
# SM_keyboard_b
# SM_mouse_b
# SM_Stairs
# SM_mouse_a
# SM_Stairs
# SM_AVP1_Rocker_01
# SM_AVP1_Network_01
# SM_Vase2
# SM_monitor_b_screen
# SM_VisitorChair
# SM_AVP1_Switch_01
# SM_AVP1_Vent_01
# SM_TableRound
# SM_monitor_b_screen
# SM_speaker_a_SM_speaker_a
# SM_Vase1
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_computer_c
# SM_computer_a
# SM_AVP1_Sprinkler_01
# SM_ExecutiveChair
# SM_DeskLamp
# SM_printer_big_a
# SM_AVP1_Keypad_01
# SM_keyboard_a
# SM_Globe
# SM_scaner_a_open
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_monitor_b_stand
# SM_AVP1_Switch_03
# SM_Mouse
# SM_computer_a
# SM_monitor_a_stand
# SM_Shelf
# SM_AVP1_Keypad_01
# SM_AVP1_Vent_01
# SM_monitor_c
# SM_monitor_b_screen
# SM_mouse_c
# SM_AVP1_Switch_03
# SM_Mouse
# SM_AVP1_Plate_01
# SM_AVP1_Plate_01
# SM_AVP1_Vent_01
# SM_AVP1_SmokeDetector_02
# SM_Door
# SM_TableRound
# SM_monitor_b_stand
# SM_Cabinet
# SM_Shelf
# SM_monitor_a_stand
# SM_projector_a
# SM_computer_a
# SM_speaker_b
# SM_AVP1_Vent_01
# SM_printer_big_a
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_laptop_a
# SM_AVP1_Hook_01
# SM_DeskLamp
# SM_Stairs
# SM_TableRound
# SM_DeskTray
# SM_AVP1_Motion_01
# SM_scaner_a
# SM_Globe
# SM_AVP1_Multimedia_01
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_Chair
# SM_AVP1_Power_03
# SM_printer_a
# SM_AVP1_Intercom_01
# SM_monitor_a_stand
# SM_computer_b
# SM_Couch
# SM_telephone_a
# SM_keyboard_a
# SM_monitor_a_stand
# SM_monitor_c
# SM_DoorFrame
# SM_printer_a
# SM_Chair
# SM_Vase2
# SM_DeskLamp
# SM_Mouse
# SM_AVP1_Power_06
# SM_AVP1_Switch_04
# SM_speaker_a_SM_speaker_a
# SM_mouse_a
# SM_AVP1_Thermo_01
# SM_Window
# SM_AVP1_Switch_03
# SM_scaner_a_open
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Vent_01
# SM_keyboard_a
# SM_Monitor
# SM_telephone_a
# SM_AVP1_Power_06
# SM_computer_c
# SM_AVP1_Power_03
# SM_Mousepad
# SM_Mousepad
# SM_AVP1_Rocker_01
# SM_laptop_a
# SM_monitor_b_screen
# SM_monitor_c
# SM_AVP1_Power_02
# SM_Cabinet
# SM_telephone_a
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_headphones_a
# SM_Vase2
# SM_AVP1_Power_04
# SM_telephone_a
# SM_Cabinet
# SM_AVP1_Sprinkler_01
# SM_monitor_b
# SM_Chair
# SM_AVP1_Coax_01
# SM_headphones_a
# SM_ExecutiveDesk
# SM_Chair
# SM_scaner_a
# SM_computer_a
# SM_AVP1_Thermo_02
# SM_AVP1_Network_01
# SM_printer_a
# SM_mouse_c
# SM_scaner_a
# SM_AVP1_Keypad_01
# SM_AVP1_Thermo_01
# SM_AVP1_Switch_02
# SM_AVP1_Switch_04
# SM_paper_sherdder_a
# SM_computer_c
# SM_AVP1_Switch_03
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_scaner_a
# SM_AVP1_Switch_04
# SM_Vase1
# SM_DeskTray
# SM_Monitor
# SM_AVP1_Power_06
# SM_tv_a_wall
# SM_AVP1_Switch_04
# SM_AVP1_Intercom_01
# SM_speaker_b
# SM_AVP1_Thermo_02
# SM_AVP1_Hook_01
# SM_DoorFrame
# SM_Stairs
# SM_Door
# SM_DeskLamp
# SM_ExecutiveDesk
# SM_AVP1_Keypad_01
# SM_Vase2
# SM_AVP1_Power_01
# SM_AVP1_Switch_04
# SM_headphones_a
# SM_Window
# SM_AVP1_Switch_02
# SM_AVP1_Vent_02
# SM_Vase
# SM_AVP1_Thermo_02
# SM_AVP1_Rocker_02
# SM_AVP1_Plate_01
# SM_Monitor
# SM_Vase2
# SM_AVP1_Power_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Slider_01
# SM_paper_sherdder_a
# SM_keyboard_c
# SM_AVP1_Rocker_01
# SM_AVP1_Power_04
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_printer_a
# SM_Door
# SM_AVP1_SmokeDetector_01
# SM_ExecutiveChair
# SM_AVP1_SmokeDetector_02
# SM_DeskTray
# SM_keyboard_b
# SM_Couch
# SM_computer_c
# SM_Window
# SM_laptop_a_closed
# SM_AVP1_Vent_01
# SM_AVP1_Switch_01
# SM_scaner_a
# SM_TableRound
# SM_Door
# SM_Monitor
# SM_AVP1_SmokeDetector_02
# SM_Laptop
# SM_AVP1_SmokeDetector_02
# SM_Keyboard
# SM_AVP1_Power_02
# SM_printer_big_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Sprinkler_01
# SM_tv_a
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_AVP1_Sprinkler_01
# SM_TableRound
# SM_Chair
# SM_monitor_a
# SM_telephone_a
# SM_ExecutiveDesk
# SM_AVP1_Rocker_02
# SM_keyboard_c
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Multimedia_01
# SM_Door
# SM_AVP1_Vent_01
# SM_keyboard_c
# SM_keyboard_a
# SM_AVP1_Multimedia_01
# SM_monitor_d
# SM_laptop_a_closed
# SM_tv_a_wall
# SM_Laptop
# SM_monitor_d
# SM_scaner_a_open
# SM_Cabinet
# SM_AVP1_Power_01
# SM_AVP1_Power_04
# SM_Keyboard
# SM_monitor_a_stand
# SM_AVP1_Keypad_01
# SM_projector_a
# SM_tv_a
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Light_01
# SM_monitor_a_stand
# SM_tv_a_wall
# SM_AVP1_Plate_01
# SM_AVP1_Power_02
# SM_tv_a_wall
# SM_monitor_b_stand
# SM_speaker_a_SM_speaker_a
# SM_scaner_a_open
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_Mousepad
# SM_mouse_b
# SM_AVP1_Network_01
# SM_ExecutiveDesk
# SM_Window
# SM_monitor_b
# SM_AVP1_Switch_03
# SM_AVP1_Power_06
# SM_Cabinet
# SM_AVP1_Sprinkler_01
# SM_projector_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Hook_01
# SM_keyboard_b
# SM_Door
# SM_printer_a
# SM_Keyboard
# SM_AVP1_Thermo_02
# SM_tv_a
# SM_AVP1_Thermo_02
# SM_Cabinet
# SM_Vase2
# SM_computer_c
# SM_Laptop
# SM_AVP1_Vent_02
# SM_AVP1_Sprinkler_01
# SM_Door
# SM_laptop_a_closed
# SM_keyboard_a
# SM_monitor_d
# SM_AVP1_Thermo_01
# SM_AVP1_Rocker_02
# SM_Keyboard
# SM_keyboard_c
# SM_laptop_a_closed
# SM_printer_a
# SM_monitor_d
# SM_AVP1_Light_01
# SM_keyboard_b
# SM_AVP1_Keypad_01
# SM_AVP1_Rocker_02
# SM_printer_a
# SM_Vase2
# SM_AVP1_Power_01
# SM_mouse_a
# SM_TableRound
# SM_Couch
# SM_Chair
# SM_Mouse
# SM_tv_a
# SM_Monitor
# SM_Globe
# SM_keyboard_b
# SM_speaker_b
# SM_ExecutiveDesk
# SM_AVP1_Network_01
# SM_Keyboard
# SM_AVP1_Sprinkler_01
# SM_Mousepad
# SM_AVP1_Vent_01
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_DeskLamp
# SM_AVP1_Coax_01
# SM_tv_a
# SM_Keyboard
# SM_Laptop
# SM_Vase
# SM_Window
# SM_monitor_b_stand
# SM_AVP1_Sprinkler_01
# SM_keyboard_b
# SM_Door
# SM_Globe
# SM_AVP1_Power_01
# SM_monitor_c
# SM_mouse_c
# SM_PencilPot
# SM_AVP1_Dimmer_01
# SM_monitor_b
# SM_Vase2
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_SmokeDetector_02
# SM_TableRound
# SM_AVP1_Power_03
# SM_AVP1_Power_01
# SM_TableRound
# SM_AVP1_Multimedia_01
# SM_Monitor
# SM_monitor_c
# SM_AVP1_Sprinkler_01
# SM_AVP1_Thermo_02
# SM_projector_a
# SM_AVP1_Network_01
# SM_AVP1_Switch_04
# SM_AVP1_Dimmer_01
# SM_VisitorChair
# SM_monitor_a_stand
# SM_Couch
# SM_monitor_b
# SM_Vase
# SM_monitor_d
# SM_computer_c
# SM_monitor_c
# SM_keyboard_c
# SM_computer_c
# SM_Door
# SM_AVP1_Motion_01
# SM_monitor_b_stand
# SM_AVP1_Intercom_01
# SM_paper_sherdder_a
# SM_Vase2
# SM_laptop_a
# SM_AVP1_Thermo_01
# SM_DeskTray
# SM_AVP1_Power_03
# SM_Vase1
# SM_printer_big_a
# SM_AVP1_Thermo_02
# SM_keyboard_a
# SM_AVP1_Light_01
# SM_Vase
# SM_headphones_a
# SM_AVP1_Thermo_02
# SM_monitor_b_stand
# SM_monitor_d
# SM_DeskTray
# SM_AVP1_Slider_01
# SM_Vase
# SM_AVP1_Hook_01
# SM_AVP1_Switch_04
# SM_Monitor
# SM_telephone_a
# SM_Monitor
# SM_monitor_b_stand
# SM_AVP1_Motion_01
# SM_speaker_b
# SM_tv_a_wall
# SM_VisitorChair
# SM_Couch
# SM_monitor_c
# SM_AVP1_Switch_01
# SM_computer_a
# SM_monitor_a_screen
# SM_Window
# SM_Globe
# SM_AVP1_Light_01
# SM_AVP1_Motion_01
# SM_Vase
# SM_mouse_b
# SM_monitor_b_stand
# SM_ExecutiveDesk
# SM_scaner_a_open
# SM_TableRound
# SM_keyboard_b
# SM_AVP1_Intercom_01
# SM_TableRound
# SM_computer_a
# SM_mouse_a
# SM_AVP1_Switch_03
# SM_mouse_a
# SM_Globe
# SM_AVP1_Coax_01
# SM_keyboard_c
# SM_Stairs
# SM_AVP1_Switch_02
# SM_AVP1_Switch_01
# SM_computer_b
# SM_PencilPot
# SM_monitor_a_stand
# SM_Window
# SM_AVP1_Power_05
# SM_TableRound
# SM_monitor_b_stand
# SM_Door
# SM_Shelf
# SM_Laptop
# SM_laptop_a_closed
# SM_Shelf
# SM_tv_a_wall
# SM_scaner_a
# SM_AVP1_Slider_01
# SM_scaner_a_open
# SM_computer_a
# SM_ExecutiveChair
# SM_tv_a
# SM_ExecutiveDesk
# SM_AVP1_Power_03
# SM_laptop_a
# SM_Chair
# SM_Keyboard
# SM_monitor_d
# SM_speaker_b
# SM_PencilPot
# SM_AVP1_Switch_03
# SM_monitor_a_screen
# SM_Chair
# SM_tv_a_wall
# SM_Mouse
# SM_laptop_a
# SM_laptop_a_closed
# SM_AVP1_Sprinkler_01
# SM_mouse_a
# SM_monitor_c
# SM_tv_a_wall
# SM_Couch
# SM_DoorFrame
# SM_Chair
# SM_VisitorChair
# SM_mouse_c
# SM_speaker_a_SM_speaker_a
# SM_DeskLamp
# SM_mouse_b
# SM_AVP1_Dimmer_01
# SM_VisitorChair
# SM_PencilPot
# SM_Chair
# SM_AVP1_Light_01
# SM_TableRound
# SM_AVP1_Switch_02
# SM_AVP1_Coax_01
# SM_monitor_a_screen
# SM_AVP1_Thermo_01
# SM_AVP1_Network_01
# SM_AVP1_Power_04
# SM_Door
# SM_headphones_a
# SM_laptop_a
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_04
# SM_Shelf
# SM_mouse_a
# SM_monitor_a_screen
# SM_computer_b
# SM_laptop_a
# SM_Laptop
# SM_keyboard_a
# SM_AVP1_Plate_01
# SM_AVP1_Power_05
# SM_AVP1_Rocker_01
# SM_monitor_b_screen
# SM_computer_a
# SM_monitor_a
# SM_AVP1_Vent_02
# SM_AVP1_Multimedia_01
# SM_AVP1_Sprinkler_01
# SM_Keyboard
# SM_keyboard_a
# SM_telephone_a
# SM_AVP1_Vent_02
# SM_keyboard_c
# SM_AVP1_Switch_04
# SM_AVP1_Coax_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Thermo_01
# SM_printer_a
# SM_keyboard_c
# SM_DoorFrame
# SM_speaker_a_SM_speaker_a
# SM_Door
# SM_monitor_a_screen
# SM_AVP1_Power_03
# SM_AVP1_Switch_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Vent_02
# SM_Couch
# SM_telephone_a
# SM_DeskTray
# SM_monitor_b_screen
# SM_Door
# SM_Chair
# SM_monitor_b_screen
# SM_Chair
# SM_AVP1_Power_03
# SM_AVP1_Rocker_02
# SM_paper_sherdder_a
# SM_DoorFrame
# SM_telephone_a
# SM_monitor_b_screen
# SM_AVP1_Network_01
# SM_Vase1
# SM_scaner_a
# SM_mouse_a
# SM_AVP1_Keypad_01
# SM_Monitor
# SM_projector_a
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Keypad_01
# SM_monitor_a_screen
# SM_projector_a
# SM_Mouse
# SM_monitor_b_screen
# SM_AVP1_Vent_01
# SM_AVP1_Slider_01
# SM_monitor_a_stand
# SM_DeskTray
# SM_tv_a_wall
# SM_scaner_a
# SM_AVP1_Power_04
# SM_Door
# SM_AVP1_Hook_01
# SM_AVP1_Hook_01
# SM_laptop_a_closed
# SM_Door
# SM_headphones_a
# SM_tv_a_wall
# SM_keyboard_c
# SM_AVP1_Thermo_01
# SM_Door
# SM_computer_a
# SM_projector_a
# SM_Laptop
# SM_AVP1_Network_01
# SM_printer_a
# SM_AVP1_Power_01
# SM_keyboard_c
# SM_AVP1_Keypad_01
# SM_AVP1_Thermo_02
# SM_AVP1_Keypad_01
# SM_paper_sherdder_a
# SM_AVP1_Switch_03
# SM_AVP1_Power_02
# SM_headphones_a
# SM_AVP1_Coax_01
# SM_mouse_c
# SM_AVP1_Slider_01
# SM_AVP1_Keypad_01
# SM_Couch
# SM_AVP1_Coax_01
# SM_scaner_a
# SM_Window
# SM_Laptop
# SM_DoorFrame
# SM_Door
# SM_DeskTray
# SM_VisitorChair
# SM_AVP1_Network_01
# SM_Chair
# SM_AVP1_Hook_01
# SM_monitor_b
# SM_Monitor
# SM_laptop_a
# SM_printer_big_a
# SM_Vase
# SM_AVP1_Power_03
# SM_keyboard_a
# SM_AVP1_Rocker_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Vent_02
# SM_DeskLamp
# SM_monitor_b
# SM_AVP1_Switch_03
# SM_AVP1_Switch_03
# SM_laptop_a_closed
# SM_AVP1_Keypad_01
# SM_mouse_b
# SM_Vase1
# SM_projector_a
# SM_DoorFrame
# SM_AVP1_Plate_01
# SM_ExecutiveChair
# SM_AVP1_Power_01
# SM_scaner_a_open
# SM_tv_a_wall
# SM_DeskLamp
# SM_AVP1_Thermo_01
# SM_ExecutiveChair
# SM_telephone_a
# SM_monitor_b
# SM_AVP1_Multimedia_01
# SM_Shelf
# SM_AVP1_Power_02
# SM_DoorFrame
# SM_AVP1_Multimedia_01
# SM_mouse_a
# SM_mouse_b
# SM_Mouse
# SM_monitor_b
# SM_AVP1_Vent_01
# SM_Laptop
# SM_Cabinet
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Power_02
# SM_Couch
# SM_printer_big_a
# SM_Couch
# SM_AVP1_Thermo_01
# SM_mouse_c
# SM_scaner_a
# SM_AVP1_Switch_01
# SM_monitor_b_stand
# SM_AVP1_Switch_01
# SM_AVP1_Motion_01
# SM_Door
# SM_laptop_a
# SM_Shelf
# SM_monitor_b
# SM_monitor_a_stand
# SM_Monitor
# SM_Vase2
# SM_monitor_a_stand
# SM_AVP1_Vent_01
# SM_AVP1_Light_01
# SM_AVP1_Power_04
# SM_ExecutiveChair
# SM_tv_a
# SM_Couch
# SM_Monitor
# SM_tv_a_wall
# SM_computer_a
# SM_tv_a
# SM_laptop_a_closed
# SM_keyboard_c
# SM_AVP1_Thermo_01
# SM_Cabinet
# SM_monitor_a_stand
# SM_telephone_a
# SM_monitor_c
# SM_Window
# SM_AVP1_Coax_01
# SM_Vase2
# SM_ExecutiveChair
# SM_AVP1_Network_01
# SM_ExecutiveDesk
# SM_AVP1_Switch_03
# SM_Monitor
# SM_scaner_a_open
# SM_AVP1_Light_01
# SM_Vase2
# SM_printer_a
# SM_TableRound
# SM_headphones_a
# SM_monitor_a
# SM_monitor_b_stand
# SM_Vase
# SM_tv_a
# SM_Globe
# SM_AVP1_Plate_01
# SM_AVP1_Thermo_01
# SM_Couch
# SM_telephone_a
# SM_Chair
# SM_VisitorChair
# SM_AVP1_SmokeDetector_02
# SM_Monitor
# SM_PencilPot
# SM_monitor_c
# SM_AVP1_Multimedia_01
# SM_Laptop
# SM_monitor_c
# SM_AVP1_Rocker_02
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_AVP1_Motion_01
# SM_laptop_a
# SM_AVP1_Rocker_02
# SM_keyboard_a
# SM_monitor_d
# SM_Keyboard
# SM_scaner_a
# SM_AVP1_Thermo_02
# SM_telephone_a
# SM_AVP1_Power_03
# SM_Keyboard
# SM_AVP1_Switch_04
# SM_Keyboard
# SM_scaner_a
# SM_scaner_a_open
# SM_AVP1_Switch_04
# SM_laptop_a_closed
# SM_Vase
# SM_Laptop
# SM_mouse_b
# SM_Stairs
# SM_AVP1_Dimmer_01
# SM_laptop_a
# SM_Vase1
# SM_AVP1_Slider_01
# SM_AVP1_Intercom_01
# SM_mouse_a
# SM_monitor_b_stand
# SM_AVP1_Keypad_01
# SM_Globe
# SM_speaker_b
# SM_DeskTray
# SM_AVP1_Hook_01
# SM_keyboard_b
# SM_AVP1_Light_01
# SM_DeskTray
# SM_laptop_a
# SM_AVP1_Power_05
# SM_mouse_a
# SM_printer_a
# SM_AVP1_Plate_01
# SM_scaner_a
# SM_AVP1_Intercom_01
# SM_ExecutiveChair
# SM_AVP1_Multimedia_01
# SM_mouse_a
# SM_computer_a
# SM_tv_a_wall
# SM_laptop_a
# SM_AVP1_Light_01
# SM_AVP1_Switch_03
# SM_keyboard_a
# SM_AVP1_Slider_01
# SM_AVP1_Light_01
# SM_tv_a_wall
# SM_telephone_a
# SM_DeskLamp
# SM_AVP1_Rocker_02
# SM_Chair
# SM_mouse_c
# SM_telephone_a
# SM_AVP1_Plate_01
# SM_Stairs
# SM_monitor_a_screen
# SM_Shelf
# SM_Stairs
# SM_AVP1_Thermo_01
# SM_monitor_b_screen
# SM_AVP1_Sprinkler_01
# SM_keyboard_c
# SM_keyboard_c
# SM_computer_b
# SM_Chair
# SM_monitor_b
# SM_AVP1_Slider_01
# SM_AVP1_Sprinkler_01
# SM_AVP1_Motion_01
# SM_speaker_a_SM_speaker_a
# SM_DeskLamp
# SM_AVP1_Switch_03
# SM_Globe
# SM_AVP1_Coax_01
# SM_AVP1_Vent_01
# SM_Chair
# SM_monitor_b_screen
# SM_AVP1_SmokeDetector_01
# SM_VisitorChair
# SM_DeskLamp
# SM_AVP1_SmokeDetector_01
# SM_telephone_a
# SM_paper_sherdder_a
# SM_Monitor
# SM_AVP1_Power_01
# SM_AVP1_Sprinkler_01
# SM_DeskTray
# SM_Chair
# SM_mouse_b
# SM_AVP1_Plate_01
# SM_Door
# SM_keyboard_a
# SM_monitor_a_stand
# SM_Monitor
# SM_AVP1_SmokeDetector_02
# SM_Globe
# SM_AVP1_Motion_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Hook_01
# SM_paper_sherdder_a
# SM_telephone_a
# SM_DoorFrame
# SM_Shelf
# SM_tv_a_wall
# SM_DoorFrame
# SM_AVP1_Hook_01
# SM_AVP1_Rocker_01
# SM_Keyboard
# SM_AVP1_Coax_01
# SM_Mouse
# SM_Door
# SM_AVP1_Light_01
# SM_Mousepad
# SM_Couch
# SM_Keyboard
# SM_AVP1_Switch_04
# SM_AVP1_Power_01
# SM_keyboard_a
# SM_AVP1_Power_03
# SM_AVP1_Dimmer_01
# SM_Cabinet
# SM_AVP1_Switch_01
# SM_monitor_a_screen
# SM_scaner_a
# SM_tv_a_wall
# SM_printer_big_a
# SM_AVP1_Rocker_02
# SM_keyboard_b
# SM_AVP1_Slider_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Thermo_01
# SM_Door
# SM_Keyboard
# SM_Couch
# SM_printer_big_a
# SM_DoorFrame
# SM_laptop_a_closed
# SM_tv_a_wall
# SM_AVP1_Power_06
# SM_Chair
# SM_ExecutiveDesk
# SM_PencilPot
# SM_Door
# SM_DoorFrame
# SM_AVP1_Sprinkler_01
# SM_printer_big_a
# SM_mouse_c
# SM_Shelf
# SM_Chair
# SM_VisitorChair
# SM_laptop_a
# SM_AVP1_SmokeDetector_02
# SM_Chair
# SM_Monitor
# SM_DeskTray
# SM_AVP1_Power_06
# SM_AVP1_SmokeDetector_01
# SM_Mousepad
# SM_AVP1_Vent_02
# SM_Chair
# SM_speaker_a_SM_speaker_a
# SM_tv_a
# SM_AVP1_Power_02
# SM_paper_sherdder_a
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_headphones_a
# SM_AVP1_Slider_01
# SM_mouse_c
# SM_DoorFrame
# SM_mouse_a
# SM_AVP1_Rocker_02
# SM_Window
# SM_AVP1_Motion_01
# SM_Shelf
# SM_AVP1_Multimedia_01
# SM_Chair
# SM_computer_b
# SM_AVP1_Power_02
# SM_Monitor
# SM_scaner_a
# SM_Shelf
# SM_AVP1_Thermo_01
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_01
# SM_Window
# SM_Mouse
# SM_paper_sherdder_a
# SM_monitor_a_screen
# SM_Monitor
# SM_monitor_a_stand
# SM_AVP1_Power_02
# SM_Monitor
# SM_printer_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Power_02
# SM_AVP1_Motion_01
# SM_AVP1_Power_01
# SM_keyboard_c
# SM_AVP1_Motion_01
# SM_Chair
# SM_speaker_a_SM_speaker_a
# SM_Stairs
# SM_telephone_a
# SM_AVP1_Power_03
# SM_AVP1_Power_04
# SM_AVP1_Power_05
# SM_AVP1_Power_02
# SM_AVP1_Switch_03
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_01
# SM_AVP1_Hook_01
# SM_DoorFrame
# SM_monitor_a_screen
# SM_DeskTray
# SM_VisitorChair
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Switch_03
# SM_keyboard_a
# SM_monitor_b_screen
# SM_keyboard_c
# SM_AVP1_SmokeDetector_02
# SM_Vase2
# SM_AVP1_Switch_03
# SM_AVP1_Coax_01
# SM_AVP1_Plate_01
# SM_AVP1_Switch_04
# SM_laptop_a
# SM_AVP1_Switch_01
# SM_AVP1_Intercom_01
# SM_monitor_b_screen
# SM_Shelf
# SM_computer_b
# SM_AVP1_Slider_01
# SM_Window
# SM_AVP1_Network_01
# SM_mouse_a
# SM_AVP1_Rocker_01
# SM_AVP1_Vent_02
# SM_printer_big_a
# SM_AVP1_Intercom_01
# SM_Stairs
# SM_AVP1_Motion_01
# SM_Laptop
# SM_AVP1_Power_03
# SM_DeskLamp
# SM_AVP1_Power_06
# SM_monitor_b_screen
# SM_AVP1_Power_04
# SM_laptop_a_closed
# SM_AVP1_Light_01
# SM_TableRound
# SM_AVP1_Dimmer_01
# SM_scaner_a_open
# SM_mouse_a
# SM_AVP1_Rocker_02
# SM_Vase1
# SM_AVP1_Power_06
# SM_AVP1_Plate_01
# SM_headphones_a
# SM_Keyboard
# SM_AVP1_Hook_01
# SM_VisitorChair
# SM_Door
# SM_AVP1_Switch_04
# SM_mouse_a
# SM_mouse_b
# SM_AVP1_Switch_04
# SM_AVP1_Thermo_02
# SM_AVP1_Power_06
# SM_Shelf
# SM_AVP1_SmokeDetector_01
# SM_keyboard_a
# SM_AVP1_Light_01
# SM_AVP1_Network_01
# SM_DeskLamp
# SM_tv_a_wall
# SM_TableRound
# SM_Chair
# SM_Mousepad
# SM_DoorFrame
# SM_speaker_b
# SM_tv_a_wall
# SM_Mouse
# SM_AVP1_Thermo_02
# SM_AVP1_Rocker_02
# SM_AVP1_Power_04
# SM_Door
# SM_AVP1_Power_06
# SM_AVP1_Dimmer_01
# SM_keyboard_b
# SM_Couch
# SM_AVP1_SmokeDetector_01
# SM_monitor_d
# SM_AVP1_Switch_04
# SM_DoorFrame
# SM_headphones_a
# SM_scaner_a
# SM_Laptop
# SM_AVP1_Switch_04
# SM_Shelf
# SM_printer_a
# SM_scaner_a
# SM_DeskTray
# SM_AVP1_Power_01
# SM_tv_a_wall
# SM_Mouse
# SM_Laptop
# SM_AVP1_Power_06
# SM_monitor_b_stand
# SM_paper_sherdder_a
# SM_Monitor
# SM_AVP1_Network_01
# SM_Mousepad
# SM_monitor_a_stand
# SM_AVP1_Switch_02
# SM_mouse_c
# SM_Laptop
# SM_scaner_a
# SM_printer_a
# SM_headphones_a
# SM_AVP1_Multimedia_01
# SM_AVP1_SmokeDetector_02
# SM_monitor_b_stand
# SM_monitor_b
# SM_PencilPot
# SM_AVP1_Vent_02
# SM_monitor_a_stand
# SM_VisitorChair
# SM_monitor_b_stand
# SM_AVP1_Multimedia_01
# SM_printer_a
# SM_AVP1_Dimmer_01
# SM_scaner_a
# SM_ExecutiveDesk
# SM_AVP1_Coax_01
# SM_printer_a
# SM_DeskLamp
# SM_laptop_a
# SM_monitor_a
# SM_monitor_a_stand
# SM_ExecutiveDesk
# SM_AVP1_Motion_01
# SM_ExecutiveDesk
# SM_AVP1_Multimedia_01
# SM_Couch
# SM_monitor_b_screen
# SM_Mousepad
# SM_AVP1_Switch_04
# SM_monitor_c
# SM_monitor_c
# SM_Chair
# SM_Chair
# SM_VisitorChair
# SM_AVP1_Thermo_01
# SM_monitor_a
# SM_laptop_a_closed
# SM_Chair
# SM_monitor_a
# SM_Door
# SM_Keyboard
# SM_AVP1_Slider_01
# SM_monitor_a
# SM_mouse_a
# SM_AVP1_Motion_01
# SM_TableRound
# SM_AVP1_Multimedia_01
# SM_Monitor
# SM_DoorFrame
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Motion_01
# SM_Stairs
# SM_Couch
# SM_ExecutiveChair
# SM_AVP1_Switch_04
# SM_AVP1_Rocker_02
# SM_mouse_c
# SM_AVP1_Switch_02
# SM_AVP1_Rocker_02
# SM_Door
# SM_headphones_a
# SM_tv_a
# SM_AVP1_Keypad_01
# SM_computer_b
# SM_monitor_c
# SM_Door
# SM_DeskLamp
# SM_AVP1_Switch_01
# SM_Cabinet
# SM_AVP1_Thermo_02
# SM_computer_a
# SM_computer_b
# SM_AVP1_Slider_01
# SM_AVP1_Dimmer_01
# SM_laptop_a_closed
# SM_AVP1_Coax_01
# SM_speaker_b
# SM_AVP1_Switch_03
# SM_AVP1_Switch_01
# SM_mouse_c
# SM_projector_a
# SM_AVP1_Plate_01
# SM_keyboard_b
# SM_AVP1_Switch_01
# SM_laptop_a
# SM_keyboard_b
# SM_Vase2
# SM_AVP1_Thermo_01
# SM_Laptop
# SM_Monitor
# SM_AVP1_Vent_01
# SM_computer_c
# SM_Vase1
# SM_computer_a
# SM_AVP1_Power_06
# SM_monitor_b_screen
# SM_AVP1_Slider_01
# SM_monitor_b_screen
# SM_monitor_b
# SM_printer_a
# SM_monitor_d
# SM_VisitorChair
# SM_Stairs
# SM_computer_b
# SM_Shelf
# SM_monitor_c
# SM_AVP1_Network_01
# SM_Chair
# SM_Vase
# SM_DoorFrame
# SM_DoorFrame
# SM_Monitor
# SM_TableRound
# ...
# SM_AVP1_Slider_01
# SM_keyboard_b
# SM_AVP1_Power_03
# SM_AVP1_Power_03
# SM_DoorFrame
# SM_tv_a
# SM_Vase2
# SM_AVP1_Coax_01
# SM_AVP1_Switch_01
# SM_mouse_b
# SM_AVP1_Switch_04
# SM_AVP1_SmokeDetector_02
# SM_Vase2
# SM_headphones_a
# SM_Monitor
# SM_VisitorChair
# SM_AVP1_Power_04
# SM_Couch
# SM_Mouse
# SM_Vase1
# SM_Chair
# SM_scaner_a
# SM_AVP1_Power_01
# SM_DeskLamp
# SM_Mousepad
# SM_DoorFrame
# SM_printer_a
# SM_AVP1_Power_01
# SM_Monitor
# SM_TableRound
# SM_telephone_a
# SM_AVP1_Sprinkler_01
# SM_AVP1_Power_02
# SM_keyboard_c
# SM_DeskLamp
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Keypad_01
# SM_monitor_d
# SM_mouse_a
# SM_projector_a
# SM_AVP1_Power_02
# SM_AVP1_Keypad_01
# SM_paper_sherdder_a
# SM_keyboard_b
# SM_mouse_c
# SM_AVP1_SmokeDetector_01
# SM_printer_a
# SM_Door
# SM_DeskLamp
# SM_mouse_c
# SM_Chair
# SM_Globe
# SM_mouse_b
# SM_Vase
# SM_keyboard_a
# SM_AVP1_Motion_01
# SM_AVP1_Light_01
# SM_DeskTray
# SM_Chair
# SM_mouse_c
# SM_Chair
# SM_AVP1_Thermo_01
# SM_speaker_b
# SM_Window
# SM_computer_a
# SM_monitor_b_stand
# SM_scaner_a_open
# SM_AVP1_Power_02
# SM_PencilPot
# SM_projector_a
# SM_Door
# SM_AVP1_Coax_01
# SM_mouse_c
# SM_speaker_b
# SM_PencilPot
# SM_DoorFrame
# SM_Shelf
# SM_AVP1_Power_04
# SM_Vase
# SM_Mousepad
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_printer_a
# SM_monitor_a_screen
# SM_computer_b
# SM_Vase1
# SM_mouse_a
# SM_AVP1_Intercom_01
# SM_monitor_b_stand
# SM_Monitor
# SM_monitor_a
# SM_AVP1_Network_01
# SM_monitor_a_stand
# SM_keyboard_c
# SM_computer_a
# SM_keyboard_a
# SM_mouse_b
# SM_AVP1_Rocker_01
# SM_AVP1_Coax_01
# SM_Globe
# SM_TableRound
# SM_PencilPot
# SM_AVP1_Slider_01
# SM_mouse_a
# SM_Door
# SM_AVP1_Switch_01
# SM_AVP1_Power_04
# SM_AVP1_Slider_01
# SM_AVP1_Motion_01
# SM_tv_a
# SM_AVP1_Thermo_02
# SM_VisitorChair
# SM_ExecutiveDesk
# SM_monitor_c
# SM_Cabinet
# SM_Chair
# SM_Vase2
# SM_AVP1_Power_06
# SM_keyboard_c
# SM_telephone_a
# SM_computer_b
# SM_ExecutiveDesk
# SM_ExecutiveChair
# SM_computer_b
# SM_ExecutiveChair
# SM_speaker_b
# SM_printer_a
# SM_Door
# SM_computer_a
# SM_AVP1_Thermo_02
# SM_Globe
# SM_AVP1_Hook_01
# SM_Monitor
# SM_Door
# SM_AVP1_Slider_01
# SM_AVP1_Multimedia_01
# SM_scaner_a_open
# SM_laptop_a
# SM_AVP1_Motion_01
# SM_Door
# SM_paper_sherdder_a
# SM_Chair
# SM_AVP1_Coax_01
# SM_Vase1
# SM_AVP1_Sprinkler_01
# SM_Chair
# SM_keyboard_a
# SM_printer_a
# SM_Shelf
# SM_AVP1_Slider_01
# SM_mouse_b
# SM_AVP1_Power_01
# SM_projector_a
# SM_monitor_c
# SM_AVP1_Thermo_02
# SM_AVP1_Vent_02
# SM_AVP1_Switch_02
# SM_AVP1_Dimmer_01
# SM_TableRound
# SM_monitor_d
# SM_AVP1_Rocker_01
# SM_laptop_a
# SM_AVP1_Rocker_02
# SM_AVP1_Plate_01
# SM_keyboard_b
# SM_speaker_a_SM_speaker_a
# SM_VisitorChair
# SM_monitor_a_screen
# SM_Mousepad
# SM_monitor_d
# SM_AVP1_Motion_01
# SM_telephone_a
# SM_VisitorChair
# SM_telephone_a
# SM_AVP1_SmokeDetector_01
# SM_monitor_c
# SM_AVP1_Power_01
# SM_Mouse
# SM_paper_sherdder_a
# SM_AVP1_Motion_01
# SM_AVP1_Coax_01
# SM_AVP1_Switch_01
# SM_keyboard_b
# SM_AVP1_Rocker_02
# SM_laptop_a
# SM_AVP1_SmokeDetector_02
# SM_Monitor
# SM_tv_a
# SM_Keyboard
# SM_Monitor
# SM_AVP1_Switch_03
# SM_tv_a
# SM_PencilPot
# SM_Shelf
# SM_projector_a
# SM_speaker_b
# SM_Vase
# SM_Cabinet
# SM_AVP1_Power_03
# SM_scaner_a
# SM_tv_a_wall
# SM_Mouse
# SM_Vase1
# SM_mouse_b
# SM_AVP1_Power_01
# SM_ExecutiveDesk
# SM_monitor_c
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Intercom_01
# SM_AVP1_Switch_03
# SM_AVP1_Thermo_02
# SM_AVP1_Light_01
# SM_Stairs
# SM_AVP1_Switch_04
# SM_PencilPot
# SM_computer_a
# SM_monitor_a
# SM_Laptop
# SM_AVP1_Light_01
# SM_telephone_a
# SM_ExecutiveDesk
# SM_AVP1_Dimmer_01
# SM_AVP1_Power_02
# SM_Shelf
# SM_paper_sherdder_a
# SM_Laptop
# SM_Cabinet
# SM_Monitor
# SM_telephone_a
# SM_laptop_a_closed
# SM_AVP1_Power_02
# SM_keyboard_c
# SM_Globe
# SM_Mouse
# SM_Door
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Vent_02
# SM_AVP1_Slider_01
# SM_laptop_a_closed
# SM_AVP1_Switch_04
# SM_monitor_d
# SM_headphones_a
# SM_Chair
# SM_laptop_a_closed
# SM_Stairs
# SM_speaker_b
# SM_Window
# SM_DoorFrame
# SM_AVP1_SmokeDetector_02
# SM_printer_a
# SM_AVP1_Power_05
# SM_speaker_a_SM_speaker_a
# SM_printer_big_a
# SM_Stairs
# SM_ExecutiveChair
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Switch_03
# SM_monitor_a_screen
# SM_Laptop
# SM_mouse_b
# SM_Vase1
# SM_scaner_a
# SM_TableRound
# SM_speaker_b
# SM_Laptop
# SM_AVP1_SmokeDetector_02
# SM_Vase
# SM_DoorFrame
# SM_AVP1_Power_04
# SM_AVP1_Light_01
# SM_AVP1_Switch_02
# SM_printer_big_a
# SM_keyboard_c
# SM_printer_big_a
# SM_AVP1_Switch_02
# SM_keyboard_b
# SM_AVP1_Keypad_01
# SM_monitor_b_stand
# SM_speaker_a_SM_speaker_a
# SM_monitor_a_screen
# SM_Mousepad
# SM_telephone_a
# SM_scaner_a_open
# SM_AVP1_Power_05
# SM_mouse_a
# SM_Vase1
# SM_monitor_a
# SM_AVP1_Plate_01
# SM_AVP1_Light_01
# SM_computer_b
# SM_AVP1_Light_01
# SM_Mouse
# SM_monitor_b_screen
# SM_AVP1_Dimmer_01
# SM_keyboard_a
# SM_AVP1_Power_05
# SM_DeskTray
# SM_ExecutiveChair
# SM_AVP1_Motion_01
# SM_headphones_a
# SM_AVP1_Rocker_02
# SM_mouse_a
# SM_headphones_a
# SM_AVP1_Vent_02
# SM_AVP1_Light_01
# SM_AVP1_Multimedia_01
# SM_AVP1_Light_01
# SM_AVP1_Power_05
# SM_mouse_b
# SM_Vase2
# SM_ExecutiveChair
# SM_computer_b
# SM_AVP1_Switch_03
# SM_AVP1_Keypad_01
# SM_paper_sherdder_a
# SM_AVP1_Switch_03
# SM_Mouse
# SM_AVP1_Power_03
# SM_Vase1
# SM_AVP1_Power_05
# SM_AVP1_Rocker_01
# SM_AVP1_Motion_01
# SM_telephone_a
# SM_computer_c
# SM_monitor_a_screen
# SM_mouse_a
# SM_telephone_a
# SM_AVP1_Vent_02
# SM_AVP1_Slider_01
# SM_AVP1_Thermo_01
# SM_keyboard_c
# SM_AVP1_Multimedia_01
# SM_speaker_a_SM_speaker_a
# SM_Monitor
# SM_tv_a_wall
# SM_Chair
# SM_AVP1_Hook_01
# SM_paper_sherdder_a
# SM_DoorFrame
# SM_mouse_b
# SM_mouse_c
# SM_AVP1_Switch_01
# SM_computer_a
# SM_ExecutiveDesk
# SM_projector_a
# SM_scaner_a
# SM_AVP1_Dimmer_01
# SM_AVP1_Light_01
# SM_AVP1_Thermo_02
# SM_PencilPot
# SM_AVP1_Switch_02
# SM_tv_a_wall
# SM_Vase
# SM_laptop_a
# SM_tv_a
# SM_Vase
# SM_ExecutiveDesk
# SM_Globe
# SM_scaner_a
# SM_AVP1_Power_01
# SM_DeskTray
# SM_mouse_c
# SM_DoorFrame
# SM_headphones_a
# SM_Mousepad
# SM_DeskTray
# SM_AVP1_Slider_01
# SM_AVP1_Intercom_01
# SM_headphones_a
# SM_AVP1_Power_01
# SM_Stairs
# SM_monitor_b
# SM_AVP1_Multimedia_01
# SM_AVP1_Vent_01
# SM_tv_a
# SM_scaner_a
# SM_Monitor
# SM_computer_a
# SM_AVP1_Intercom_01
# SM_keyboard_a
# SM_AVP1_Slider_01
# SM_scaner_a_open
# SM_Monitor
# SM_AVP1_Vent_01
# SM_AVP1_Keypad_01
# SM_AVP1_Dimmer_01
# SM_PencilPot
# SM_scaner_a
# SM_AVP1_Rocker_01
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Plate_01
# SM_TableRound
# SM_Chair
# SM_AVP1_Motion_01
# SM_monitor_b_screen
# SM_AVP1_Light_01
# SM_monitor_a_stand
# SM_AVP1_Switch_03
# SM_Chair
# SM_speaker_b
# SM_Vase1
# SM_laptop_a
# SM_Laptop
# SM_monitor_b_stand
# SM_monitor_d
# SM_AVP1_Power_06
# SM_AVP1_Hook_01
# SM_computer_a
# SM_Shelf
# SM_AVP1_Intercom_01
# SM_AVP1_Intercom_01
# SM_Keyboard
# SM_Monitor
# SM_telephone_a
# SM_Shelf
# SM_AVP1_SmokeDetector_01
# SM_printer_a
# SM_Door
# SM_AVP1_Rocker_02
# SM_PencilPot
# SM_AVP1_Switch_04
# SM_AVP1_Switch_02
# SM_Vase1
# SM_AVP1_Motion_01
# SM_DeskTray
# SM_keyboard_a
# SM_scaner_a_open
# SM_Laptop
# SM_monitor_c
# SM_AVP1_SmokeDetector_01
# SM_monitor_a_screen
# SM_DeskTray
# SM_mouse_a
# SM_AVP1_Dimmer_01
# SM_laptop_a
# SM_AVP1_Switch_04
# SM_Stairs
# SM_monitor_b_stand
# SM_paper_sherdder_a
# SM_Monitor
# SM_projector_a
# SM_AVP1_Power_05
# SM_AVP1_Power_01
# SM_headphones_a
# SM_tv_a
# SM_monitor_a_stand
# SM_VisitorChair
# SM_ExecutiveChair
# SM_AVP1_Switch_03
# SM_mouse_a
# SM_keyboard_c
# SM_AVP1_Coax_01
# SM_Door
# SM_computer_c
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Rocker_01
# SM_mouse_b
# SM_AVP1_Power_06
# SM_AVP1_Dimmer_01
# SM_scaner_a
# SM_Mousepad
# SM_AVP1_Network_01
# SM_monitor_b_screen
# SM_computer_b
# SM_scaner_a_open
# SM_paper_sherdder_a
# SM_keyboard_c
# SM_scaner_a
# SM_AVP1_Dimmer_01
# SM_keyboard_a
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Thermo_01
# SM_AVP1_Coax_01
# SM_computer_a
# SM_Mouse
# SM_AVP1_Switch_02
# SM_monitor_d
# SM_AVP1_Keypad_01
# SM_ExecutiveDesk
# SM_monitor_b_screen
# SM_AVP1_Power_02
# SM_Globe
# SM_monitor_a_stand
# SM_projector_a
# SM_AVP1_Dimmer_01
# SM_Mousepad
# SM_AVP1_Power_03
# SM_AVP1_Power_01
# SM_Door
# SM_AVP1_SmokeDetector_02
# SM_keyboard_b
# SM_AVP1_Hook_01
# SM_monitor_b_stand
# SM_ExecutiveDesk
# SM_monitor_b_stand
# SM_Chair
# SM_keyboard_c
# SM_AVP1_Keypad_01
# SM_mouse_c
# SM_speaker_b
# SM_AVP1_Network_01
# SM_TableRound
# SM_Stairs
# SM_AVP1_SmokeDetector_01
# SM_mouse_b
# SM_speaker_b
# SM_monitor_b
# SM_AVP1_Rocker_02
# SM_speaker_a_SM_speaker_a
# SM_monitor_b_screen
# SM_speaker_a_SM_speaker_a
# SM_Shelf
# SM_monitor_b_screen
# SM_scaner_a
# SM_AVP1_Thermo_02
# SM_AVP1_SmokeDetector_01
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Power_05
# SM_monitor_a_screen
# SM_AVP1_Motion_01
# SM_printer_a
# SM_AVP1_Switch_02
# SM_Mouse
# SM_monitor_b_stand
# SM_printer_a
# SM_AVP1_Rocker_01
# SM_keyboard_c
# SM_PencilPot
# SM_Chair
# SM_monitor_b
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Thermo_01
# SM_scaner_a
# SM_monitor_b_screen
# SM_Vase1
# SM_Door
# SM_scaner_a_open
# SM_ExecutiveDesk
# SM_AVP1_Keypad_01
# SM_Globe
# SM_scaner_a_open
# SM_Keyboard
# SM_DeskLamp
# SM_tv_a_wall
# SM_AVP1_Power_03
# SM_ExecutiveDesk
# SM_speaker_b
# SM_Vase1
# SM_AVP1_Switch_04
# SM_AVP1_Power_06
# SM_AVP1_Network_01
# SM_keyboard_b
# SM_monitor_b_screen
# SM_Window
# SM_scaner_a
# SM_Door
# SM_mouse_b
# SM_printer_a
# SM_scaner_a
# SM_AVP1_Motion_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Switch_03
# SM_AVP1_Rocker_01
# SM_computer_c
# SM_AVP1_Keypad_01
# SM_AVP1_Multimedia_01
# SM_Mousepad
# SM_DoorFrame
# SM_scaner_a
# SM_Shelf
# SM_AVP1_Rocker_01
# SM_printer_big_a
# SM_keyboard_c
# SM_AVP1_Sprinkler_01
# SM_ExecutiveDesk
# SM_Mousepad
# SM_AVP1_Sprinkler_01
# SM_scaner_a_open
# SM_AVP1_Coax_01
# SM_Vase1
# SM_Door
# SM_AVP1_Power_03
# SM_AVP1_Thermo_01
# SM_tv_a_wall
# SM_Laptop
# SM_speaker_a_SM_speaker_a
# SM_monitor_b
# SM_DeskLamp
# SM_mouse_a
# SM_AVP1_Power_05
# SM_Monitor
# SM_AVP1_Sprinkler_01
# SM_keyboard_a
# SM_AVP1_SmokeDetector_01
# SM_monitor_c
# SM_monitor_d
# SM_Door
# SM_AVP1_Thermo_01
# SM_TableRound
# SM_AVP1_Thermo_02
# SM_mouse_c
# SM_monitor_a_screen
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_03
# SM_AVP1_Plate_01
# SM_PencilPot
# SM_AVP1_Power_05
# SM_Monitor
# SM_monitor_b
# SM_AVP1_Plate_01
# SM_printer_big_a
# SM_AVP1_Multimedia_01
# SM_AVP1_Keypad_01
# SM_telephone_a
# SM_Mouse
# SM_headphones_a
# SM_printer_big_a
# SM_DeskLamp
# SM_Mousepad
# SM_Chair
# SM_monitor_b_stand
# SM_computer_c
# SM_printer_a
# SM_AVP1_Intercom_01
# SM_printer_a
# SM_Door
# SM_Chair
# SM_speaker_b
# SM_laptop_a
# SM_AVP1_Power_01
# SM_tv_a
# SM_AVP1_Thermo_01
# SM_laptop_a_closed
# SM_Mousepad
# SM_projector_a
# SM_printer_a
# SM_AVP1_Slider_01
# SM_Mousepad
# SM_AVP1_Keypad_01
# SM_VisitorChair
# SM_tv_a
# SM_monitor_c
# SM_Keyboard
# SM_Laptop
# SM_Cabinet
# SM_Stairs
# SM_Window
# SM_AVP1_Coax_01
# SM_DoorFrame
# SM_AVP1_Dimmer_01
# SM_AVP1_Power_06
# SM_AVP1_Plate_01
# SM_AVP1_Network_01
# SM_Door
# SM_mouse_c
# SM_AVP1_Switch_01
# SM_AVP1_Power_06
# SM_monitor_d
# SM_laptop_a_closed
# SM_PencilPot
# SM_AVP1_Network_01
# SM_scaner_a
# SM_AVP1_Switch_03
# SM_mouse_b
# SM_monitor_a_screen
# SM_TableRound
# SM_PencilPot
# SM_printer_big_a
# SM_AVP1_Power_06
# SM_Window
# SM_AVP1_Vent_01
# SM_ExecutiveDesk
# SM_Door
# SM_Globe
# SM_Cabinet
# SM_AVP1_Motion_01
# SM_Cabinet
# SM_AVP1_Switch_03
# SM_printer_a
# SM_monitor_a_screen
# SM_computer_a
# SM_ExecutiveDesk
# SM_DeskTray
# SM_AVP1_Sprinkler_01
# SM_mouse_a
# SM_AVP1_Power_06
# SM_tv_a
# SM_Vase1
# SM_Window
# SM_monitor_a_screen
# SM_AVP1_Switch_01
# SM_Vase
# SM_AVP1_Vent_01
# SM_AVP1_Power_02
# SM_monitor_a
# SM_computer_a
# SM_monitor_a
# SM_TableRound
# SM_AVP1_SmokeDetector_01
# SM_DoorFrame
# SM_AVP1_Coax_01
# SM_Laptop
# SM_AVP1_Network_01
# SM_headphones_a
# SM_monitor_b
# SM_printer_a
# SM_AVP1_SmokeDetector_01
# SM_Globe
# SM_AVP1_Coax_01
# SM_Mouse
# SM_Window
# SM_laptop_a_closed
# SM_Cabinet
# SM_printer_big_a
# SM_Mouse
# SM_AVP1_Light_01
# SM_AVP1_Switch_01
# SM_AVP1_Dimmer_01
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Power_03
# SM_AVP1_Power_04
# SM_Monitor
# SM_AVP1_Switch_04
# SM_Couch
# SM_VisitorChair
# SM_printer_a
# SM_AVP1_Switch_03
# SM_Shelf
# SM_scaner_a_open
# SM_computer_c
# SM_DeskLamp
# SM_AVP1_Coax_01
# SM_AVP1_Keypad_01
# SM_AVP1_Power_01
# SM_paper_sherdder_a
# SM_Vase1
# SM_headphones_a
# SM_scaner_a
# SM_Stairs
# SM_AVP1_Rocker_01
# SM_AVP1_Power_04
# SM_Keyboard
# SM_tv_a
# SM_laptop_a_closed
# SM_AVP1_Switch_01
# SM_AVP1_Slider_01
# SM_VisitorChair
# SM_keyboard_c
# SM_AVP1_Power_05
# SM_laptop_a
# SM_keyboard_c
# SM_Window
# SM_AVP1_Rocker_02
# SM_AVP1_Network_01
# SM_Cabinet
# SM_AVP1_Switch_02
# SM_AVP1_Motion_01
# SM_AVP1_Power_02
# SM_DeskLamp
# SM_AVP1_Vent_01
# SM_AVP1_Power_05
# SM_keyboard_b
# SM_AVP1_Multimedia_01
# SM_AVP1_Plate_01
# SM_PencilPot
# SM_Window
# SM_Cabinet
# SM_keyboard_a
# SM_AVP1_Coax_01
# SM_AVP1_Rocker_01
# SM_Mouse
# SM_computer_a
# SM_telephone_a
# SM_AVP1_Power_01
# SM_AVP1_Thermo_02
# SM_Vase
# SM_AVP1_Sprinkler_01
# SM_keyboard_c
# SM_monitor_d
# SM_Keyboard
# SM_AVP1_Network_01
# SM_AVP1_Dimmer_01
# SM_AVP1_Switch_02
# SM_monitor_b_stand
# SM_monitor_d
# SM_AVP1_Power_01
# SM_computer_a
# SM_AVP1_Coax_01
# SM_AVP1_Power_03
# SM_AVP1_Plate_01
# SM_AVP1_Switch_04
# SM_AVP1_Power_02
# SM_AVP1_Motion_01
# SM_VisitorChair
# SM_AVP1_Coax_01
# SM_tv_a
# SM_monitor_b
# SM_AVP1_Power_05
# SM_Mouse
# SM_Cabinet
# SM_Couch
# SM_Mouse
# SM_Shelf
# SM_speaker_b
# SM_AVP1_Power_05
# SM_mouse_a
# SM_AVP1_Slider_01
# SM_computer_b
# SM_Laptop
# SM_mouse_c
# SM_computer_a
# SM_Globe
# SM_telephone_a
# SM_AVP1_Thermo_01
# SM_AVP1_Keypad_01
# SM_AVP1_Switch_02
# SM_Globe
# SM_projector_a
# SM_keyboard_b
# SM_AVP1_Rocker_02
# SM_AVP1_Coax_01
# SM_tv_a
# SM_DeskTray
# SM_computer_b
# SM_AVP1_Switch_04
# SM_PencilPot
# SM_Mouse
# SM_computer_a
# SM_AVP1_Power_04
# SM_monitor_b_screen
# SM_TableRound
# SM_AVP1_Power_06
# SM_AVP1_Coax_01
# SM_computer_a
# SM_AVP1_Multimedia_01
# SM_speaker_b
# SM_keyboard_b
# SM_Cabinet
# SM_scaner_a
# SM_AVP1_Dimmer_01
# SM_scaner_a
# SM_ExecutiveDesk
# SM_monitor_a_stand
# SM_headphones_a
# SM_tv_a
# SM_Globe
# SM_AVP1_Power_06
# SM_Shelf
# SM_AVP1_Power_06
# SM_AVP1_Rocker_02
# SM_monitor_a_stand
# SM_AVP1_Power_04
# SM_Globe
# SM_monitor_b_stand
# SM_Keyboard
# SM_DoorFrame
# SM_speaker_b
# SM_AVP1_Multimedia_01
# SM_monitor_a_screen
# SM_AVP1_Vent_02
# SM_Mouse
# SM_AVP1_Rocker_01
# SM_mouse_c
# SM_laptop_a_closed
# SM_PencilPot
# SM_telephone_a
# SM_AVP1_SmokeDetector_01
# SM_telephone_a
# SM_AVP1_Rocker_01
# SM_monitor_b_screen
# SM_AVP1_Power_01
# SM_AVP1_Dimmer_01
# SM_DeskTray
# SM_keyboard_b
# SM_AVP1_Dimmer_01
# SM_Cabinet
# SM_tv_a
# SM_computer_b
# SM_AVP1_Switch_01
# SM_computer_a
# SM_keyboard_b
# SM_Vase2
# SM_Vase1
# SM_AVP1_Vent_02
# SM_tv_a_wall
# SM_monitor_b
# SM_mouse_c
# SM_keyboard_b
# SM_Mousepad
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Switch_04
# SM_Vase2
# SM_tv_a_wall
# SM_AVP1_Switch_04
# SM_Keyboard
# SM_AVP1_Sprinkler_01
# SM_AVP1_Dimmer_01
# SM_AVP1_Network_01
# SM_tv_a
# SM_AVP1_Slider_01
# SM_Vase
# SM_AVP1_Slider_01
# SM_AVP1_Sprinkler_01
# SM_tv_a_wall
# SM_speaker_a_SM_speaker_a
# SM_paper_sherdder_a
# SM_computer_a
# SM_AVP1_Intercom_01
# SM_Shelf
# SM_AVP1_Power_04
# SM_AVP1_Motion_01
# SM_AVP1_Dimmer_01
# SM_AVP1_Hook_01
# SM_AVP1_Keypad_01
# SM_Vase2
# SM_AVP1_Keypad_01
# SM_AVP1_Power_05
# SM_paper_sherdder_a
# SM_Window
# SM_Door
# SM_keyboard_a
# SM_monitor_a_screen
# SM_DeskLamp
# SM_AVP1_Power_01
# SM_AVP1_Power_06
# SM_TableRound
# SM_TableRound
# SM_AVP1_Switch_03
# SM_Chair
# SM_monitor_b_stand
# SM_monitor_a_screen
# SM_AVP1_Slider_01
# SM_Chair
# SM_AVP1_Sprinkler_01
# SM_monitor_b_screen
# SM_monitor_a_stand
# SM_AVP1_Power_06
# SM_AVP1_SmokeDetector_02
# SM_AVP1_Intercom_01
# SM_computer_a
# SM_keyboard_a
# SM_AVP1_SmokeDetector_01
# SM_PencilPot
# SM_projector_a
# SM_Door
# SM_monitor_d
# SM_AVP1_Multimedia_01
# SM_Mousepad
# SM_AVP1_Switch_01
# SM_AVP1_SmokeDetector_01
# SM_monitor_d
# SM_Monitor
# SM_tv_a_wall
# SM_AVP1_Rocker_01
# SM_AVP1_Multimedia_01
# SM_mouse_c
# SM_Window
# SM_Chair
# SM_ExecutiveChair
# SM_AVP1_Coax_01
# SM_Mouse
# SM_tv_a
# SM_Monitor
# SM_monitor_d
# SM_Laptop
# SM_computer_a
# SM_Vase
# SM_AVP1_Light_01
# SM_tv_a
# SM_Door
# SM_AVP1_Keypad_01
# SM_Vase1
# SM_ExecutiveDesk
# SM_Chair
# SM_DeskLamp
# SM_AVP1_Keypad_01
# SM_AVP1_SmokeDetector_01
# SM_AVP1_Plate_01
# SM_computer_b
# SM_tv_a
# SM_AVP1_Vent_01
# SM_keyboard_c
# SM_AVP1_Network_01
# SM_printer_a
# SM_AVP1_Dimmer_01
# SM_keyboard_b
# SM_Vase2
# SM_keyboard_c
# SM_computer_b
# SM_AVP1_Dimmer_01
# SM_Stairs
# SM_keyboard_c
# SM_laptop_a
# SM_ExecutiveChair
# SM_Door
# SM_Laptop
# SM_mouse_a
# SM_AVP1_Switch_04
# SM_scaner_a
# SM_AVP1_Rocker_01
# SM_monitor_b_stand
# SM_AVP1_Motion_01
# SM_monitor_b
# SM_Laptop
# SM_monitor_a_screen
# SM_AVP1_Power_04
# SM_Cabinet
# SM_computer_b
# SM_AVP1_Power_06
# SM_mouse_b
# SM_Chair
# SM_AVP1_Power_02
# SM_printer_a
# SM_AVP1_Thermo_02
# SM_telephone_a
# SM_computer_a
# SM_computer_a
# SM_mouse_c
# SM_printer_big_a
# SM_projector_a
# SM_monitor_b_screen
# SM_AVP1_Rocker_02
# SM_DeskLamp
# SM_Window
# SM_Laptop
# SM_Stairs
# SM_AVP1_Motion_01
# SM_AVP1_Sprinkler_01
# SM_AVP1_Rocker_02
# SM_AVP1_Power_06
# SM_mouse_b
# SM_AVP1_Switch_03
# SM_AVP1_Motion_01
# SM_AVP1_Vent_02
# SM_monitor_a
# SM_AVP1_Switch_04
# SM_Vase
# SM_AVP1_SmokeDetector_01
# SM_tv_a_wall
# SM_AVP1_Power_02
# SM_Laptop
# SM_paper_sherdder_a
# SM_ExecutiveDesk
# SM_Couch
# SM_AVP1_Multimedia_01
# SM_Laptop
# SM_AVP1_Light_01
# SM_Shelf
# SM_AVP1_Sprinkler_01
# SM_AVP1_Switch_04
# SM_speaker_a_SM_speaker_a
# SM_AVP1_Rocker_02
# SM_monitor_a_stand
# SM_Mouse
# SM_AVP1_Rocker_01
# SM_AVP1_Switch_02
# SM_PencilPot
# SM_keyboard_b
# SM_AVP1_Multimedia_01
# SM_Door
# SM_Vase2
# SM_AVP1_Rocker_02
# SM_Laptop
# SM_Vase1
# SM_PencilPot
# SM_monitor_a_screen
# SM_computer_a
# SM_AVP1_Slider_01
# SM_printer_a
# SM_AVP1_Switch_04
# Types of objects found:85

# %%
print(all_keys)
# Out:
# ['SM_monitor_b', 'SM_tv_a_wall', 'SM_VisitorChair', 'SM_AVP1_Power_05', 'SM_AVP1_SmokeDetector_02', 'SM_projector_a', 'SM_AVP1_Power_06', 'SM_Door', 'SM_computer_a', 'SM_AVP1_Keypad_01', 'SM_Mousepad', 'SM_AVP1_Switch_01', 'SM_laptop_a', 'SM_AVP1_Hook_01', 'SM_mouse_b', 'SM_AVP1_Vent_01', 'SM_keyboard_b', 'SM_ExecutiveChair', 'SM_computer_c', 'SM_AVP1_Power_04', 'SM_AVP1_Network_01', 'SM_tv_a', 'SM_AVP1_Coax_01', 'SM_AVP1_Power_03', 'SM_DoorFrame', 'SM_DeskTray', 'SM_ExecutiveDesk', 'SM_monitor_b_stand', 'SM_AVP1_Plate_01', 'SM_monitor_c', 'SM_Chair', 'SM_Vase2', 'SM_Vase1', 'SM_AVP1_Slider_01', 'SM_Window', 'SM_Vase', 'SM_AVP1_Rocker_01', 'SM_TableRound', 'SM_monitor_a', 'SM_Couch', 'SM_keyboard_a', 'SM_AVP1_Switch_04', 'SM_AVP1_Intercom_01', 'SM_DeskLamp', 'SM_AVP1_Switch_03', 'SM_AVP1_Multimedia_01', 'SM_printer_big_a', 'SM_Cabinet', 'SM_Monitor', 'SM_speaker_a_SM_speaker_a', 'SM_Shelf', 'SM_keyboard_c', 'SM_AVP1_Power_02', 'SM_monitor_d', 'SM_paper_sherdder_a', 'SM_AVP1_Sprinkler_01', 'SM_laptop_a_closed', 'SM_Mouse', 'SM_scaner_a_open', 'SM_AVP1_Rocker_02', 'SM_AVP1_Power_01', 'SM_mouse_a', 'SM_computer_b', 'SM_AVP1_Thermo_02', 'SM_AVP1_Dimmer_01', 'SM_headphones_a', 'SM_Keyboard', 'SM_scaner_a', 'SM_monitor_a_stand', 'SM_AVP1_Light_01', 'SM_Laptop', 'SM_printer_a', 'SM_telephone_a', 'SM_monitor_b_screen', 'SM_Globe', 'SM_Stairs', 'SM_AVP1_Vent_02', 'SM_AVP1_SmokeDetector_01', 'SM_AVP1_Motion_01', 'SM_monitor_a_screen', 'SM_speaker_b', 'SM_mouse_c', 'SM_AVP1_Thermo_01', 'SM_PencilPot', 'SM_AVP1_Switch_02']

# %%
lastThread = None
count = 0
total = 0
for key in objectmappings:
    lastThread = client.simSetSegmentationObjectID(key, all_keys.index(objectmappings[key]));
    count = count + 1;
    total = total + 1
    if count == 500:
        #lastThread.join()
        count = 0
        print("Waiting for Unreal to catchup..." + str(total) + " of " + str(len(objectmappings.keys())))
    #print(key + " set to object id " + str(all_keys.index(objectmappings[key])) + " since its a: " + objectmappings[key])

#Wait only for the last thread.  This can take a while... 
#lastThread.join()
# Out:
# Waiting for Unreal to catchup...500 of 18607
# Waiting for Unreal to catchup...1000 of 18607
# Waiting for Unreal to catchup...1500 of 18607
# Waiting for Unreal to catchup...2000 of 18607
# Waiting for Unreal to catchup...2500 of 18607
# Waiting for Unreal to catchup...3000 of 18607
# Waiting for Unreal to catchup...3500 of 18607
# Waiting for Unreal to catchup...4000 of 18607
# Waiting for Unreal to catchup...4500 of 18607
# Waiting for Unreal to catchup...5000 of 18607
# Waiting for Unreal to catchup...5500 of 18607
# Waiting for Unreal to catchup...6000 of 18607
# Waiting for Unreal to catchup...6500 of 18607
# Waiting for Unreal to catchup...7000 of 18607
# Waiting for Unreal to catchup...7500 of 18607
# Waiting for Unreal to catchup...8000 of 18607
# Waiting for Unreal to catchup...8500 of 18607
# Waiting for Unreal to catchup...9000 of 18607
# Waiting for Unreal to catchup...9500 of 18607
# Waiting for Unreal to catchup...10000 of 18607
# Waiting for Unreal to catchup...10500 of 18607
# Waiting for Unreal to catchup...11000 of 18607
# Waiting for Unreal to catchup...11500 of 18607
# Waiting for Unreal to catchup...12000 of 18607
# Waiting for Unreal to catchup...12500 of 18607
# Waiting for Unreal to catchup...13000 of 18607
# Waiting for Unreal to catchup...13500 of 18607
# Waiting for Unreal to catchup...14000 of 18607
# Waiting for Unreal to catchup...14500 of 18607
# Waiting for Unreal to catchup...15000 of 18607
# Waiting for Unreal to catchup...15500 of 18607
# Waiting for Unreal to catchup...16000 of 18607
# Waiting for Unreal to catchup...16500 of 18607
# Waiting for Unreal to catchup...17000 of 18607
# Waiting for Unreal to catchup...17500 of 18607
# Waiting for Unreal to catchup...18000 of 18607
# Waiting for Unreal to catchup...18500 of 18607

# %%
for x in range(500): # do few times
    x = random.randrange(0,2000)/100; # some random number
    y = random.randrange(0,2000)/100; # some random number
    z = 0-(random.randrange(0,700)/100); # some random number
    client.simSetVehiclePose(airsim.Pose(airsim.Vector3r(x, y, z), airsim.to_quaternion(x / 3.0, 0, x / 3.0)), True)

    responses = client.simGetImages([
        airsim.ImageRequest("front_left", airsim.ImageType.Scene),
        airsim.ImageRequest("front_right", airsim.ImageType.Scene),
        airsim.ImageRequest("front_center", airsim.ImageType.Segmentation),
        airsim.ImageRequest("front_center", airsim.ImageType.DepthPerspective),
        airsim.ImageRequest("front_center", airsim.ImageType.DepthVis),
        airsim.ImageRequest("front_center", airsim.ImageType.DisparityNormalized),
        ])

    for i, response in enumerate(responses):
        filename = os.path.join(tmp_dir, str(x) + "_" + str(y) + "_" + str(z) + "_" + str(i))
        if response.pixels_as_float:
            print("Type %d, size %d, pos %s" % (response.image_type, len(response.image_data_float), pprint.pformat(response.camera_position)))
            airsim.write_pfm(os.path.normpath(filename + '.pfm'), airsim.get_pfm_array(response))
        else:
            print("Type %d, size %d, pos %s" % (response.image_type, len(response.image_data_uint8), pprint.pformat(response.camera_position)))
            airsim.write_file(os.path.normpath(filename + '.png'), response.image_data_uint8)
# Out:
# Type 0, size 125927, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': -0.125,
#     'z_val': 2989.474853515625}
# Type 0, size 125892, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': 0.125,
#     'z_val': 2989.474853515625}
# Type 5, size 3852, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': 0.0,
#     'z_val': 2989.474853515625}
# Type 2, size 22618, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': 0.0,
#     'z_val': 2989.474853515625}
# Type 3, size 23289, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': 0.0,
#     'z_val': 2989.474853515625}
# Type 4, size 3204, pos <Vector3r> {   'x_val': 0.4599999785423279,
#     'y_val': 0.0,
#     'z_val': 2989.474853515625}
# Type 0, size 258545, pos <Vector3r> {   'x_val': 12.213322639465332,
#     'y_val': 12.715843200683594,
#     'z_val': -2.031750202178955}
# Type 0, size 225214, pos <Vector3r> {   'x_val': 12.409423828125,
#     'y_val': 12.560782432556152,
#     'z_val': -2.031750202178955}
# Type 5, size 6416, pos <Vector3r> {   'x_val': 12.311372756958008,
#     'y_val': 12.638312339782715,
#     'z_val': -2.031750202178955}
# Type 2, size 31304, pos <Vector3r> {   'x_val': 12.311372756958008,
#     'y_val': 12.638312339782715,
#     'z_val': -2.031750202178955}
# Type 3, size 14163, pos <Vector3r> {   'x_val': 12.311372756958008,
#     'y_val': 12.638312339782715,
#     'z_val': -2.031750202178955}
# Type 4, size 22495, pos <Vector3r> {   'x_val': 12.311372756958008,
#     'y_val': 12.638312339782715,
#     'z_val': -2.031750202178955}
# Type 0, size 215975, pos <Vector3r> {   'x_val': 12.561532974243164,
#     'y_val': 13.02902889251709,
#     'z_val': 1.9449201822280884}
# Type 0, size 205317, pos <Vector3r> {   'x_val': 12.757634162902832,
#     'y_val': 12.873968124389648,
#     'z_val': 1.9449201822280884}
# Type 5, size 5204, pos <Vector3r> {   'x_val': 12.65958309173584,
#     'y_val': 12.951498985290527,
#     'z_val': 1.9449201822280884}
# Type 2, size 38632, pos <Vector3r> {   'x_val': 12.65958309173584,
#     'y_val': 12.951498985290527,
#     'z_val': 1.9449201822280884}
# Type 3, size 7466, pos <Vector3r> {   'x_val': 12.65958309173584,
#     'y_val': 12.951498985290527,
#     'z_val': 1.9449201822280884}
# Type 4, size 12912, pos <Vector3r> {   'x_val': 12.65958309173584,
#     'y_val': 12.951498985290527,
#     'z_val': 1.9449201822280884}
# Type 0, size 289667, pos <Vector3r> {   'x_val': 18.42137336730957,
#     'y_val': 15.248361587524414,
#     'z_val': -2.8334081172943115}
# Type 0, size 292251, pos <Vector3r> {   'x_val': 18.544111251831055,
#     'y_val': 15.466157913208008,
#     'z_val': -2.8334081172943115}
# Type 5, size 11403, pos <Vector3r> {   'x_val': 18.482742309570312,
#     'y_val': 15.357258796691895,
#     'z_val': -2.8334081172943115}
# Type 2, size 9383, pos <Vector3r> {   'x_val': 18.482742309570312,
#     'y_val': 15.357258796691895,
#     'z_val': -2.8334081172943115}
# Type 3, size 9380, pos <Vector3r> {   'x_val': 18.482742309570312,
#     'y_val': 15.357258796691895,
#     'z_val': -2.8334081172943115}
# Type 4, size 12629, pos <Vector3r> {   'x_val': 18.482742309570312,
#     'y_val': 15.357258796691895,
#     'z_val': -2.8334081172943115}
# Type 0, size 262681, pos <Vector3r> {   'x_val': 16.37621307373047,
#     'y_val': 4.397700786590576,
#     'z_val': -2.208601713180542}
# Type 0, size 263849, pos <Vector3r> {   'x_val': 16.604387283325195,
#     'y_val': 4.499856948852539,
#     'z_val': -2.208601474761963}
# Type 5, size 7164, pos <Vector3r> {   'x_val': 16.49030113220215,
#     'y_val': 4.448779106140137,
#     'z_val': -2.208601713180542}
# Type 2, size 38903, pos <Vector3r> {   'x_val': 16.49030113220215,
#     'y_val': 4.448779106140137,
#     'z_val': -2.208601713180542}
# Type 3, size 15767, pos <Vector3r> {   'x_val': 16.49030113220215,
#     'y_val': 4.448779106140137,
#     'z_val': -2.208601713180542}
# Type 4, size 9535, pos <Vector3r> {   'x_val': 16.49030113220215,
#     'y_val': 4.448779106140137,
#     'z_val': -2.208601713180542}
# Type 0, size 324642, pos <Vector3r> {   'x_val': 11.336068153381348,
#     'y_val': 4.801111221313477,
#     'z_val': -2.4610304832458496}
# Type 0, size 326978, pos <Vector3r> {   'x_val': 11.356480598449707,
#     'y_val': 4.55194616317749,
#     'z_val': -2.4610304832458496}
# Type 5, size 25992, pos <Vector3r> {   'x_val': 11.346274375915527,
#     'y_val': 4.6765289306640625,
#     'z_val': -2.4610304832458496}
# Type 2, size 3565, pos <Vector3r> {   'x_val': 11.346274375915527,
#     'y_val': 4.6765289306640625,
#     'z_val': -2.4610304832458496}
# Type 3, size 3565, pos <Vector3r> {   'x_val': 11.346274375915527,
#     'y_val': 4.6765289306640625,
#     'z_val': -2.4610304832458496}
# Type 4, size 26572, pos <Vector3r> {   'x_val': 11.346274375915527,
#     'y_val': 4.6765289306640625,
#     'z_val': -2.4610304832458496}
# Type 0, size 94808, pos <Vector3r> {   'x_val': 14.75916862487793,
#     'y_val': 13.018568992614746,
#     'z_val': 2.692153215408325}
# Type 0, size 94861, pos <Vector3r> {   'x_val': 15.006012916564941,
#     'y_val': 12.978973388671875,
#     'z_val': 2.692153215408325}
# Type 5, size 3206, pos <Vector3r> {   'x_val': 14.882590293884277,
#     'y_val': 12.998770713806152,
#     'z_val': 2.692153215408325}
# Type 2, size 8065, pos <Vector3r> {   'x_val': 14.882590293884277,
#     'y_val': 12.998770713806152,
#     'z_val': 2.692153215408325}
# Type 3, size 8185, pos <Vector3r> {   'x_val': 14.882590293884277,
#     'y_val': 12.998770713806152,
#     'z_val': 2.692153215408325}
# Type 4, size 3204, pos <Vector3r> {   'x_val': 14.882590293884277,
#     'y_val': 12.998770713806152,
#     'z_val': 2.692153215408325}
# Type 0, size 279723, pos <Vector3r> {   'x_val': 18.12152099609375,
#     'y_val': 10.494454383850098,
#     'z_val': -0.4787389934062958}
# Type 0, size 278550, pos <Vector3r> {   'x_val': 18.211891174316406,
#     'y_val': 10.727548599243164,
#     'z_val': -0.4787389934062958}
# Type 5, size 10035, pos <Vector3r> {   'x_val': 18.166706085205078,
#     'y_val': 10.611001968383789,
#     'z_val': -0.4787389934062958}
# Type 2, size 4114, pos <Vector3r> {   'x_val': 18.166706085205078,
#     'y_val': 10.611001968383789,
#     'z_val': -0.4787389934062958}
# Type 3, size 4114, pos <Vector3r> {   'x_val': 18.166706085205078,
#     'y_val': 10.611001968383789,
#     'z_val': -0.4787389934062958}
# Type 4, size 11656, pos <Vector3r> {   'x_val': 18.166706085205078,
#     'y_val': 10.611001968383789,
#     'z_val': -0.4787389934062958}
# Type 0, size 163720, pos <Vector3r> {   'x_val': 19.725229263305664,
#     'y_val': 10.190421104431152,
#     'z_val': 2.779201030731201}
# Type 0, size 163599, pos <Vector3r> {   'x_val': 19.815597534179688,
#     'y_val': 10.423515319824219,
#     'z_val': 2.779201030731201}
# Type 5, size 4617, pos <Vector3r> {   'x_val': 19.77041244506836,
#     'y_val': 10.306968688964844,
#     'z_val': 2.779201030731201}
# Type 2, size 9242, pos <Vector3r> {   'x_val': 19.77041244506836,
#     'y_val': 10.306968688964844,
#     'z_val': 2.779201030731201}
# Type 3, size 7345, pos <Vector3r> {   'x_val': 19.77041244506836,
#     'y_val': 10.306968688964844,
#     'z_val': 2.779201030731201}
# Type 4, size 5868, pos <Vector3r> {   'x_val': 19.77041244506836,
#     'y_val': 10.306968688964844,
#     'z_val': 2.779201030731201}
# Type 0, size 329443, pos <Vector3r> {   'x_val': 0.7351693511009216,
#     'y_val': 13.18140697479248,
#     'z_val': -3.8862600326538086}
# Type 0, size 329335, pos <Vector3r> {   'x_val': 0.731836199760437,
#     'y_val': 13.431385040283203,
#     'z_val': -3.8862600326538086}
# Type 5, size 29289, pos <Vector3r> {   'x_val': 0.7335028052330017,
#     'y_val': 13.306396484375,
#     'z_val': -3.8862600326538086}
# Type 2, size 4223, pos <Vector3r> {   'x_val': 0.7335028052330017,
#     'y_val': 13.306396484375,
#     'z_val': -3.8862600326538086}
# Type 3, size 4228, pos <Vector3r> {   'x_val': 0.7335028052330017,
#     'y_val': 13.306396484375,
#     'z_val': -3.8862600326538086}
# Type 4, size 19018, pos <Vector3r> {   'x_val': 0.7335028052330017,
#     'y_val': 13.306396484375,
#     'z_val': -3.8862600326538086}
# Type 0, size 292783, pos <Vector3r> {   'x_val': 2.955543041229248,
#     'y_val': 12.696779251098633,
#     'z_val': -0.6138578653335571}
# Type 0, size 287853, pos <Vector3r> {   'x_val': 2.952209711074829,
#     'y_val': 12.946757316589355,
#     'z_val': -0.6138578653335571}
# Type 5, size 19177, pos <Vector3r> {   'x_val': 2.953876256942749,
#     'y_val': 12.821768760681152,
#     'z_val': -0.6138578653335571}
# Type 2, size 4426, pos <Vector3r> {   'x_val': 2.953876256942749,
#     'y_val': 12.821768760681152,
#     'z_val': -0.6138578653335571}
# Type 3, size 4436, pos <Vector3r> {   'x_val': 2.953876256942749,
#     'y_val': 12.821768760681152,
#     'z_val': -0.6138578653335571}
# Type 4, size 17863, pos <Vector3r> {   'x_val': 2.953876256942749,
#     'y_val': 12.821768760681152,
#     'z_val': -0.6138578653335571}
# Type 0, size 362709, pos <Vector3r> {   'x_val': 4.406649589538574,
#     'y_val': 3.0397326946258545,
#     'z_val': 0.20195645093917847}
# Type 0, size 364308, pos <Vector3r> {   'x_val': 4.215567111968994,
#     'y_val': 3.200939178466797,
#     'z_val': 0.20195645093917847}
# Type 5, size 64009, pos <Vector3r> {   'x_val': 4.311108112335205,
#     'y_val': 3.120335817337036,
#     'z_val': 0.20195645093917847}
# Type 2, size 14014, pos <Vector3r> {   'x_val': 4.311108112335205,
#     'y_val': 3.120335817337036,
#     'z_val': 0.20195645093917847}
# Type 3, size 13923, pos <Vector3r> {   'x_val': 4.311108112335205,
#     'y_val': 3.120335817337036,
#     'z_val': 0.20195645093917847}
# Type 4, size 37632, pos <Vector3r> {   'x_val': 4.311108112335205,
#     'y_val': 3.120335817337036,
#     'z_val': 0.20195645093917847}
# Type 0, size 341548, pos <Vector3r> {   'x_val': 6.925538063049316,
#     'y_val': 16.16176986694336,
#     'z_val': 1.5574326515197754}
# Type 0, size 342860, pos <Vector3r> {   'x_val': 6.679250240325928,
#     'y_val': 16.11884880065918,
#     'z_val': 1.5574326515197754}
# Type 5, size 66199, pos <Vector3r> {   'x_val': 6.802394390106201,
#     'y_val': 16.140310287475586,
#     'z_val': 1.5574326515197754}
# Type 2, size 23813, pos <Vector3r> {   'x_val': 6.802394390106201,
#     'y_val': 16.140310287475586,
#     'z_val': 1.5574326515197754}
# Type 3, size 23386, pos <Vector3r> {   'x_val': 6.802394390106201,
#     'y_val': 16.140310287475586,
#     'z_val': 1.5574326515197754}
# Type 4, size 36076, pos <Vector3r> {   'x_val': 6.802394390106201,
#     'y_val': 16.140310287475586,
#     'z_val': 1.5574326515197754}
# Type 0, size 342041, pos <Vector3r> {   'x_val': 2.1697661876678467,
#     'y_val': 8.713699340820312,
#     'z_val': -3.6216938495635986}
# Type 0, size 340252, pos <Vector3r> {   'x_val': 2.031369209289551,
#     'y_val': 8.921896934509277,
#     'z_val': -3.6216938495635986}
# Type 5, size 44770, pos <Vector3r> {   'x_val': 2.1005678176879883,
#     'y_val': 8.817798614501953,
#     'z_val': -3.6216938495635986}
# Type 2, size 10068, pos <Vector3r> {   'x_val': 2.1005678176879883,
#     'y_val': 8.817798614501953,
#     'z_val': -3.6216938495635986}
# Type 3, size 10068, pos <Vector3r> {   'x_val': 2.1005678176879883,
#     'y_val': 8.817798614501953,
#     'z_val': -3.6216938495635986}
# Type 4, size 30524, pos <Vector3r> {   'x_val': 2.1005678176879883,
#     'y_val': 8.817798614501953,
#     'z_val': -3.6216938495635986}
# Type 0, size 242114, pos <Vector3r> {   'x_val': 1.780969500541687,
#     'y_val': 9.138093948364258,
#     'z_val': 0.42471396923065186}
# Type 0, size 241748, pos <Vector3r> {   'x_val': 1.642572283744812,
#     'y_val': 9.346291542053223,
#     'z_val': 0.42471396923065186}
# Type 5, size 18131, pos <Vector3r> {   'x_val': 1.7117708921432495,
#     'y_val': 9.242193222045898,
#     'z_val': 0.42471396923065186}
# Type 2, size 5869, pos <Vector3r> {   'x_val': 1.7117708921432495,
#     'y_val': 9.242193222045898,
#     'z_val': 0.42471396923065186}
# Type 3, size 5869, pos <Vector3r> {   'x_val': 1.7117708921432495,
#     'y_val': 9.242193222045898,
#     'z_val': 0.42471396923065186}
# Type 4, size 21913, pos <Vector3r> {   'x_val': 1.7117708921432495,
#     'y_val': 9.242193222045898,
#     'z_val': 0.42471396923065186}
# Type 0, size 151923, pos <Vector3r> {   'x_val': 2.8210222721099854,
#     'y_val': 18.49542236328125,
#     'z_val': -6.466414451599121}
# Type 0, size 141157, pos <Vector3r> {   'x_val': 2.63320255279541,
#     'y_val': 18.660419464111328,
#     'z_val': -6.466414451599121}
# Type 5, size 4156, pos <Vector3r> {   'x_val': 2.727112293243408,
#     'y_val': 18.577922821044922,
#     'z_val': -6.466414451599121}
# Type 2, size 31740, pos <Vector3r> {   'x_val': 2.727112293243408,
#     'y_val': 18.577922821044922,
#     'z_val': -6.466414451599121}
# Type 3, size 8533, pos <Vector3r> {   'x_val': 2.727112293243408,
#     'y_val': 18.577922821044922,
#     'z_val': -6.466414451599121}
# Type 4, size 8940, pos <Vector3r> {   'x_val': 2.727112293243408,
#     'y_val': 18.577922821044922,
#     'z_val': -6.466414451599121}
# Type 0, size 183911, pos <Vector3r> {   'x_val': 1.7413618564605713,
#     'y_val': 18.209156036376953,
#     'z_val': -2.4451849460601807}
# Type 0, size 194283, pos <Vector3r> {   'x_val': 1.5535417795181274,
#     'y_val': 18.37415313720703,
#     'z_val': -2.4451849460601807}
# Type 5, size 11681, pos <Vector3r> {   'x_val': 1.6474517583847046,
#     'y_val': 18.291654586791992,
#     'z_val': -2.4451849460601807}
# Type 2, size 6009, pos <Vector3r> {   'x_val': 1.6474517583847046,
#     'y_val': 18.291654586791992,
#     'z_val': -2.4451849460601807}
# Type 3, size 6009, pos <Vector3r> {   'x_val': 1.6474517583847046,
#     'y_val': 18.291654586791992,
#     'z_val': -2.4451849460601807}
# Type 4, size 16389, pos <Vector3r> {   'x_val': 1.6474517583847046,
#     'y_val': 18.291654586791992,
#     'z_val': -2.4451849460601807}
# Type 0, size 315157, pos <Vector3r> {   'x_val': 10.927658081054688,
#     'y_val': 5.729648113250732,
#     'z_val': -3.209378242492676}
# Type 0, size 314343, pos <Vector3r> {   'x_val': 11.070549011230469,
#     'y_val': 5.524508476257324,
#     'z_val': -3.209378242492676}
# Type 5, size 19662, pos <Vector3r> {   'x_val': 10.999103546142578,
#     'y_val': 5.627078056335449,
#     'z_val': -3.209378242492676}
# Type 2, size 47302, pos <Vector3r> {   'x_val': 10.999103546142578,
#     'y_val': 5.627078056335449,
#     'z_val': -3.209378242492676}
# Type 3, size 32935, pos <Vector3r> {   'x_val': 10.999103546142578,
#     'y_val': 5.627078056335449,
#     'z_val': -3.209378242492676}
# Type 4, size 19532, pos <Vector3r> {   'x_val': 10.999103546142578,
#     'y_val': 5.627078056335449,
#     'z_val': -3.209378242492676}
# Type 0, size 339694, pos <Vector3r> {   'x_val': 0.9835668206214905,
#     'y_val': 8.498371124267578,
#     'z_val': -3.845858573913574}
# Type 0, size 339112, pos <Vector3r> {   'x_val': 0.9049251079559326,
#     'y_val': 8.735679626464844,
#     'z_val': -3.845858573913574}
# Type 5, size 48802, pos <Vector3r> {   'x_val': 0.9442459940910339,
#     'y_val': 8.617025375366211,
#     'z_val': -3.845858573913574}
# Type 2, size 6225, pos <Vector3r> {   'x_val': 0.9442459940910339,
#     'y_val': 8.617025375366211,
#     'z_val': -3.845858573913574}
# Type 3, size 6223, pos <Vector3r> {   'x_val': 0.9442459940910339,
#     'y_val': 8.617025375366211,
#     'z_val': -3.845858573913574}
# Type 4, size 32288, pos <Vector3r> {   'x_val': 0.9442459940910339,
#     'y_val': 8.617025375366211,
#     'z_val': -3.845858573913574}
# Type 0, size 317303, pos <Vector3r> {   'x_val': 18.016246795654297,
#     'y_val': 9.067046165466309,
#     'z_val': -3.9907939434051514}
# Type 0, size 316757, pos <Vector3r> {   'x_val': 18.076444625854492,
#     'y_val': 9.30968952178955,
#     'z_val': -3.9907939434051514}
# Type 5, size 11651, pos <Vector3r> {   'x_val': 18.046344757080078,
#     'y_val': 9.18836784362793,
#     'z_val': -3.9907939434051514}
# Type 2, size 3869, pos <Vector3r> {   'x_val': 18.046344757080078,
#     'y_val': 9.18836784362793,
#     'z_val': -3.9907939434051514}
# Type 3, size 3869, pos <Vector3r> {   'x_val': 18.046344757080078,
#     'y_val': 9.18836784362793,
#     'z_val': -3.9907939434051514}
# Type 4, size 10732, pos <Vector3r> {   'x_val': 18.046344757080078,
#     'y_val': 9.18836784362793,
#     'z_val': -3.9907939434051514}
# Type 0, size 312258, pos <Vector3r> {   'x_val': 7.945034503936768,
#     'y_val': 4.472898006439209,
#     'z_val': -2.3310279846191406}
# Type 0, size 332055, pos <Vector3r> {   'x_val': 7.8248291015625,
#     'y_val': 4.253693580627441,
#     'z_val': -2.3310279846191406}
# Type 5, size 48495, pos <Vector3r> {   'x_val': 7.884931564331055,
#     'y_val': 4.363296031951904,
#     'z_val': -2.3310279846191406}
# Type 2, size 8405, pos <Vector3r> {   'x_val': 7.884931564331055,
#     'y_val': 4.363296031951904,
#     'z_val': -2.3310279846191406}
# Type 3, size 8339, pos <Vector3r> {   'x_val': 7.884931564331055,
#     'y_val': 4.363296031951904,
#     'z_val': -2.3310279846191406}
# Type 4, size 34352, pos <Vector3r> {   'x_val': 7.884931564331055,
#     'y_val': 4.363296031951904,
#     'z_val': -2.3310279846191406}
# Type 0, size 241465, pos <Vector3r> {   'x_val': 0.142995685338974,
#     'y_val': 17.19462776184082,
#     'z_val': 1.631229043006897}
# Type 0, size 229900, pos <Vector3r> {   'x_val': 0.1023435965180397,
#     'y_val': 17.441301345825195,
#     'z_val': 1.631229043006897}
# Type 5, size 22713, pos <Vector3r> {   'x_val': 0.12266963720321655,
#     'y_val': 17.317964553833008,
#     'z_val': 1.631229043006897}
# Type 2, size 4256, pos <Vector3r> {   'x_val': 0.12266963720321655,
#     'y_val': 17.317964553833008,
#     'z_val': 1.631229043006897}
# Type 3, size 4256, pos <Vector3r> {   'x_val': 0.12266963720321655,
#     'y_val': 17.317964553833008,
#     'z_val': 1.631229043006897}
# Type 4, size 14206, pos <Vector3r> {   'x_val': 0.12266963720321655,
#     'y_val': 17.317964553833008,
#     'z_val': 1.631229043006897}
# Type 0, size 297568, pos <Vector3r> {   'x_val': 11.022859573364258,
#     'y_val': 11.740984916687012,
#     'z_val': -4.708258152008057}
# Type 0, size 290548, pos <Vector3r> {   'x_val': 11.170496940612793,
#     'y_val': 11.53923511505127,
#     'z_val': -4.708258152008057}
# Type 5, size 13899, pos <Vector3r> {   'x_val': 11.096677780151367,
#     'y_val': 11.640110969543457,
#     'z_val': -4.708258152008057}
# Type 2, size 32045, pos <Vector3r> {   'x_val': 11.096677780151367,
#     'y_val': 11.640110969543457,
#     'z_val': -4.708258152008057}
# Type 3, size 29361, pos <Vector3r> {   'x_val': 11.096677780151367,
#     'y_val': 11.640110969543457,
#     'z_val': -4.708258152008057}
# Type 4, size 19993, pos <Vector3r> {   'x_val': 11.096677780151367,
#     'y_val': 11.640110969543457,
#     'z_val': -4.708258152008057}
# Type 0, size 212368, pos <Vector3r> {   'x_val': 1.6675710678100586,
#     'y_val': 17.72963523864746,
#     'z_val': -4.72151517868042}
# Type 0, size 209112, pos <Vector3r> {   'x_val': 1.526410460472107,
#     'y_val': 17.93596839904785,
#     'z_val': -4.72151517868042}
# Type 5, size 11861, pos <Vector3r> {   'x_val': 1.5969908237457275,
#     'y_val': 17.832801818847656,
#     'z_val': -4.72151517868042}
# Type 2, size 6445, pos <Vector3r> {   'x_val': 1.5969908237457275,
#     'y_val': 17.832801818847656,
#     'z_val': -4.72151517868042}
# Type 3, size 6445, pos <Vector3r> {   'x_val': 1.5969908237457275,
#     'y_val': 17.832801818847656,
#     'z_val': -4.72151517868042}
# Type 4, size 22963, pos <Vector3r> {   'x_val': 1.5969908237457275,
#     'y_val': 17.832801818847656,
#     'z_val': -4.72151517868042}
# Type 0, size 161863, pos <Vector3r> {   'x_val': 15.27612018585205,
#     'y_val': 13.04280948638916,
#     'z_val': 1.7218480110168457}
# Type 0, size 154097, pos <Vector3r> {   'x_val': 15.489128112792969,
#     'y_val': 13.17368221282959,
#     'z_val': 1.7218480110168457}
# Type 5, size 3205, pos <Vector3r> {   'x_val': 15.382624626159668,
#     'y_val': 13.108245849609375,
#     'z_val': 1.7218480110168457}
# Type 2, size 34871, pos <Vector3r> {   'x_val': 15.382624626159668,
#     'y_val': 13.108245849609375,
#     'z_val': 1.7218480110168457}
# Type 3, size 5346, pos <Vector3r> {   'x_val': 15.382624626159668,
#     'y_val': 13.108245849609375,
#     'z_val': 1.7218480110168457}
# Type 4, size 3458, pos <Vector3r> {   'x_val': 15.382624626159668,
#     'y_val': 13.108245849609375,
#     'z_val': 1.7218480110168457}
# Type 0, size 287065, pos <Vector3r> {   'x_val': 14.991381645202637,
#     'y_val': 6.748158931732178,
#     'z_val': -4.936873912811279}
# Type 0, size 286301, pos <Vector3r> {   'x_val': 15.228084564208984,
#     'y_val': 6.828604698181152,
#     'z_val': -4.936873912811279}
# Type 5, size 14304, pos <Vector3r> {   'x_val': 15.109733581542969,
#     'y_val': 6.788381576538086,
#     'z_val': -4.936873912811279}
# Type 2, size 51304, pos <Vector3r> {   'x_val': 15.109733581542969,
#     'y_val': 6.788381576538086,
#     'z_val': -4.936873912811279}
# Type 3, size 24325, pos <Vector3r> {   'x_val': 15.109733581542969,
#     'y_val': 6.788381576538086,
#     'z_val': -4.936873912811279}
# Type 4, size 14754, pos <Vector3r> {   'x_val': 15.109733581542969,
#     'y_val': 6.788381576538086,
#     'z_val': -4.936873912811279}
# Type 0, size 230400, pos <Vector3r> {   'x_val': 13.859073638916016,
#     'y_val': 6.502586364746094,
#     'z_val': -1.0574578046798706}
# Type 0, size 230814, pos <Vector3r> {   'x_val': 14.095775604248047,
#     'y_val': 6.583032131195068,
#     'z_val': -1.057457685470581}
# Type 5, size 7611, pos <Vector3r> {   'x_val': 13.977425575256348,
#     'y_val': 6.54280948638916,
#     'z_val': -1.0574578046798706}
# Type 2, size 40669, pos <Vector3r> {   'x_val': 13.977425575256348,
#     'y_val': 6.54280948638916,
#     'z_val': -1.0574578046798706}
# Type 3, size 12278, pos <Vector3r> {   'x_val': 13.977425575256348,
#     'y_val': 6.54280948638916,
#     'z_val': -1.0574578046798706}
# Type 4, size 17584, pos <Vector3r> {   'x_val': 13.977425575256348,
#     'y_val': 6.54280948638916,
#     'z_val': -1.0574578046798706}
# Type 0, size 340007, pos <Vector3r> {   'x_val': 2.7076196670532227,
#     'y_val': 8.278887748718262,
#     'z_val': -2.301440715789795}
# Type 0, size 341872, pos <Vector3r> {   'x_val': 2.4797701835632324,
#     'y_val': 8.381770133972168,
#     'z_val': -2.301440715789795}
# Type 5, size 58727, pos <Vector3r> {   'x_val': 2.5936946868896484,
#     'y_val': 8.330328941345215,
#     'z_val': -2.301440715789795}
# Type 2, size 18036, pos <Vector3r> {   'x_val': 2.5936946868896484,
#     'y_val': 8.330328941345215,
#     'z_val': -2.301440715789795}
# Type 3, size 17969, pos <Vector3r> {   'x_val': 2.5936946868896484,
#     'y_val': 8.330328941345215,
#     'z_val': -2.301440715789795}
# Type 4, size 38078, pos <Vector3r> {   'x_val': 2.5936946868896484,
#     'y_val': 8.330328941345215,
#     'z_val': -2.301440715789795}
# Type 0, size 353317, pos <Vector3r> {   'x_val': 7.553098678588867,
#     'y_val': 10.43913459777832,
#     'z_val': -0.6872539520263672}
# Type 0, size 355718, pos <Vector3r> {   'x_val': 7.478043079376221,
#     'y_val': 10.200666427612305,
#     'z_val': -0.687254011631012}
# Type 5, size 49762, pos <Vector3r> {   'x_val': 7.515571117401123,
#     'y_val': 10.319899559020996,
#     'z_val': -0.6872539520263672}
# Type 2, size 5564, pos <Vector3r> {   'x_val': 7.515571117401123,
#     'y_val': 10.319899559020996,
#     'z_val': -0.6872539520263672}
# Type 3, size 5564, pos <Vector3r> {   'x_val': 7.515571117401123,
#     'y_val': 10.319899559020996,
#     'z_val': -0.6872539520263672}
# Type 4, size 30600, pos <Vector3r> {   'x_val': 7.515571117401123,
#     'y_val': 10.319899559020996,
#     'z_val': -0.6872539520263672}
# Type 0, size 336371, pos <Vector3r> {   'x_val': -0.0561593621969223,
#     'y_val': 3.8376591205596924,
#     'z_val': 0.1739446371793747}
# Type 0, size 343434, pos <Vector3r> {   'x_val': -0.16264411807060242,
#     'y_val': 4.063847064971924,
#     'z_val': 0.1739446371793747}
# Type 5, size 47257, pos <Vector3r> {   'x_val': -0.10940174013376236,
#     'y_val': 3.9507534503936768,
#     'z_val': 0.1739446371793747}
# Type 2, size 6665, pos <Vector3r> {   'x_val': -0.10940174013376236,
#     'y_val': 3.9507534503936768,
#     'z_val': 0.1739446371793747}
# Type 3, size 6659, pos <Vector3r> {   'x_val': -0.10940174013376236,
#     'y_val': 3.9507534503936768,
#     'z_val': 0.1739446371793747}
# Type 4, size 32402, pos <Vector3r> {   'x_val': -0.10940174013376236,
#     'y_val': 3.9507534503936768,
#     'z_val': 0.1739446371793747}
# Type 0, size 351570, pos <Vector3r> {   'x_val': -1.1035633087158203,
#     'y_val': 5.763490676879883,
#     'z_val': 0.18537843227386475}
# Type 0, size 350825, pos <Vector3r> {   'x_val': -1.1662214994430542,
#     'y_val': 6.0055108070373535,
#     'z_val': 0.18537843227386475}
# Type 5, size 48794, pos <Vector3r> {   'x_val': -1.134892463684082,
#     'y_val': 5.884500503540039,
#     'z_val': 0.18537843227386475}
# Type 2, size 5426, pos <Vector3r> {   'x_val': -1.134892463684082,
#     'y_val': 5.884500503540039,
#     'z_val': 0.18537843227386475}
# Type 3, size 5426, pos <Vector3r> {   'x_val': -1.134892463684082,
#     'y_val': 5.884500503540039,
#     'z_val': 0.18537843227386475}
# Type 4, size 28761, pos <Vector3r> {   'x_val': -1.134892463684082,
#     'y_val': 5.884500503540039,
#     'z_val': 0.18537843227386475}
# Type 0, size 298589, pos <Vector3r> {   'x_val': -0.24089285731315613,
#     'y_val': 15.348799705505371,
#     'z_val': -2.713869333267212}
# Type 0, size 295877, pos <Vector3r> {   'x_val': -0.37368953227996826,
#     'y_val': 15.560612678527832,
#     'z_val': -2.713869571685791}
# Type 5, size 22917, pos <Vector3r> {   'x_val': -0.3072912096977234,
#     'y_val': 15.454705238342285,
#     'z_val': -2.713869571685791}
# Type 2, size 6998, pos <Vector3r> {   'x_val': -0.3072912096977234,
#     'y_val': 15.454705238342285,
#     'z_val': -2.713869571685791}
# Type 3, size 6998, pos <Vector3r> {   'x_val': -0.3072912096977234,
#     'y_val': 15.454705238342285,
#     'z_val': -2.713869571685791}
# Type 4, size 17865, pos <Vector3r> {   'x_val': -0.3072912096977234,
#     'y_val': 15.454705238342285,
#     'z_val': -2.713869571685791}
# Type 0, size 278733, pos <Vector3r> {   'x_val': 16.871469497680664,
#     'y_val': 16.70920181274414,
#     'z_val': -2.1723074913024902}
# Type 0, size 272835, pos <Vector3r> {   'x_val': 16.91455078125,
#     'y_val': 16.955463409423828,
#     'z_val': -2.1723074913024902}
# Type 5, size 10239, pos <Vector3r> {   'x_val': 16.893009185791016,
#     'y_val': 16.832332611083984,
#     'z_val': -2.1723074913024902}
# Type 2, size 3930, pos <Vector3r> {   'x_val': 16.893009185791016,
#     'y_val': 16.832332611083984,
#     'z_val': -2.1723074913024902}
# Type 3, size 3930, pos <Vector3r> {   'x_val': 16.893009185791016,
#     'y_val': 16.832332611083984,
#     'z_val': -2.1723074913024902}
# Type 4, size 10260, pos <Vector3r> {   'x_val': 16.893009185791016,
#     'y_val': 16.832332611083984,
#     'z_val': -2.1723074913024902}
# Type 0, size 261135, pos <Vector3r> {   'x_val': 9.076248168945312,
#     'y_val': 4.339514255523682,
#     'z_val': 1.2176169157028198}
# Type 0, size 261061, pos <Vector3r> {   'x_val': 9.14575481414795,
#     'y_val': 4.099371433258057,
#     'z_val': 1.2176169157028198}
# Type 5, size 11337, pos <Vector3r> {   'x_val': 9.111001014709473,
#     'y_val': 4.219442844390869,
#     'z_val': 1.2176169157028198}
# Type 2, size 26683, pos <Vector3r> {   'x_val': 9.111001014709473,
#     'y_val': 4.219442844390869,
#     'z_val': 1.2176169157028198}
# Type 3, size 22670, pos <Vector3r> {   'x_val': 9.111001014709473,
#     'y_val': 4.219442844390869,
#     'z_val': 1.2176169157028198}
# Type 4, size 11618, pos <Vector3r> {   'x_val': 9.111001014709473,
#     'y_val': 4.219442844390869,
#     'z_val': 1.2176169157028198}
# Type 0, size 346537, pos <Vector3r> {   'x_val': 3.035717725753784,
#     'y_val': 4.520918846130371,
#     'z_val': -4.311243057250977}
# Type 0, size 346675, pos <Vector3r> {   'x_val': 2.8313989639282227,
#     'y_val': 4.664980888366699,
#     'z_val': -4.311243057250977}
# Type 5, size 58978, pos <Vector3r> {   'x_val': 2.933558225631714,
#     'y_val': 4.592949867248535,
#     'z_val': -4.311243057250977}
# Type 2, size 18294, pos <Vector3r> {   'x_val': 2.933558225631714,
#     'y_val': 4.592949867248535,
#     'z_val': -4.311243057250977}
# Type 3, size 17866, pos <Vector3r> {   'x_val': 2.933558225631714,
#     'y_val': 4.592949867248535,
#     'z_val': -4.311243057250977}
# Type 4, size 35216, pos <Vector3r> {   'x_val': 2.933558225631714,
#     'y_val': 4.592949867248535,
#     'z_val': -4.311243057250977}
# Type 0, size 199018, pos <Vector3r> {   'x_val': 1.117972731590271,
#     'y_val': 3.9905343055725098,
#     'z_val': -0.56407630443573}
# Type 0, size 329730, pos <Vector3r> {   'x_val': 0.9136540293693542,
#     'y_val': 4.134596347808838,
#     'z_val': -0.56407630443573}
# Type 5, size 26624, pos <Vector3r> {   'x_val': 1.0158134698867798,
#     'y_val': 4.062565326690674,
#     'z_val': -0.56407630443573}
# Type 2, size 5413, pos <Vector3r> {   'x_val': 1.0158134698867798,
#     'y_val': 4.062565326690674,
#     'z_val': -0.56407630443573}
# Type 3, size 5407, pos <Vector3r> {   'x_val': 1.0158134698867798,
#     'y_val': 4.062565326690674,
#     'z_val': -0.56407630443573}
# Type 4, size 30080, pos <Vector3r> {   'x_val': 1.0158134698867798,
#     'y_val': 4.062565326690674,
#     'z_val': -0.56407630443573}
# Type 0, size 308706, pos <Vector3r> {   'x_val': 8.672472953796387,
#     'y_val': 5.201623439788818,
#     'z_val': -3.015104293823242}
# Type 0, size 306865, pos <Vector3r> {   'x_val': 8.699522018432617,
#     'y_val': 4.953091144561768,
#     'z_val': -3.015104293823242}
# Type 5, size 25965, pos <Vector3r> {   'x_val': 8.685997009277344,
#     'y_val': 5.077357292175293,
#     'z_val': -3.015104293823242}
# Type 2, size 23083, pos <Vector3r> {   'x_val': 8.685997009277344,
#     'y_val': 5.077357292175293,
#     'z_val': -3.015104293823242}
# Type 3, size 23030, pos <Vector3r> {   'x_val': 8.685997009277344,
#     'y_val': 5.077357292175293,
#     'z_val': -3.015104293823242}
# Type 4, size 23597, pos <Vector3r> {   'x_val': 8.685997009277344,
#     'y_val': 5.077357292175293,
#     'z_val': -3.015104293823242}
# Type 0, size 348828, pos <Vector3r> {   'x_val': 2.8043129444122314,
#     'y_val': 4.068896293640137,
#     'z_val': -3.9613211154937744}
# Type 0, size 350635, pos <Vector3r> {   'x_val': 2.6069369316101074,
#     'y_val': 4.22233247756958,
#     'z_val': -3.9613211154937744}
# Type 5, size 57934, pos <Vector3r> {   'x_val': 2.705625057220459,
#     'y_val': 4.145614147186279,
#     'z_val': -3.9613211154937744}
# Type 2, size 16428, pos <Vector3r> {   'x_val': 2.705625057220459,
#     'y_val': 4.145614147186279,
#     'z_val': -3.9613211154937744}
# Type 3, size 16192, pos <Vector3r> {   'x_val': 2.705625057220459,
#     'y_val': 4.145614147186279,
#     'z_val': -3.9613211154937744}
# Type 4, size 34782, pos <Vector3r> {   'x_val': 2.705625057220459,
#     'y_val': 4.145614147186279,
#     'z_val': -3.9613211154937744}
# Type 0, size 348021, pos <Vector3r> {   'x_val': 0.7511941194534302,
#     'y_val': 3.532503604888916,
#     'z_val': 0.9590979814529419}
# Type 0, size 348979, pos <Vector3r> {   'x_val': 0.5538181662559509,
#     'y_val': 3.6859397888183594,
#     'z_val': 0.9590979814529419}
# Type 5, size 54428, pos <Vector3r> {   'x_val': 0.6525061726570129,
#     'y_val': 3.6092216968536377,
#     'z_val': 0.9590979814529419}
# Type 2, size 9227, pos <Vector3r> {   'x_val': 0.6525061726570129,
#     'y_val': 3.6092216968536377,
#     'z_val': 0.9590979814529419}
# Type 3, size 9234, pos <Vector3r> {   'x_val': 0.6525061726570129,
#     'y_val': 3.6092216968536377,
#     'z_val': 0.9590979814529419}
# Type 4, size 35727, pos <Vector3r> {   'x_val': 0.6525061726570129,
#     'y_val': 3.6092216968536377,
#     'z_val': 0.9590979814529419}
# Type 0, size 280270, pos <Vector3r> {   'x_val': 18.04220962524414,
#     'y_val': 6.849627494812012,
#     'z_val': -1.7074946165084839}
# Type 0, size 283078, pos <Vector3r> {   'x_val': 17.976295471191406,
#     'y_val': 7.090781211853027,
#     'z_val': -1.7074946165084839}
# Type 5, size 17074, pos <Vector3r> {   'x_val': 18.009252548217773,
#     'y_val': 6.9702043533325195,
#     'z_val': -1.7074946165084839}
# Type 2, size 4685, pos <Vector3r> {   'x_val': 18.009252548217773,
#     'y_val': 6.9702043533325195,
#     'z_val': -1.7074946165084839}
# Type 3, size 4685, pos <Vector3r> {   'x_val': 18.009252548217773,
#     'y_val': 6.9702043533325195,
#     'z_val': -1.7074946165084839}
# Type 4, size 17374, pos <Vector3r> {   'x_val': 18.009252548217773,
#     'y_val': 6.9702043533325195,
#     'z_val': -1.7074946165084839}
# Type 0, size 301236, pos <Vector3r> {   'x_val': 17.25273323059082,
#     'y_val': 3.8880860805511475,
#     'z_val': -1.540795922279358}
# Type 0, size 303080, pos <Vector3r> {   'x_val': 17.285106658935547,
#     'y_val': 4.135981559753418,
#     'z_val': -1.540795922279358}
# Type 5, size 15498, pos <Vector3r> {   'x_val': 17.2689208984375,
#     'y_val': 4.012033462524414,
#     'z_val': -1.540795922279358}
# Type 2, size 3882, pos <Vector3r> {   'x_val': 17.2689208984375,
#     'y_val': 4.012033462524414,
#     'z_val': -1.540795922279358}
# Type 3, size 3882, pos <Vector3r> {   'x_val': 17.2689208984375,
#     'y_val': 4.012033462524414,
#     'z_val': -1.540795922279358}
# Type 4, size 16201, pos <Vector3r> {   'x_val': 17.2689208984375,
#     'y_val': 4.012033462524414,
#     'z_val': -1.540795922279358}
# Type 0, size 196215, pos <Vector3r> {   'x_val': 13.59761905670166,
#     'y_val': 3.310725688934326,
#     'z_val': -0.02103925682604313}
# Type 0, size 193461, pos <Vector3r> {   'x_val': 13.82969856262207,
#     'y_val': 3.403674840927124,
#     'z_val': -0.02103925682604313}
# Type 5, size 4482, pos <Vector3r> {   'x_val': 13.713659286499023,
#     'y_val': 3.3572001457214355,
#     'z_val': -0.02103925682604313}
# Type 2, size 35461, pos <Vector3r> {   'x_val': 13.713659286499023,
#     'y_val': 3.3572001457214355,
#     'z_val': -0.02103925682604313}
# Type 3, size 8963, pos <Vector3r> {   'x_val': 13.713659286499023,
#     'y_val': 3.3572001457214355,
#     'z_val': -0.02103925682604313}
# Type 4, size 5069, pos <Vector3r> {   'x_val': 13.713659286499023,
#     'y_val': 3.3572001457214355,
#     'z_val': -0.02103925682604313}
# Type 0, size 287541, pos <Vector3r> {   'x_val': 18.08265495300293,
#     'y_val': 3.4479598999023438,
#     'z_val': 1.2824500799179077}
# Type 0, size 287025, pos <Vector3r> {   'x_val': 18.03050422668457,
#     'y_val': 3.6924595832824707,
#     'z_val': 1.2824500799179077}
# Type 5, size 13847, pos <Vector3r> {   'x_val': 18.05657958984375,
#     'y_val': 3.5702099800109863,
#     'z_val': 1.2824500799179077}
# Type 2, size 4386, pos <Vector3r> {   'x_val': 18.05657958984375,
#     'y_val': 3.5702099800109863,
#     'z_val': 1.2824500799179077}
# Type 3, size 4386, pos <Vector3r> {   'x_val': 18.05657958984375,
#     'y_val': 3.5702099800109863,
#     'z_val': 1.2824500799179077}
# Type 4, size 11780, pos <Vector3r> {   'x_val': 18.05657958984375,
#     'y_val': 3.5702099800109863,
#     'z_val': 1.2824500799179077}
# Type 0, size 222344, pos <Vector3r> {   'x_val': 17.123754501342773,
#     'y_val': 18.2248592376709,
#     'z_val': -4.917757987976074}
# Type 0, size 220754, pos <Vector3r> {   'x_val': 17.17420196533203,
#     'y_val': 18.469717025756836,
#     'z_val': -4.917757987976074}
# Type 5, size 8914, pos <Vector3r> {   'x_val': 17.14897918701172,
#     'y_val': 18.347288131713867,
#     'z_val': -4.917757987976074}
# Type 2, size 3809, pos <Vector3r> {   'x_val': 17.14897918701172,
#     'y_val': 18.347288131713867,
#     'z_val': -4.917757987976074}
# Type 3, size 3809, pos <Vector3r> {   'x_val': 17.14897918701172,
#     'y_val': 18.347288131713867,
#     'z_val': -4.917757987976074}
# Type 4, size 13780, pos <Vector3r> {   'x_val': 17.14897918701172,
#     'y_val': 18.347288131713867,
#     'z_val': -4.917757987976074}
# Type 0, size 241978, pos <Vector3r> {   'x_val': 13.38776683807373,
#     'y_val': 10.089542388916016,
#     'z_val': 0.5392229557037354}
# Type 0, size 244885, pos <Vector3r> {   'x_val': 13.629728317260742,
#     'y_val': 10.15242862701416,
#     'z_val': 0.5392229557037354}
# Type 5, size 6490, pos <Vector3r> {   'x_val': 13.508747100830078,
#     'y_val': 10.12098503112793,
#     'z_val': 0.5392229557037354}
# Type 2, size 37968, pos <Vector3r> {   'x_val': 13.508747100830078,
#     'y_val': 10.12098503112793,
#     'z_val': 0.5392229557037354}
# Type 3, size 9238, pos <Vector3r> {   'x_val': 13.508747100830078,
#     'y_val': 10.12098503112793,
#     'z_val': 0.5392229557037354}
# Type 4, size 9978, pos <Vector3r> {   'x_val': 13.508747100830078,
#     'y_val': 10.12098503112793,
#     'z_val': 0.5392229557037354}
# Type 0, size 313750, pos <Vector3r> {   'x_val': 1.6000361442565918,
#     'y_val': 8.14377498626709,
#     'z_val': 1.9264540672302246}
# Type 0, size 254060, pos <Vector3r> {   'x_val': 1.3966822624206543,
#     'y_val': 8.289196014404297,
#     'z_val': 1.9264540672302246}
# Type 5, size 45654, pos <Vector3r> {   'x_val': 1.498359203338623,
#     'y_val': 8.216485023498535,
#     'z_val': 1.9264540672302246}
# Type 2, size 11090, pos <Vector3r> {   'x_val': 1.498359203338623,
#     'y_val': 8.216485023498535,
#     'z_val': 1.9264540672302246}
# Type 3, size 11070, pos <Vector3r> {   'x_val': 1.498359203338623,
#     'y_val': 8.216485023498535,
#     'z_val': 1.9264540672302246}
# Type 4, size 42133, pos <Vector3r> {   'x_val': 1.498359203338623,
#     'y_val': 8.216485023498535,
#     'z_val': 1.9264540672302246}
# Type 0, size 178294, pos <Vector3r> {   'x_val': -0.8191759586334229,
#     'y_val': 8.1569185256958,
#     'z_val': 2.8622634410858154}
# Type 0, size 174557, pos <Vector3r> {   'x_val': -0.8499311804771423,
#     'y_val': 8.405019760131836,
#     'z_val': 2.8622634410858154}
# Type 5, size 8682, pos <Vector3r> {   'x_val': -0.8345534801483154,
#     'y_val': 8.28096866607666,
#     'z_val': 2.8622634410858154}
# Type 2, size 5161, pos <Vector3r> {   'x_val': -0.8345534801483154,
#     'y_val': 8.28096866607666,
#     'z_val': 2.8622634410858154}
# Type 3, size 5161, pos <Vector3r> {   'x_val': -0.8345534801483154,
#     'y_val': 8.28096866607666,
#     'z_val': 2.8622634410858154}
# Type 4, size 16574, pos <Vector3r> {   'x_val': -0.8345534801483154,
#     'y_val': 8.28096866607666,
#     'z_val': 2.8622634410858154}
# Type 0, size 327446, pos <Vector3r> {   'x_val': 2.440096616744995,
#     'y_val': 4.5836405754089355,
#     'z_val': -3.377835512161255}
# Type 0, size 317054, pos <Vector3r> {   'x_val': 2.1985504627227783,
#     'y_val': 4.648102760314941,
#     'z_val': -3.377835512161255}
# Type 5, size 60873, pos <Vector3r> {   'x_val': 2.3193233013153076,
#     'y_val': 4.615871429443359,
#     'z_val': -3.377835512161255}
# Type 2, size 21595, pos <Vector3r> {   'x_val': 2.3193233013153076,
#     'y_val': 4.615871429443359,
#     'z_val': -3.377835512161255}
# Type 3, size 21452, pos <Vector3r> {   'x_val': 2.3193233013153076,
#     'y_val': 4.615871429443359,
#     'z_val': -3.377835512161255}
# Type 4, size 41390, pos <Vector3r> {   'x_val': 2.3193233013153076,
#     'y_val': 4.615871429443359,
#     'z_val': -3.377835512161255}
# Type 0, size 287784, pos <Vector3r> {   'x_val': 2.317049980163574,
#     'y_val': 13.10396671295166,
#     'z_val': -2.559265375137329}
# Type 0, size 292635, pos <Vector3r> {   'x_val': 2.0709762573242188,
#     'y_val': 13.148099899291992,
#     'z_val': -2.559265375137329}
# Type 5, size 32283, pos <Vector3r> {   'x_val': 2.1940131187438965,
#     'y_val': 13.126033782958984,
#     'z_val': -2.559265375137329}
# Type 2, size 12414, pos <Vector3r> {   'x_val': 2.1940131187438965,
#     'y_val': 13.126033782958984,
#     'z_val': -2.559265375137329}
# Type 3, size 12317, pos <Vector3r> {   'x_val': 2.1940131187438965,
#     'y_val': 13.126033782958984,
#     'z_val': -2.559265375137329}
# Type 4, size 24945, pos <Vector3r> {   'x_val': 2.1940131187438965,
#     'y_val': 13.126033782958984,
#     'z_val': -2.559265375137329}
# Type 0, size 214812, pos <Vector3r> {   'x_val': 0.4858522415161133,
#     'y_val': 19.442678451538086,
#     'z_val': -4.962433338165283}
# Type 0, size 214557, pos <Vector3r> {   'x_val': 0.4608938992023468,
#     'y_val': 19.691429138183594,
#     'z_val': -4.962433338165283}
# Type 5, size 9459, pos <Vector3r> {   'x_val': 0.47337305545806885,
#     'y_val': 19.567054748535156,
#     'z_val': -4.962433338165283}
# Type 2, size 4325, pos <Vector3r> {   'x_val': 0.47337305545806885,
#     'y_val': 19.567054748535156,
#     'z_val': -4.962433338165283}
# Type 3, size 4222, pos <Vector3r> {   'x_val': 0.47337305545806885,
#     'y_val': 19.567054748535156,
#     'z_val': -4.962433338165283}
# Type 4, size 6598, pos <Vector3r> {   'x_val': 0.47337305545806885,
#     'y_val': 19.567054748535156,
#     'z_val': -4.962433338165283}
# Type 0, size 120154, pos <Vector3r> {   'x_val': -2.5032167434692383,
#     'y_val': 19.24079132080078,
#     'z_val': -1.2767810821533203}
# Type 0, size 121447, pos <Vector3r> {   'x_val': -2.528174877166748,
#     'y_val': 19.48954200744629,
#     'z_val': -1.2767810821533203}
# Type 5, size 3206, pos <Vector3r> {   'x_val': -2.515695810317993,
#     'y_val': 19.36516761779785,
#     'z_val': -1.2767810821533203}
# Type 2, size 32151, pos <Vector3r> {   'x_val': -2.515695810317993,
#     'y_val': 19.36516761779785,
#     'z_val': -1.2767810821533203}
# Type 3, size 4954, pos <Vector3r> {   'x_val': -2.515695810317993,
#     'y_val': 19.36516761779785,
#     'z_val': -1.2767810821533203}
# Type 4, size 9999, pos <Vector3r> {   'x_val': -2.515695810317993,
#     'y_val': 19.36516761779785,
#     'z_val': -1.2767810821533203}
# Type 0, size 168447, pos <Vector3r> {   'x_val': 4.1140217781066895,
#     'y_val': 9.454779624938965,
#     'z_val': -0.4567732810974121}
# Type 0, size 152754, pos <Vector3r> {   'x_val': 3.870842456817627,
#     'y_val': 9.512778282165527,
#     'z_val': -0.4567732810974121}
# Type 5, size 5091, pos <Vector3r> {   'x_val': 3.992432117462158,
#     'y_val': 9.483778953552246,
#     'z_val': -0.4567732810974121}
# Type 2, size 7948, pos <Vector3r> {   'x_val': 3.992432117462158,
#     'y_val': 9.483778953552246,
#     'z_val': -0.4567732810974121}
# Type 3, size 5459, pos <Vector3r> {   'x_val': 3.992432117462158,
#     'y_val': 9.483778953552246,
#     'z_val': -0.4567732810974121}
# Type 4, size 34201, pos <Vector3r> {   'x_val': 3.992432117462158,
#     'y_val': 9.483778953552246,
#     'z_val': -0.4567732810974121}
# Type 0, size 279118, pos <Vector3r> {   'x_val': 14.975666046142578,
#     'y_val': 15.198514938354492,
#     'z_val': -3.9632487297058105}
# Type 0, size 278706, pos <Vector3r> {   'x_val': 15.210140228271484,
#     'y_val': 15.28524398803711,
#     'z_val': -3.9632487297058105}
# Type 5, size 8886, pos <Vector3r> {   'x_val': 15.092902183532715,
#     'y_val': 15.2418794631958,
#     'z_val': -3.9632487297058105}
# Type 2, size 45985, pos <Vector3r> {   'x_val': 15.092902183532715,
#     'y_val': 15.2418794631958,
#     'z_val': -3.9632487297058105}
# Type 3, size 17932, pos <Vector3r> {   'x_val': 15.092902183532715,
#     'y_val': 15.2418794631958,
#     'z_val': -3.9632487297058105}
# Type 4, size 10632, pos <Vector3r> {   'x_val': 15.092902183532715,
#     'y_val': 15.2418794631958,
#     'z_val': -3.9632487297058105}
# Type 0, size 231809, pos <Vector3r> {   'x_val': 12.676332473754883,
#     'y_val': 14.26772403717041,
#     'z_val': 1.2350656986236572}
# Type 0, size 215683, pos <Vector3r> {   'x_val': 12.910806655883789,
#     'y_val': 14.354453086853027,
#     'z_val': 1.2350656986236572}
# Type 5, size 4880, pos <Vector3r> {   'x_val': 12.79356861114502,
#     'y_val': 14.311088562011719,
#     'z_val': 1.2350656986236572}
# Type 2, size 39393, pos <Vector3r> {   'x_val': 12.79356861114502,
#     'y_val': 14.311088562011719,
#     'z_val': 1.2350656986236572}
# Type 3, size 7379, pos <Vector3r> {   'x_val': 12.79356861114502,
#     'y_val': 14.311088562011719,
#     'z_val': 1.2350656986236572}
# Type 4, size 8722, pos <Vector3r> {   'x_val': 12.79356861114502,
#     'y_val': 14.311088562011719,
#     'z_val': 1.2350656986236572}
# Type 0, size 261026, pos <Vector3r> {   'x_val': 6.072804927825928,
#     'y_val': 17.835235595703125,
#     'z_val': -2.335012912750244}
# Type 0, size 250403, pos <Vector3r> {   'x_val': 5.841819763183594,
#     'y_val': 17.73960304260254,
#     'z_val': -2.335012912750244}
# Type 5, size 47967, pos <Vector3r> {   'x_val': 5.95731258392334,
#     'y_val': 17.787418365478516,
#     'z_val': -2.335012912750244}
# Type 2, size 17740, pos <Vector3r> {   'x_val': 5.95731258392334,
#     'y_val': 17.787418365478516,
#     'z_val': -2.335012912750244}
# Type 3, size 17527, pos <Vector3r> {   'x_val': 5.95731258392334,
#     'y_val': 17.787418365478516,
#     'z_val': -2.335012912750244}
# Type 4, size 28632, pos <Vector3r> {   'x_val': 5.95731258392334,
#     'y_val': 17.787418365478516,
#     'z_val': -2.335012912750244}
# Type 0, size 328356, pos <Vector3r> {   'x_val': 3.478724956512451,
#     'y_val': 9.55734634399414,
#     'z_val': -2.1268467903137207}
# Type 0, size 325712, pos <Vector3r> {   'x_val': 3.248537540435791,
#     'y_val': 9.654884338378906,
#     'z_val': -2.1268467903137207}
# Type 5, size 50814, pos <Vector3r> {   'x_val': 3.363631248474121,
#     'y_val': 9.606115341186523,
#     'z_val': -2.1268467903137207}
# Type 2, size 16606, pos <Vector3r> {   'x_val': 3.363631248474121,
#     'y_val': 9.606115341186523,
#     'z_val': -2.1268467903137207}
# Type 3, size 16572, pos <Vector3r> {   'x_val': 3.363631248474121,
#     'y_val': 9.606115341186523,
#     'z_val': -2.1268467903137207}
# Type 4, size 36398, pos <Vector3r> {   'x_val': 3.363631248474121,
#     'y_val': 9.606115341186523,
#     'z_val': -2.1268467903137207}
# Type 0, size 10626, pos <Vector3r> {   'x_val': 0.45164406299591064,
#     'y_val': 9.202157974243164,
#     'z_val': 6.571201801300049}
# Type 0, size 11462, pos <Vector3r> {   'x_val': 0.22145645320415497,
#     'y_val': 9.29969596862793,
#     'z_val': 6.571201801300049}
# Type 5, size 4456, pos <Vector3r> {   'x_val': 0.336550235748291,
#     'y_val': 9.250926971435547,
#     'z_val': 6.571201801300049}
# Type 2, size 36503, pos <Vector3r> {   'x_val': 0.336550235748291,
#     'y_val': 9.250926971435547,
#     'z_val': 6.571201801300049}
# Type 3, size 8765, pos <Vector3r> {   'x_val': 0.336550235748291,
#     'y_val': 9.250926971435547,
#     'z_val': 6.571201801300049}
# Type 4, size 5090, pos <Vector3r> {   'x_val': 0.336550235748291,
#     'y_val': 9.250926971435547,
#     'z_val': 6.571201801300049}
# Type 0, size 310657, pos <Vector3r> {   'x_val': 17.672048568725586,
#     'y_val': 3.7814385890960693,
#     'z_val': -1.5134447813034058}
# Type 0, size 312112, pos <Vector3r> {   'x_val': 17.622344970703125,
#     'y_val': 4.026447772979736,
#     'z_val': -1.5134447813034058}
# Type 5, size 21337, pos <Vector3r> {   'x_val': 17.647197723388672,
#     'y_val': 3.9039433002471924,
#     'z_val': -1.5134447813034058}
# Type 2, size 4617, pos <Vector3r> {   'x_val': 17.647197723388672,
#     'y_val': 3.9039433002471924,
#     'z_val': -1.5134447813034058}
# Type 3, size 4617, pos <Vector3r> {   'x_val': 17.647197723388672,
#     'y_val': 3.9039433002471924,
#     'z_val': -1.5134447813034058}
# Type 4, size 16835, pos <Vector3r> {   'x_val': 17.647197723388672,
#     'y_val': 3.9039433002471924,
#     'z_val': -1.5134447813034058}
# Type 0, size 307993, pos <Vector3r> {   'x_val': 17.648380279541016,
#     'y_val': 12.38170051574707,
#     'z_val': -4.631630897521973}
# Type 0, size 306341, pos <Vector3r> {   'x_val': 17.754831314086914,
#     'y_val': 12.607903480529785,
#     'z_val': -4.631631374359131}
# Type 5, size 14377, pos <Vector3r> {   'x_val': 17.70160675048828,
#     'y_val': 12.49480152130127,
#     'z_val': -4.631630897521973}
# Type 2, size 4211, pos <Vector3r> {   'x_val': 17.70160675048828,
#     'y_val': 12.49480152130127,
#     'z_val': -4.631630897521973}
# Type 3, size 4211, pos <Vector3r> {   'x_val': 17.70160675048828,
#     'y_val': 12.49480152130127,
#     'z_val': -4.631630897521973}
# Type 4, size 11975, pos <Vector3r> {   'x_val': 17.70160675048828,
#     'y_val': 12.49480152130127,
#     'z_val': -4.631630897521973}
# Type 0, size 270082, pos <Vector3r> {   'x_val': 15.396262168884277,
#     'y_val': 11.40351390838623,
#     'z_val': -1.508535623550415}
# Type 0, size 265977, pos <Vector3r> {   'x_val': 15.502713203430176,
#     'y_val': 11.629717826843262,
#     'z_val': -1.508535623550415}
# Type 5, size 12796, pos <Vector3r> {   'x_val': 15.449488639831543,
#     'y_val': 11.516615867614746,
#     'z_val': -1.508535623550415}
# Type 2, size 3961, pos <Vector3r> {   'x_val': 15.449488639831543,
#     'y_val': 11.516615867614746,
#     'z_val': -1.508535623550415}
# Type 3, size 3961, pos <Vector3r> {   'x_val': 15.449488639831543,
#     'y_val': 11.516615867614746,
#     'z_val': -1.508535623550415}
# Type 4, size 13273, pos <Vector3r> {   'x_val': 15.449488639831543,
#     'y_val': 11.516615867614746,
#     'z_val': -1.508535623550415}
# Type 0, size 236382, pos <Vector3r> {   'x_val': 0.8304234147071838,
# ...
#     'z_val': -0.3487776219844818}
# Type 3, size 20070, pos <Vector3r> {   'x_val': 3.0444107055664062,
#     'y_val': 4.356123924255371,
#     'z_val': -0.3487776219844818}
# Type 4, size 39621, pos <Vector3r> {   'x_val': 3.0444107055664062,
#     'y_val': 4.356123924255371,
#     'z_val': -0.3487776219844818}
# Type 0, size 239596, pos <Vector3r> {   'x_val': 18.747526168823242,
#     'y_val': 16.454191207885742,
#     'z_val': -1.4456233978271484}
# Type 0, size 249521, pos <Vector3r> {   'x_val': 18.686447143554688,
#     'y_val': 16.69661521911621,
#     'z_val': -1.4456233978271484}
# Type 5, size 8312, pos <Vector3r> {   'x_val': 18.71698760986328,
#     'y_val': 16.575403213500977,
#     'z_val': -1.4456233978271484}
# Type 2, size 23765, pos <Vector3r> {   'x_val': 18.71698760986328,
#     'y_val': 16.575403213500977,
#     'z_val': -1.4456233978271484}
# Type 3, size 14367, pos <Vector3r> {   'x_val': 18.71698760986328,
#     'y_val': 16.575403213500977,
#     'z_val': -1.4456233978271484}
# Type 4, size 11124, pos <Vector3r> {   'x_val': 18.71698760986328,
#     'y_val': 16.575403213500977,
#     'z_val': -1.4456233978271484}
# Type 0, size 136355, pos <Vector3r> {   'x_val': 12.718262672424316,
#     'y_val': 2.76823091506958,
#     'z_val': 2.734717845916748}
# Type 0, size 138192, pos <Vector3r> {   'x_val': 12.967413902282715,
#     'y_val': 2.747657060623169,
#     'z_val': 2.734717845916748}
# Type 5, size 10412, pos <Vector3r> {   'x_val': 12.842838287353516,
#     'y_val': 2.757943868637085,
#     'z_val': 2.734717845916748}
# Type 2, size 13188, pos <Vector3r> {   'x_val': 12.842838287353516,
#     'y_val': 2.757943868637085,
#     'z_val': 2.734717845916748}
# Type 3, size 13207, pos <Vector3r> {   'x_val': 12.842838287353516,
#     'y_val': 2.757943868637085,
#     'z_val': 2.734717845916748}
# Type 4, size 11133, pos <Vector3r> {   'x_val': 12.842838287353516,
#     'y_val': 2.757943868637085,
#     'z_val': 2.734717845916748}
# Type 0, size 298869, pos <Vector3r> {   'x_val': 13.026345252990723,
#     'y_val': 1.610588788986206,
#     'z_val': -4.67773962020874}
# Type 0, size 298613, pos <Vector3r> {   'x_val': 13.26126766204834,
#     'y_val': 1.5250862836837769,
#     'z_val': -4.67773962020874}
# Type 5, size 11708, pos <Vector3r> {   'x_val': 13.143807411193848,
#     'y_val': 1.5678374767303467,
#     'z_val': -4.67773962020874}
# Type 2, size 46770, pos <Vector3r> {   'x_val': 13.143807411193848,
#     'y_val': 1.5678374767303467,
#     'z_val': -4.67773962020874}
# Type 3, size 21867, pos <Vector3r> {   'x_val': 13.143807411193848,
#     'y_val': 1.5678374767303467,
#     'z_val': -4.67773962020874}
# Type 4, size 12577, pos <Vector3r> {   'x_val': 13.143807411193848,
#     'y_val': 1.5678374767303467,
#     'z_val': -4.67773962020874}
# Type 0, size 259589, pos <Vector3r> {   'x_val': 11.165783882141113,
#     'y_val': 1.45936918258667,
#     'z_val': -0.8612789511680603}
# Type 0, size 258677, pos <Vector3r> {   'x_val': 11.40070629119873,
#     'y_val': 1.3738666772842407,
#     'z_val': -0.8612790703773499}
# Type 5, size 5233, pos <Vector3r> {   'x_val': 11.283246040344238,
#     'y_val': 1.4166178703308105,
#     'z_val': -0.8612790703773499}
# Type 2, size 37725, pos <Vector3r> {   'x_val': 11.283246040344238,
#     'y_val': 1.4166178703308105,
#     'z_val': -0.8612790703773499}
# Type 3, size 10876, pos <Vector3r> {   'x_val': 11.283246040344238,
#     'y_val': 1.4166178703308105,
#     'z_val': -0.8612790703773499}
# Type 4, size 5339, pos <Vector3r> {   'x_val': 11.283246040344238,
#     'y_val': 1.4166178703308105,
#     'z_val': -0.8612790703773499}
# Type 0, size 267367, pos <Vector3r> {   'x_val': 17.960100173950195,
#     'y_val': 6.227120399475098,
#     'z_val': 1.259761095046997}
# Type 0, size 256837, pos <Vector3r> {   'x_val': 17.922704696655273,
#     'y_val': 6.474307537078857,
#     'z_val': 1.259761095046997}
# Type 5, size 8521, pos <Vector3r> {   'x_val': 17.941402435302734,
#     'y_val': 6.350714206695557,
#     'z_val': 1.259761095046997}
# Type 2, size 4124, pos <Vector3r> {   'x_val': 17.941402435302734,
#     'y_val': 6.350714206695557,
#     'z_val': 1.259761095046997}
# Type 3, size 4124, pos <Vector3r> {   'x_val': 17.941402435302734,
#     'y_val': 6.350714206695557,
#     'z_val': 1.259761095046997}
# Type 4, size 19588, pos <Vector3r> {   'x_val': 17.941402435302734,
#     'y_val': 6.350714206695557,
#     'z_val': 1.259761095046997}
# Type 0, size 274311, pos <Vector3r> {   'x_val': 19.90884017944336,
#     'y_val': 15.982698440551758,
#     'z_val': -3.483912229537964}
# Type 0, size 267554, pos <Vector3r> {   'x_val': 19.841320037841797,
#     'y_val': 16.223407745361328,
#     'z_val': -3.483912229537964}
# Type 5, size 9705, pos <Vector3r> {   'x_val': 19.87508201599121,
#     'y_val': 16.103052139282227,
#     'z_val': -3.483912229537964}
# Type 2, size 3925, pos <Vector3r> {   'x_val': 19.87508201599121,
#     'y_val': 16.103052139282227,
#     'z_val': -3.483912229537964}
# Type 3, size 3925, pos <Vector3r> {   'x_val': 19.87508201599121,
#     'y_val': 16.103052139282227,
#     'z_val': -3.483912229537964}
# Type 4, size 12262, pos <Vector3r> {   'x_val': 19.87508201599121,
#     'y_val': 16.103052139282227,
#     'z_val': -3.483912229537964}
# Type 0, size 244931, pos <Vector3r> {   'x_val': 17.652067184448242,
#     'y_val': 16.11487579345703,
#     'z_val': -0.04964994266629219}
# Type 0, size 241261, pos <Vector3r> {   'x_val': 17.584545135498047,
#     'y_val': 16.3555850982666,
#     'z_val': -0.049649953842163086}
# Type 5, size 8934, pos <Vector3r> {   'x_val': 17.61830711364746,
#     'y_val': 16.2352294921875,
#     'z_val': -0.049649953842163086}
# Type 2, size 4150, pos <Vector3r> {   'x_val': 17.61830711364746,
#     'y_val': 16.2352294921875,
#     'z_val': -0.049649953842163086}
# Type 3, size 4150, pos <Vector3r> {   'x_val': 17.61830711364746,
#     'y_val': 16.2352294921875,
#     'z_val': -0.049649953842163086}
# Type 4, size 9947, pos <Vector3r> {   'x_val': 17.61830711364746,
#     'y_val': 16.2352294921875,
#     'z_val': -0.049649953842163086}
# Type 0, size 292861, pos <Vector3r> {   'x_val': 17.31431770324707,
#     'y_val': 12.411116600036621,
#     'z_val': -1.5581413507461548}
# Type 0, size 291835, pos <Vector3r> {   'x_val': 17.335920333862305,
#     'y_val': 12.660181999206543,
#     'z_val': -1.5581413507461548}
# Type 5, size 10957, pos <Vector3r> {   'x_val': 17.325117111206055,
#     'y_val': 12.535649299621582,
#     'z_val': -1.5581413507461548}
# Type 2, size 4065, pos <Vector3r> {   'x_val': 17.325117111206055,
#     'y_val': 12.535649299621582,
#     'z_val': -1.5581413507461548}
# Type 3, size 4065, pos <Vector3r> {   'x_val': 17.325117111206055,
#     'y_val': 12.535649299621582,
#     'z_val': -1.5581413507461548}
# Type 4, size 9279, pos <Vector3r> {   'x_val': 17.325117111206055,
#     'y_val': 12.535649299621582,
#     'z_val': -1.5581413507461548}
# Type 0, size 133820, pos <Vector3r> {   'x_val': 3.1848256587982178,
#     'y_val': 19.634258270263672,
#     'z_val': -6.3929266929626465}
# Type 0, size 132563, pos <Vector3r> {   'x_val': 2.97536301612854,
#     'y_val': 19.770732879638672,
#     'z_val': -6.3929266929626465}
# Type 5, size 3206, pos <Vector3r> {   'x_val': 3.080094575881958,
#     'y_val': 19.702495574951172,
#     'z_val': -6.3929266929626465}
# Type 2, size 35386, pos <Vector3r> {   'x_val': 3.080094575881958,
#     'y_val': 19.702495574951172,
#     'z_val': -6.3929266929626465}
# Type 3, size 7278, pos <Vector3r> {   'x_val': 3.080094575881958,
#     'y_val': 19.702495574951172,
#     'z_val': -6.3929266929626465}
# Type 4, size 3465, pos <Vector3r> {   'x_val': 3.080094575881958,
#     'y_val': 19.702495574951172,
#     'z_val': -6.3929266929626465}
# Type 0, size 131849, pos <Vector3r> {   'x_val': 1.0684587955474854,
#     'y_val': 19.697744369506836,
#     'z_val': -2.9416863918304443}
# Type 0, size 125706, pos <Vector3r> {   'x_val': 0.8589962720870972,
#     'y_val': 19.834218978881836,
#     'z_val': -2.9416863918304443}
# Type 5, size 7129, pos <Vector3r> {   'x_val': 0.9637274742126465,
#     'y_val': 19.765981674194336,
#     'z_val': -2.9416863918304443}
# Type 2, size 3794, pos <Vector3r> {   'x_val': 0.9637274742126465,
#     'y_val': 19.765981674194336,
#     'z_val': -2.9416863918304443}
# Type 3, size 3794, pos <Vector3r> {   'x_val': 0.9637274742126465,
#     'y_val': 19.765981674194336,
#     'z_val': -2.9416863918304443}
# Type 4, size 6630, pos <Vector3r> {   'x_val': 0.9637274742126465,
#     'y_val': 19.765981674194336,
#     'z_val': -2.9416863918304443}
# Type 0, size 308037, pos <Vector3r> {   'x_val': 17.58510398864746,
#     'y_val': 8.607744216918945,
#     'z_val': -4.386375904083252}
# Type 0, size 308078, pos <Vector3r> {   'x_val': 17.706388473510742,
#     'y_val': 8.826354026794434,
#     'z_val': -4.386375904083252}
# Type 5, size 18980, pos <Vector3r> {   'x_val': 17.6457462310791,
#     'y_val': 8.717049598693848,
#     'z_val': -4.386375904083252}
# Type 2, size 33896, pos <Vector3r> {   'x_val': 17.6457462310791,
#     'y_val': 8.717049598693848,
#     'z_val': -4.386375904083252}
# Type 3, size 33833, pos <Vector3r> {   'x_val': 17.6457462310791,
#     'y_val': 8.717049598693848,
#     'z_val': -4.386375904083252}
# Type 4, size 17128, pos <Vector3r> {   'x_val': 17.6457462310791,
#     'y_val': 8.717049598693848,
#     'z_val': -4.386375904083252}
# Type 0, size 290354, pos <Vector3r> {   'x_val': 16.442485809326172,
#     'y_val': 8.313949584960938,
#     'z_val': -1.208154320716858}
# Type 0, size 290823, pos <Vector3r> {   'x_val': 16.56376838684082,
#     'y_val': 8.532559394836426,
#     'z_val': -1.208154320716858}
# Type 5, size 12129, pos <Vector3r> {   'x_val': 16.50312614440918,
#     'y_val': 8.423254013061523,
#     'z_val': -1.208154320716858}
# Type 2, size 29847, pos <Vector3r> {   'x_val': 16.50312614440918,
#     'y_val': 8.423254013061523,
#     'z_val': -1.208154320716858}
# Type 3, size 25666, pos <Vector3r> {   'x_val': 16.50312614440918,
#     'y_val': 8.423254013061523,
#     'z_val': -1.208154320716858}
# Type 4, size 13414, pos <Vector3r> {   'x_val': 16.50312614440918,
#     'y_val': 8.423254013061523,
#     'z_val': -1.208154320716858}
# Type 0, size 258475, pos <Vector3r> {   'x_val': 12.280946731567383,
#     'y_val': 17.006319046020508,
#     'z_val': -3.11816143989563}
# Type 0, size 251157, pos <Vector3r> {   'x_val': 12.501249313354492,
#     'y_val': 16.88813591003418,
#     'z_val': -3.11816143989563}
# Type 5, size 5250, pos <Vector3r> {   'x_val': 12.391098022460938,
#     'y_val': 16.947229385375977,
#     'z_val': -3.11816143989563}
# Type 2, size 38204, pos <Vector3r> {   'x_val': 12.391098022460938,
#     'y_val': 16.947229385375977,
#     'z_val': -3.11816143989563}
# Type 3, size 16926, pos <Vector3r> {   'x_val': 12.391098022460938,
#     'y_val': 16.947229385375977,
#     'z_val': -3.11816143989563}
# Type 4, size 15526, pos <Vector3r> {   'x_val': 12.391098022460938,
#     'y_val': 16.947229385375977,
#     'z_val': -3.11816143989563}
# Type 0, size 200487, pos <Vector3r> {   'x_val': 17.099620819091797,
#     'y_val': 16.843305587768555,
#     'z_val': 1.5424973964691162}
# Type 0, size 201951, pos <Vector3r> {   'x_val': 17.254838943481445,
#     'y_val': 17.039283752441406,
#     'z_val': 1.5424973964691162}
# Type 5, size 3205, pos <Vector3r> {   'x_val': 17.177228927612305,
#     'y_val': 16.941295623779297,
#     'z_val': 1.5424975156784058}
# Type 2, size 28813, pos <Vector3r> {   'x_val': 17.177228927612305,
#     'y_val': 16.941295623779297,
#     'z_val': 1.5424975156784058}
# Type 3, size 7818, pos <Vector3r> {   'x_val': 17.177228927612305,
#     'y_val': 16.941295623779297,
#     'z_val': 1.5424975156784058}
# Type 4, size 3251, pos <Vector3r> {   'x_val': 17.177228927612305,
#     'y_val': 16.941295623779297,
#     'z_val': 1.5424975156784058}
# Type 0, size 332539, pos <Vector3r> {   'x_val': 5.294686317443848,
#     'y_val': 4.41649866104126,
#     'z_val': -5.383120059967041}
# Type 0, size 333438, pos <Vector3r> {   'x_val': 5.047463417053223,
#     'y_val': 4.379335880279541,
#     'z_val': -5.383120059967041}
# Type 5, size 76312, pos <Vector3r> {   'x_val': 5.171074867248535,
#     'y_val': 4.3979172706604,
#     'z_val': -5.383120059967041}
# Type 2, size 34954, pos <Vector3r> {   'x_val': 5.171074867248535,
#     'y_val': 4.3979172706604,
#     'z_val': -5.383120059967041}
# Type 3, size 34571, pos <Vector3r> {   'x_val': 5.171074867248535,
#     'y_val': 4.3979172706604,
#     'z_val': -5.383120059967041}
# Type 4, size 46962, pos <Vector3r> {   'x_val': 5.171074867248535,
#     'y_val': 4.3979172706604,
#     'z_val': -5.383120059967041}
# Type 0, size 328169, pos <Vector3r> {   'x_val': 5.395517349243164,
#     'y_val': 3.9543168544769287,
#     'z_val': -1.8557900190353394}
# Type 0, size 325918, pos <Vector3r> {   'x_val': 5.148294448852539,
#     'y_val': 3.91715407371521,
#     'z_val': -1.8557900190353394}
# Type 5, size 66238, pos <Vector3r> {   'x_val': 5.271905899047852,
#     'y_val': 3.9357354640960693,
#     'z_val': -1.8557900190353394}
# Type 2, size 25879, pos <Vector3r> {   'x_val': 5.271905899047852,
#     'y_val': 3.9357354640960693,
#     'z_val': -1.8557900190353394}
# Type 3, size 25465, pos <Vector3r> {   'x_val': 5.271905899047852,
#     'y_val': 3.9357354640960693,
#     'z_val': -1.8557900190353394}
# Type 4, size 44905, pos <Vector3r> {   'x_val': 5.271905899047852,
#     'y_val': 3.9357354640960693,
#     'z_val': -1.8557900190353394}
# Type 0, size 282463, pos <Vector3r> {   'x_val': 20.352724075317383,
#     'y_val': 6.8489580154418945,
#     'z_val': -1.9298981428146362}
# Type 0, size 285126, pos <Vector3r> {   'x_val': 20.26540184020996,
#     'y_val': 7.083211421966553,
#     'z_val': -1.9298981428146362}
# Type 5, size 16806, pos <Vector3r> {   'x_val': 20.309062957763672,
#     'y_val': 6.9660844802856445,
#     'z_val': -1.9298981428146362}
# Type 2, size 5055, pos <Vector3r> {   'x_val': 20.309062957763672,
#     'y_val': 6.9660844802856445,
#     'z_val': -1.9298981428146362}
# Type 3, size 5025, pos <Vector3r> {   'x_val': 20.309062957763672,
#     'y_val': 6.9660844802856445,
#     'z_val': -1.9298981428146362}
# Type 4, size 16990, pos <Vector3r> {   'x_val': 20.309062957763672,
#     'y_val': 6.9660844802856445,
#     'z_val': -1.9298981428146362}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1d2a18b42c68> in <module>
#       5     client.simSetVehiclePose(airsim.Pose(airsim.Vector3r(x, y, z), airsim.to_quaternion(x / 3.0, 0, x / 3.0)), True)
#       6
# ----> 7     responses = client.simGetImages([
#       8         airsim.ImageRequest("front_left", airsim.ImageType.Scene),
#       9         airsim.ImageRequest("front_right", airsim.ImageType.Scene),
#
# ~/.local/lib/python3.8/site-packages/airsim/client.py in simGetImages(self, requests, vehicle_name)
#     293             list[ImageResponse]:
#     294         """
# --> 295         responses_raw = self.client.call("simGetImages", requests, vehicle_name)
#     296         return [
#     297             ImageResponse.from_msgpack(response_raw) for response_raw in responses_raw
#
# ~/.local/lib/python3.8/site-packages/msgpackrpc/session.py in call(self, method, *args)
#      39
#      40     def call(self, method, *args):
# ---> 41         return self.send_request(method, args).get()
#      42
#      43     def call_async(self, method, *args):
#
# ~/.local/lib/python3.8/site-packages/msgpackrpc/future.py in get(self)
#      23
#      24     def get(self):
# ---> 25         self.join()
#      26
#      27         assert self._set_flag == True
#
# ~/.local/lib/python3.8/site-packages/msgpackrpc/future.py in join(self)
#      20     def join(self):
#      21         while (not self._set_flag):
# ---> 22             self._loop.start()
#      23
#      24     def get(self):
#
# ~/.local/lib/python3.8/site-packages/msgpackrpc/loop.py in start(self)
#      20         """
#      21
# ---> 22         self._ioloop.start()
#      23
#      24     def stop(self):
#
# ~/.local/lib/python3.8/site-packages/tornado/ioloop.py in start(self)
#     861
#     862                 try:
# --> 863                     event_pairs = self._impl.poll(poll_timeout)
#     864                 except Exception as e:
#     865                     # Depending on python version and IOLoop implementation,
#
# KeyboardInterrupt:
